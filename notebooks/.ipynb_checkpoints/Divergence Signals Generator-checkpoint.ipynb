# %% [markdown]
# # Introduction
#
# In this notebook, I develop a new indicator for detecting Divergences. Based on most popular oscillators, as: MACD, RSI, Stochastic; and on the ZigZag indicator, it generates signals, such as:
#
# - RegularBullishDivergence
# - RegularBearishDivergence
# - HiddenBullishDivergence
# - HiddenBearishDivergence
#
# Also it prints on the chart, those points where divergence appear.

# %%
import sys

####################################################################################
# Data handling 
import pandas as pd
from pandas import concat
from pandas.plotting import scatter_matrix
import numpy as np

####################################################################################
# Visualization
import matplotlib.pyplot as plt
from matplotlib import dates, ticker
from matplotlib.dates import (MONDAY, DateFormatter, MonthLocator, WeekdayLocator, date2num)
import matplotlib as mpl
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.graph_objs import *
from plotly.tools import FigureFactory as FF
import plotly.tools as tls
plotly.offline.init_notebook_mode(connected=True)

####################################################################################
# TA-Lib: 
import talib

####################################################################################
# Other utilities
import datetime
import time
import os
import sys
import math
from enum import Enum
import logging
logging.basicConfig(level=logging.DEBUG, stream=sys.stdout)

print('Packages loaded!!')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# Packages loaded!!
# DEBUG:matplotlib.pyplot:Loaded backend module://ipykernel.pylab.backend_inline version unknown.

# %%
# Append path for MACD_Signal_Listener class (parent folder)
sys.path.append('..')

# import main class and event class
from Divergences import Divergences

# creates divergence indicator
_div = Divergences(level=logging.DEBUG)
# Out:
# INFO:Divergences:Created!
# INFO:ZIGZAG_Signal_Listener:Created!

# %%
# load dataframe
df_H1 = pd.read_csv('../csv_data/EURUSD_H1.csv', sep=';')
df_H1['TIME'] = df_H1['DATE'] + '  ' + df_H1['TIME'] 
df_H1['TIME'] = df_H1['TIME'].map(lambda x: datetime.datetime.strptime(x, '%Y.%m.%d %H:%M:%S'))  
df_H1['TIME'] = pd.to_datetime(df_H1['TIME'])
df_H1 = df_H1[['TIME', 'OPEN','HIGH','LOW','CLOSE']]

print('h1_rows={}'.format(df_H1.shape[0]))
# Out:
# h1_rows=27264

# %%
# executes divergences indicator
_df = _div.searchDivergences(df_H1, 
                             zigzag_cfg = {'minbars':12, 'bb_period':20, 'bb_dev':2.0, 'bb_sma':[100], 'nan_value':0.0, 'level':logging.WARN}, 
                             level=logging.DEBUG, exitAt='zzpoints-processing')
# Out:
# DEBUG:Divergences:row [0]: error-zigzag-isnan
# DEBUG:Divergences:row [1]: error-zigzag-isnan
# DEBUG:Divergences:row [2]: error-zigzag-isnan
# DEBUG:Divergences:row [3]: error-zigzag-isnan
# DEBUG:Divergences:row [4]: error-zigzag-isnan
# DEBUG:Divergences:row [5]: error-zigzag-isnan
# DEBUG:Divergences:row [6]: error-zigzag-isnan
# DEBUG:Divergences:row [7]: error-zigzag-isnan
# DEBUG:Divergences:row [8]: error-zigzag-isnan
# DEBUG:Divergences:row [9]: error-zigzag-isnan
# DEBUG:Divergences:row [10]: error-zigzag-isnan
# DEBUG:Divergences:row [11]: error-zigzag-isnan
# DEBUG:Divergences:row [12]: error-zigzag-isnan
# DEBUG:Divergences:row [13]: error-zigzag-isnan
# DEBUG:Divergences:row [14]: error-zigzag-isnan
# DEBUG:Divergences:row [15]: error-zigzag-isnan
# DEBUG:Divergences:row [16]: error-zigzag-isnan
# DEBUG:Divergences:row [17]: error-zigzag-isnan
# DEBUG:Divergences:row [18]: error-zigzag-isnan
# DEBUG:Divergences:row [19]: error-zigzag-isnan
# DEBUG:Divergences:row [20]: error-zigzag-isnan
# DEBUG:Divergences:row [21]: error-zigzag-isnan
# DEBUG:Divergences:row [22]: error-zigzag-isnan
# DEBUG:Divergences:row [23]: error-zigzag-isnan
# DEBUG:Divergences:row [24]: error-zigzag-isnan
# DEBUG:Divergences:row [25]: error-zigzag-isnan
# DEBUG:Divergences:row [26]: error-zigzag-isnan
# DEBUG:Divergences:row [27]: error-zigzag-isnan
# DEBUG:Divergences:row [28]: error-zigzag-isnan
# DEBUG:Divergences:row [29]: error-zigzag-isnan
# DEBUG:Divergences:row [30]: error-zigzag-isnan
# DEBUG:Divergences:row [31]: error-zigzag-isnan
# DEBUG:Divergences:row [32]: error-zigzag-isnan
# DEBUG:Divergences:row [33]: error-zigzag-isnan
# DEBUG:Divergences:row [34]: error-zigzag-isnan
# DEBUG:Divergences:row [35]: error-zigzag-isnan
# DEBUG:Divergences:row [36]: error-zigzag-isnan
# DEBUG:Divergences:row [37]: error-zigzag-isnan
# DEBUG:Divergences:row [38]: error-zigzag-isnan
# DEBUG:Divergences:row [39]: error-zigzag-isnan
# DEBUG:Divergences:row [40]: error-zigzag-isnan
# DEBUG:Divergences:row [41]: error-zigzag-isnan
# DEBUG:Divergences:row [42]: error-zigzag-isnan
# DEBUG:Divergences:row [43]: error-zigzag-isnan
# DEBUG:Divergences:row [44]: error-zigzag-isnan
# DEBUG:Divergences:row [45]: error-zigzag-isnan
# DEBUG:Divergences:row [46]: error-zigzag-isnan
# DEBUG:Divergences:row [47]: error-zigzag-isnan
# DEBUG:Divergences:row [48]: error-zzpoints-count=1
# DEBUG:Divergences:row [49]: error-zigzag-isnan
# DEBUG:Divergences:row [50]: error-zigzag-isnan
# DEBUG:Divergences:row [51]: error-zigzag-isnan
# DEBUG:Divergences:row [52]: error-zigzag-isnan
# DEBUG:Divergences:row [53]: error-zigzag-isnan
# DEBUG:Divergences:row [54]: error-zigzag-isnan
# DEBUG:Divergences:row [55]: error-zigzag-isnan
# DEBUG:Divergences:row [56]: error-zigzag-isnan
# DEBUG:Divergences:row [57]: error-zigzag-isnan
# DEBUG:Divergences:row [58]: error-zigzag-isnan
# DEBUG:Divergences:row [59]: error-zigzag-isnan
# DEBUG:Divergences:row [60]: error-zigzag-isnan
# DEBUG:Divergences:row [61]: error-zigzag-isnan
# DEBUG:Divergences:row [62]: error-zigzag-isnan
# DEBUG:Divergences:row [63]: error-zigzag-isnan
# DEBUG:Divergences:row [64]: error-zigzag-isnan
# DEBUG:Divergences:row [65]: error-zigzag-isnan
# DEBUG:Divergences:row [66]: error-zigzag-isnan
# DEBUG:Divergences:row [67]: error-zigzag-isnan
# DEBUG:Divergences:row [68]: error-zigzag-isnan
# DEBUG:Divergences:row [69]: error-zigzag-isnan
# DEBUG:Divergences:row [70]: error-zigzag-isnan
# DEBUG:Divergences:row [71]: error-zigzag-isnan
# DEBUG:Divergences:row [72]: error-zigzag-isnan
# DEBUG:Divergences:row [73]: error-zigzag-isnan
# DEBUG:Divergences:row [74]: error-zigzag-isnan
# DEBUG:Divergences:row [75]: error-zigzag-isnan
# DEBUG:Divergences:row [76]: error-zigzag-isnan
# DEBUG:Divergences:row [77]: error-zigzag-isnan
# DEBUG:Divergences:row [78]: error-zigzag-isnan
# DEBUG:Divergences:row [79]: error-zigzag-isnan
# DEBUG:Divergences:row [80]: error-zigzag-isnan
# DEBUG:Divergences:row [81]: error-zigzag-isnan
# DEBUG:Divergences:row [82]: error-zigzag-isnan
# DEBUG:Divergences:row [83]: error-zigzag-isnan
# DEBUG:Divergences:row [84]: error-zigzag-isnan
# DEBUG:Divergences:row [85]: error-zigzag-isnan
# DEBUG:Divergences:row [86]: error-zigzag-isnan
# DEBUG:Divergences:row [87]: error-zigzag-isnan
# DEBUG:Divergences:row [88]: error-zigzag-isnan
# DEBUG:Divergences:row [89]: error-zigzag-isnan
# DEBUG:Divergences:row [90]: error-zigzag-isnan
# DEBUG:Divergences:row [91]: error-zigzag-isnan
# DEBUG:Divergences:row [92]: error-zigzag-isnan
# DEBUG:Divergences:row [93]: error-zigzag-isnan
# DEBUG:Divergences:row [94]: error-zigzag-isnan
# DEBUG:Divergences:row [95]: error-zigzag-isnan
# DEBUG:Divergences:row [96]: error-zigzag-isnan
# DEBUG:Divergences:row [97]: error-zigzag-isnan
# DEBUG:Divergences:row [98]: error-zzpoints-count=2
# DEBUG:Divergences:row [99]: error-zigzag-isnan
# DEBUG:Divergences:row [100]: error-zigzag-isnan
# DEBUG:Divergences:row [101]: error-zigzag-isnan
# DEBUG:Divergences:row [102]: error-zigzag-isnan
# DEBUG:Divergences:row [103]: error-zigzag-isnan
# DEBUG:Divergences:row [104]: error-zigzag-isnan
# DEBUG:Divergences:row [105]: error-zigzag-isnan
# DEBUG:Divergences:row [106]: error-zigzag-isnan
# DEBUG:Divergences:row [107]: error-zigzag-isnan
# DEBUG:Divergences:row [108]: error-zigzag-isnan
# DEBUG:Divergences:row [109]: error-zigzag-isnan
# DEBUG:Divergences:row [110]: error-zigzag-isnan
# DEBUG:Divergences:row [111]: error-zigzag-isnan
# DEBUG:Divergences:row [112]: error-zigzag-isnan
# DEBUG:Divergences:row [113]: error-zigzag-isnan
# DEBUG:Divergences:row [114]: error-zigzag-isnan
# DEBUG:Divergences:row [115]: error-zigzag-isnan
# DEBUG:Divergences:row [116]: error-zigzag-isnan
# DEBUG:Divergences:row [117]: error-zigzag-isnan
# DEBUG:Divergences:row [118]: error-zigzag-isnan
# DEBUG:Divergences:row [119]: error-zigzag-isnan
# DEBUG:Divergences:row [120]: error-zigzag-isnan
# DEBUG:Divergences:row [121]: error-zigzag-isnan
# DEBUG:Divergences:row [122]: error-zzpoints-count=3
# DEBUG:Divergences:row [123]: error-zigzag-isnan
# DEBUG:Divergences:row [124]: error-zigzag-isnan
# DEBUG:Divergences:row [125]: error-zigzag-isnan
# DEBUG:Divergences:row [126]: error-zigzag-isnan
# DEBUG:Divergences:row [127]: error-zigzag-isnan
# DEBUG:Divergences:row [128]: error-zigzag-isnan
# DEBUG:Divergences:row [129]: error-zigzag-isnan
# DEBUG:Divergences:row [130]: error-zigzag-isnan
# DEBUG:Divergences:row [131]: error-zigzag-isnan
# DEBUG:Divergences:row [132]: error-zigzag-isnan
# DEBUG:Divergences:row [133]: error-zigzag-isnan
# DEBUG:Divergences:row [134]: error-zigzag-isnan
# DEBUG:Divergences:row [135]: error-zigzag-isnan
# DEBUG:Divergences:row [136]: error-zigzag-isnan
# DEBUG:Divergences:row [137]: error-zigzag-isnan
# DEBUG:Divergences:row [138]: error-zigzag-isnan
# DEBUG:Divergences:row [139]: error-zigzag-isnan
# DEBUG:Divergences:row [140]: error-zigzag-isnan
# DEBUG:Divergences:row [141]: error-zigzag-isnan
# DEBUG:Divergences:row [142]: error-zigzag-isnan
# DEBUG:Divergences:row [143]: error-zigzag-isnan
# DEBUG:Divergences:row [144]: error-zigzag-isnan
# DEBUG:Divergences:row [145]: error-zigzag-isnan
# DEBUG:Divergences:row [146]: error-zigzag-isnan
# DEBUG:Divergences:row [147]: error-zigzag-isnan
# DEBUG:Divergences:row [148]: error-zigzag-isnan
# DEBUG:Divergences:row [149]: error-zigzag-isnan
# DEBUG:Divergences:row [150]: error-zzpoints-count=4
# DEBUG:Divergences:row [151]: error-zigzag-isnan
# DEBUG:Divergences:row [152]: error-zigzag-isnan
# DEBUG:Divergences:row [153]: error-zzpoints-count=5
# DEBUG:Divergences:row [154]: error-zigzag-isnan
# DEBUG:Divergences:row [155]: error-zigzag-isnan
# DEBUG:Divergences:row [156]: error-zigzag-isnan
# DEBUG:Divergences:row [157]: error-zigzag-isnan
# DEBUG:Divergences:row [158]: error-zigzag-isnan
# DEBUG:Divergences:row [159]: error-zigzag-isnan
# DEBUG:Divergences:row [160]: error-zigzag-isnan
# DEBUG:Divergences:row [161]: error-zigzag-isnan
# DEBUG:Divergences:row [162]: error-zigzag-isnan
# DEBUG:Divergences:row [163]: error-zigzag-isnan
# DEBUG:Divergences:row [164]: error-zigzag-isnan
# DEBUG:Divergences:row [165]: error-zigzag-isnan
# DEBUG:Divergences:row [166]: error-zigzag-isnan
# DEBUG:Divergences:row [167]: error-zigzag-isnan
# DEBUG:Divergences:row [168]: error-zigzag-isnan
# DEBUG:Divergences:row [169]: error-zigzag-isnan
# DEBUG:Divergences:row [170]: error-zigzag-isnan
# DEBUG:Divergences:row [171]: error-zigzag-isnan
# DEBUG:Divergences:row [172]: error-zigzag-isnan
# DEBUG:Divergences:row [173]: error-zigzag-isnan
# DEBUG:Divergences:row [174]: error-zigzag-isnan
# DEBUG:Divergences:row [175]: error-zigzag-isnan
# DEBUG:Divergences:row [176]: error-zigzag-isnan
# DEBUG:Divergences:row [177]: zzpoints=48     1.18451
# 98     1.14594
# 122    1.16381
# 150    1.15397
# 153    1.16796
# 177    1.13163
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [178]: error-zigzag-isnan
# DEBUG:Divergences:row [179]: error-zigzag-isnan
# DEBUG:Divergences:row [180]: error-zigzag-isnan
# DEBUG:Divergences:row [181]: error-zigzag-isnan
# DEBUG:Divergences:row [182]: error-zigzag-isnan
# DEBUG:Divergences:row [183]: error-zigzag-isnan
# DEBUG:Divergences:row [184]: error-zigzag-isnan
# DEBUG:Divergences:row [185]: error-zigzag-isnan
# DEBUG:Divergences:row [186]: error-zigzag-isnan
# DEBUG:Divergences:row [187]: error-zigzag-isnan
# DEBUG:Divergences:row [188]: error-zigzag-isnan
# DEBUG:Divergences:row [189]: error-zigzag-isnan
# DEBUG:Divergences:row [190]: error-zigzag-isnan
# DEBUG:Divergences:row [191]: zzpoints=98     1.14594
# 122    1.16381
# 150    1.15397
# 153    1.16796
# 177    1.13163
# 191    1.16485
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [192]: error-zigzag-isnan
# DEBUG:Divergences:row [193]: error-zigzag-isnan
# DEBUG:Divergences:row [194]: error-zigzag-isnan
# DEBUG:Divergences:row [195]: error-zigzag-isnan
# DEBUG:Divergences:row [196]: error-zigzag-isnan
# DEBUG:Divergences:row [197]: error-zigzag-isnan
# DEBUG:Divergences:row [198]: error-zigzag-isnan
# DEBUG:Divergences:row [199]: error-zigzag-isnan
# DEBUG:Divergences:row [200]: error-zigzag-isnan
# DEBUG:Divergences:row [201]: error-zigzag-isnan
# DEBUG:Divergences:row [202]: error-zigzag-isnan
# DEBUG:Divergences:row [203]: error-zigzag-isnan
# DEBUG:Divergences:row [204]: error-zigzag-isnan
# DEBUG:Divergences:row [205]: error-zigzag-isnan
# DEBUG:Divergences:row [206]: error-zigzag-isnan
# DEBUG:Divergences:row [207]: error-zigzag-isnan
# DEBUG:Divergences:row [208]: error-zigzag-isnan
# DEBUG:Divergences:row [209]: error-zigzag-isnan
# DEBUG:Divergences:row [210]: error-zigzag-isnan
# DEBUG:Divergences:row [211]: error-zigzag-isnan
# DEBUG:Divergences:row [212]: error-zigzag-isnan
# DEBUG:Divergences:row [213]: error-zigzag-isnan
# DEBUG:Divergences:row [214]: error-zigzag-isnan
# DEBUG:Divergences:row [215]: error-zigzag-isnan
# DEBUG:Divergences:row [216]: error-zigzag-isnan
# DEBUG:Divergences:row [217]: error-zigzag-isnan
# DEBUG:Divergences:row [218]: error-zigzag-isnan
# DEBUG:Divergences:row [219]: error-zigzag-isnan
# DEBUG:Divergences:row [220]: error-zigzag-isnan
# DEBUG:Divergences:row [221]: error-zigzag-isnan
# DEBUG:Divergences:row [222]: error-zigzag-isnan
# DEBUG:Divergences:row [223]: error-zigzag-isnan
# DEBUG:Divergences:row [224]: error-zigzag-isnan
# DEBUG:Divergences:row [225]: error-zigzag-isnan
# DEBUG:Divergences:row [226]: zzpoints=122    1.16381
# 150    1.15397
# 153    1.16796
# 177    1.13163
# 191    1.16485
# 226    1.10970
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [227]: error-zigzag-isnan
# DEBUG:Divergences:row [228]: error-zigzag-isnan
# DEBUG:Divergences:row [229]: error-zigzag-isnan
# DEBUG:Divergences:row [230]: error-zigzag-isnan
# DEBUG:Divergences:row [231]: error-zigzag-isnan
# DEBUG:Divergences:row [232]: error-zigzag-isnan
# DEBUG:Divergences:row [233]: error-zigzag-isnan
# DEBUG:Divergences:row [234]: error-zigzag-isnan
# DEBUG:Divergences:row [235]: error-zigzag-isnan
# DEBUG:Divergences:row [236]: error-zigzag-isnan
# DEBUG:Divergences:row [237]: error-zigzag-isnan
# DEBUG:Divergences:row [238]: error-zigzag-isnan
# DEBUG:Divergences:row [239]: error-zigzag-isnan
# DEBUG:Divergences:row [240]: error-zigzag-isnan
# DEBUG:Divergences:row [241]: error-zigzag-isnan
# DEBUG:Divergences:row [242]: error-zigzag-isnan
# DEBUG:Divergences:row [243]: error-zigzag-isnan
# DEBUG:Divergences:row [244]: error-zigzag-isnan
# DEBUG:Divergences:row [245]: error-zigzag-isnan
# DEBUG:Divergences:row [246]: error-zigzag-isnan
# DEBUG:Divergences:row [247]: error-zigzag-isnan
# DEBUG:Divergences:row [248]: error-zigzag-isnan
# DEBUG:Divergences:row [249]: zzpoints=150    1.15397
# 153    1.16796
# 177    1.13163
# 191    1.16485
# 226    1.10970
# 249    1.14225
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [250]: error-zigzag-isnan
# DEBUG:Divergences:row [251]: error-zigzag-isnan
# DEBUG:Divergences:row [252]: error-zigzag-isnan
# DEBUG:Divergences:row [253]: error-zigzag-isnan
# DEBUG:Divergences:row [254]: error-zigzag-isnan
# DEBUG:Divergences:row [255]: error-zigzag-isnan
# DEBUG:Divergences:row [256]: error-zigzag-isnan
# DEBUG:Divergences:row [257]: error-zigzag-isnan
# DEBUG:Divergences:row [258]: error-zigzag-isnan
# DEBUG:Divergences:row [259]: error-zigzag-isnan
# DEBUG:Divergences:row [260]: error-zigzag-isnan
# DEBUG:Divergences:row [261]: error-zigzag-isnan
# DEBUG:Divergences:row [262]: error-zigzag-isnan
# DEBUG:Divergences:row [263]: error-zigzag-isnan
# DEBUG:Divergences:row [264]: error-zigzag-isnan
# DEBUG:Divergences:row [265]: error-zigzag-isnan
# DEBUG:Divergences:row [266]: error-zigzag-isnan
# DEBUG:Divergences:row [267]: error-zigzag-isnan
# DEBUG:Divergences:row [268]: error-zigzag-isnan
# DEBUG:Divergences:row [269]: error-zigzag-isnan
# DEBUG:Divergences:row [270]: error-zigzag-isnan
# DEBUG:Divergences:row [271]: error-zigzag-isnan
# DEBUG:Divergences:row [272]: error-zigzag-isnan
# DEBUG:Divergences:row [273]: error-zigzag-isnan
# DEBUG:Divergences:row [274]: error-zigzag-isnan
# DEBUG:Divergences:row [275]: error-zigzag-isnan
# DEBUG:Divergences:row [276]: error-zigzag-isnan
# DEBUG:Divergences:row [277]: error-zigzag-isnan
# DEBUG:Divergences:row [278]: error-zigzag-isnan
# DEBUG:Divergences:row [279]: error-zigzag-isnan
# DEBUG:Divergences:row [280]: error-zigzag-isnan
# DEBUG:Divergences:row [281]: error-zigzag-isnan
# DEBUG:Divergences:row [282]: error-zigzag-isnan
# DEBUG:Divergences:row [283]: error-zigzag-isnan
# DEBUG:Divergences:row [284]: error-zigzag-isnan
# DEBUG:Divergences:row [285]: error-zigzag-isnan
# DEBUG:Divergences:row [286]: error-zigzag-isnan
# DEBUG:Divergences:row [287]: error-zigzag-isnan
# DEBUG:Divergences:row [288]: error-zigzag-isnan
# DEBUG:Divergences:row [289]: error-zigzag-isnan
# DEBUG:Divergences:row [290]: error-zigzag-isnan
# DEBUG:Divergences:row [291]: error-zigzag-isnan
# DEBUG:Divergences:row [292]: error-zigzag-isnan
# DEBUG:Divergences:row [293]: error-zigzag-isnan
# DEBUG:Divergences:row [294]: error-zigzag-isnan
# DEBUG:Divergences:row [295]: error-zigzag-isnan
# DEBUG:Divergences:row [296]: error-zigzag-isnan
# DEBUG:Divergences:row [297]: error-zigzag-isnan
# DEBUG:Divergences:row [298]: error-zigzag-isnan
# DEBUG:Divergences:row [299]: error-zigzag-isnan
# DEBUG:Divergences:row [300]: error-zigzag-isnan
# DEBUG:Divergences:row [301]: error-zigzag-isnan
# DEBUG:Divergences:row [302]: error-zigzag-isnan
# DEBUG:Divergences:row [303]: error-zigzag-isnan
# DEBUG:Divergences:row [304]: zzpoints=153    1.16796
# 177    1.13163
# 191    1.16485
# 226    1.10970
# 249    1.14225
# 304    1.12612
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [305]: error-zigzag-isnan
# DEBUG:Divergences:row [306]: error-zigzag-isnan
# DEBUG:Divergences:row [307]: error-zigzag-isnan
# DEBUG:Divergences:row [308]: error-zigzag-isnan
# DEBUG:Divergences:row [309]: error-zigzag-isnan
# DEBUG:Divergences:row [310]: error-zigzag-isnan
# DEBUG:Divergences:row [311]: error-zigzag-isnan
# DEBUG:Divergences:row [312]: error-zigzag-isnan
# DEBUG:Divergences:row [313]: error-zigzag-isnan
# DEBUG:Divergences:row [314]: zzpoints=177    1.13163
# 191    1.16485
# 226    1.10970
# 249    1.14225
# 304    1.12612
# 314    1.13670
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [315]: error-zigzag-isnan
# DEBUG:Divergences:row [316]: error-zigzag-isnan
# DEBUG:Divergences:row [317]: error-zigzag-isnan
# DEBUG:Divergences:row [318]: error-zigzag-isnan
# DEBUG:Divergences:row [319]: error-zigzag-isnan
# DEBUG:Divergences:row [320]: error-zigzag-isnan
# DEBUG:Divergences:row [321]: error-zigzag-isnan
# DEBUG:Divergences:row [322]: error-zigzag-isnan
# DEBUG:Divergences:row [323]: error-zigzag-isnan
# DEBUG:Divergences:row [324]: error-zigzag-isnan
# DEBUG:Divergences:row [325]: error-zigzag-isnan
# DEBUG:Divergences:row [326]: error-zigzag-isnan
# DEBUG:Divergences:row [327]: error-zigzag-isnan
# DEBUG:Divergences:row [328]: error-zigzag-isnan
# DEBUG:Divergences:row [329]: error-zigzag-isnan
# DEBUG:Divergences:row [330]: error-zigzag-isnan
# DEBUG:Divergences:row [331]: error-zigzag-isnan
# DEBUG:Divergences:row [332]: error-zigzag-isnan
# DEBUG:Divergences:row [333]: error-zigzag-isnan
# DEBUG:Divergences:row [334]: error-zigzag-isnan
# DEBUG:Divergences:row [335]: error-zigzag-isnan
# DEBUG:Divergences:row [336]: error-zigzag-isnan
# DEBUG:Divergences:row [337]: error-zigzag-isnan
# DEBUG:Divergences:row [338]: error-zigzag-isnan
# DEBUG:Divergences:row [339]: error-zigzag-isnan
# DEBUG:Divergences:row [340]: error-zigzag-isnan
# DEBUG:Divergences:row [341]: error-zigzag-isnan
# DEBUG:Divergences:row [342]: error-zigzag-isnan
# DEBUG:Divergences:row [343]: error-zigzag-isnan
# DEBUG:Divergences:row [344]: zzpoints=191    1.16485
# 226    1.10970
# 249    1.14225
# 304    1.12612
# 314    1.13670
# 344    1.12770
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [345]: error-zigzag-isnan
# DEBUG:Divergences:row [346]: error-zigzag-isnan
# DEBUG:Divergences:row [347]: error-zigzag-isnan
# DEBUG:Divergences:row [348]: error-zigzag-isnan
# DEBUG:Divergences:row [349]: error-zigzag-isnan
# DEBUG:Divergences:row [350]: error-zigzag-isnan
# DEBUG:Divergences:row [351]: error-zigzag-isnan
# DEBUG:Divergences:row [352]: error-zigzag-isnan
# DEBUG:Divergences:row [353]: error-zigzag-isnan
# DEBUG:Divergences:row [354]: error-zigzag-isnan
# DEBUG:Divergences:row [355]: error-zigzag-isnan
# DEBUG:Divergences:row [356]: error-zigzag-isnan
# DEBUG:Divergences:row [357]: error-zigzag-isnan
# DEBUG:Divergences:row [358]: error-zigzag-isnan
# DEBUG:Divergences:row [359]: error-zigzag-isnan
# DEBUG:Divergences:row [360]: error-zigzag-isnan
# DEBUG:Divergences:row [361]: error-zigzag-isnan
# DEBUG:Divergences:row [362]: error-zigzag-isnan
# DEBUG:Divergences:row [363]: error-zigzag-isnan
# DEBUG:Divergences:row [364]: error-zigzag-isnan
# DEBUG:Divergences:row [365]: error-zigzag-isnan
# DEBUG:Divergences:row [366]: error-zigzag-isnan
# DEBUG:Divergences:row [367]: error-zigzag-isnan
# DEBUG:Divergences:row [368]: error-zigzag-isnan
# DEBUG:Divergences:row [369]: zzpoints=226    1.10970
# 249    1.14225
# 304    1.12612
# 314    1.13670
# 344    1.12770
# 369    1.15337
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [370]: error-zigzag-isnan
# DEBUG:Divergences:row [371]: error-zigzag-isnan
# DEBUG:Divergences:row [372]: error-zigzag-isnan
# DEBUG:Divergences:row [373]: error-zigzag-isnan
# DEBUG:Divergences:row [374]: error-zigzag-isnan
# DEBUG:Divergences:row [375]: error-zigzag-isnan
# DEBUG:Divergences:row [376]: error-zigzag-isnan
# DEBUG:Divergences:row [377]: error-zigzag-isnan
# DEBUG:Divergences:row [378]: error-zigzag-isnan
# DEBUG:Divergences:row [379]: error-zigzag-isnan
# DEBUG:Divergences:row [380]: zzpoints=249    1.14225
# 304    1.12612
# 314    1.13670
# 344    1.12770
# 369    1.15337
# 380    1.13122
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [381]: error-zigzag-isnan
# DEBUG:Divergences:row [382]: error-zigzag-isnan
# DEBUG:Divergences:row [383]: error-zigzag-isnan
# DEBUG:Divergences:row [384]: error-zigzag-isnan
# DEBUG:Divergences:row [385]: error-zigzag-isnan
# DEBUG:Divergences:row [386]: error-zigzag-isnan
# DEBUG:Divergences:row [387]: error-zigzag-isnan
# DEBUG:Divergences:row [388]: error-zigzag-isnan
# DEBUG:Divergences:row [389]: zzpoints=304    1.12612
# 314    1.13670
# 344    1.12770
# 369    1.15337
# 380    1.13122
# 389    1.15332
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [390]: error-zigzag-isnan
# DEBUG:Divergences:row [391]: error-zigzag-isnan
# DEBUG:Divergences:row [392]: error-zigzag-isnan
# DEBUG:Divergences:row [393]: error-zigzag-isnan
# DEBUG:Divergences:row [394]: error-zigzag-isnan
# DEBUG:Divergences:row [395]: error-zigzag-isnan
# DEBUG:Divergences:row [396]: error-zigzag-isnan
# DEBUG:Divergences:row [397]: error-zigzag-isnan
# DEBUG:Divergences:row [398]: error-zigzag-isnan
# DEBUG:Divergences:row [399]: error-zigzag-isnan
# DEBUG:Divergences:row [400]: error-zigzag-isnan
# DEBUG:Divergences:row [401]: error-zigzag-isnan
# DEBUG:Divergences:row [402]: error-zigzag-isnan
# DEBUG:Divergences:row [403]: error-zigzag-isnan
# DEBUG:Divergences:row [404]: error-zigzag-isnan
# DEBUG:Divergences:row [405]: error-zigzag-isnan
# DEBUG:Divergences:row [406]: error-zigzag-isnan
# DEBUG:Divergences:row [407]: error-zigzag-isnan
# DEBUG:Divergences:row [408]: error-zigzag-isnan
# DEBUG:Divergences:row [409]: error-zigzag-isnan
# DEBUG:Divergences:row [410]: error-zigzag-isnan
# DEBUG:Divergences:row [411]: error-zigzag-isnan
# DEBUG:Divergences:row [412]: error-zigzag-isnan
# DEBUG:Divergences:row [413]: error-zigzag-isnan
# DEBUG:Divergences:row [414]: error-zigzag-isnan
# DEBUG:Divergences:row [415]: error-zigzag-isnan
# DEBUG:Divergences:row [416]: error-zigzag-isnan
# DEBUG:Divergences:row [417]: error-zigzag-isnan
# DEBUG:Divergences:row [418]: zzpoints=314    1.13670
# 344    1.12770
# 369    1.15337
# 380    1.13122
# 389    1.15332
# 418    1.13035
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [419]: error-zigzag-isnan
# DEBUG:Divergences:row [420]: error-zigzag-isnan
# DEBUG:Divergences:row [421]: error-zigzag-isnan
# DEBUG:Divergences:row [422]: error-zigzag-isnan
# DEBUG:Divergences:row [423]: error-zigzag-isnan
# DEBUG:Divergences:row [424]: error-zigzag-isnan
# DEBUG:Divergences:row [425]: error-zigzag-isnan
# DEBUG:Divergences:row [426]: error-zigzag-isnan
# DEBUG:Divergences:row [427]: error-zigzag-isnan
# DEBUG:Divergences:row [428]: error-zigzag-isnan
# DEBUG:Divergences:row [429]: error-zigzag-isnan
# DEBUG:Divergences:row [430]: error-zigzag-isnan
# DEBUG:Divergences:row [431]: error-zigzag-isnan
# DEBUG:Divergences:row [432]: error-zigzag-isnan
# DEBUG:Divergences:row [433]: error-zigzag-isnan
# DEBUG:Divergences:row [434]: error-zigzag-isnan
# DEBUG:Divergences:row [435]: error-zigzag-isnan
# DEBUG:Divergences:row [436]: error-zigzag-isnan
# DEBUG:Divergences:row [437]: zzpoints=344    1.12770
# 369    1.15337
# 380    1.13122
# 389    1.15332
# 418    1.13035
# 437    1.14983
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [438]: error-zigzag-isnan
# DEBUG:Divergences:row [439]: error-zigzag-isnan
# DEBUG:Divergences:row [440]: error-zigzag-isnan
# DEBUG:Divergences:row [441]: error-zigzag-isnan
# DEBUG:Divergences:row [442]: error-zigzag-isnan
# DEBUG:Divergences:row [443]: error-zigzag-isnan
# DEBUG:Divergences:row [444]: error-zigzag-isnan
# DEBUG:Divergences:row [445]: error-zigzag-isnan
# DEBUG:Divergences:row [446]: error-zigzag-isnan
# DEBUG:Divergences:row [447]: error-zigzag-isnan
# DEBUG:Divergences:row [448]: error-zigzag-isnan
# DEBUG:Divergences:row [449]: error-zigzag-isnan
# DEBUG:Divergences:row [450]: error-zigzag-isnan
# DEBUG:Divergences:row [451]: error-zigzag-isnan
# DEBUG:Divergences:row [452]: error-zigzag-isnan
# DEBUG:Divergences:row [453]: error-zigzag-isnan
# DEBUG:Divergences:row [454]: error-zigzag-isnan
# DEBUG:Divergences:row [455]: error-zigzag-isnan
# DEBUG:Divergences:row [456]: error-zigzag-isnan
# DEBUG:Divergences:row [457]: error-zigzag-isnan
# DEBUG:Divergences:row [458]: error-zigzag-isnan
# DEBUG:Divergences:row [459]: error-zigzag-isnan
# DEBUG:Divergences:row [460]: error-zigzag-isnan
# DEBUG:Divergences:row [461]: error-zigzag-isnan
# DEBUG:Divergences:row [462]: error-zigzag-isnan
# DEBUG:Divergences:row [463]: error-zigzag-isnan
# DEBUG:Divergences:row [464]: error-zigzag-isnan
# DEBUG:Divergences:row [465]: zzpoints=369    1.15337
# 380    1.13122
# 389    1.15332
# 418    1.13035
# 437    1.14983
# 465    1.12701
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [466]: error-zigzag-isnan
# DEBUG:Divergences:row [467]: error-zigzag-isnan
# DEBUG:Divergences:row [468]: error-zigzag-isnan
# DEBUG:Divergences:row [469]: error-zigzag-isnan
# DEBUG:Divergences:row [470]: error-zigzag-isnan
# DEBUG:Divergences:row [471]: error-zigzag-isnan
# DEBUG:Divergences:row [472]: error-zigzag-isnan
# DEBUG:Divergences:row [473]: error-zigzag-isnan
# DEBUG:Divergences:row [474]: error-zigzag-isnan
# DEBUG:Divergences:row [475]: error-zigzag-isnan
# DEBUG:Divergences:row [476]: zzpoints=380    1.13122
# 389    1.15332
# 418    1.13035
# 437    1.14983
# 465    1.12701
# 476    1.13520
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [477]: error-zigzag-isnan
# DEBUG:Divergences:row [478]: error-zigzag-isnan
# DEBUG:Divergences:row [479]: zzpoints=389    1.15332
# 418    1.13035
# 437    1.14983
# 465    1.12701
# 476    1.13520
# 479    1.12698
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [480]: error-zigzag-isnan
# DEBUG:Divergences:row [481]: error-zigzag-isnan
# DEBUG:Divergences:row [482]: error-zigzag-isnan
# DEBUG:Divergences:row [483]: error-zigzag-isnan
# DEBUG:Divergences:row [484]: error-zigzag-isnan
# DEBUG:Divergences:row [485]: error-zigzag-isnan
# DEBUG:Divergences:row [486]: error-zigzag-isnan
# DEBUG:Divergences:row [487]: error-zigzag-isnan
# DEBUG:Divergences:row [488]: error-zigzag-isnan
# DEBUG:Divergences:row [489]: error-zigzag-isnan
# DEBUG:Divergences:row [490]: error-zigzag-isnan
# DEBUG:Divergences:row [491]: error-zigzag-isnan
# DEBUG:Divergences:row [492]: error-zigzag-isnan
# DEBUG:Divergences:row [493]: error-zigzag-isnan
# DEBUG:Divergences:row [494]: error-zigzag-isnan
# DEBUG:Divergences:row [495]: error-zigzag-isnan
# DEBUG:Divergences:row [496]: error-zigzag-isnan
# DEBUG:Divergences:row [497]: error-zigzag-isnan
# DEBUG:Divergences:row [498]: error-zigzag-isnan
# DEBUG:Divergences:row [499]: error-zigzag-isnan
# DEBUG:Divergences:row [500]: error-zigzag-isnan
# DEBUG:Divergences:row [501]: error-zigzag-isnan
# DEBUG:Divergences:row [502]: error-zigzag-isnan
# DEBUG:Divergences:row [503]: error-zigzag-isnan
# DEBUG:Divergences:row [504]: error-zigzag-isnan
# DEBUG:Divergences:row [505]: error-zigzag-isnan
# DEBUG:Divergences:row [506]: error-zigzag-isnan
# DEBUG:Divergences:row [507]: error-zigzag-isnan
# DEBUG:Divergences:row [508]: error-zigzag-isnan
# DEBUG:Divergences:row [509]: error-zigzag-isnan
# DEBUG:Divergences:row [510]: error-zigzag-isnan
# DEBUG:Divergences:row [511]: error-zigzag-isnan
# DEBUG:Divergences:row [512]: error-zigzag-isnan
# DEBUG:Divergences:row [513]: error-zigzag-isnan
# DEBUG:Divergences:row [514]: error-zigzag-isnan
# DEBUG:Divergences:row [515]: error-zigzag-isnan
# DEBUG:Divergences:row [516]: error-zigzag-isnan
# DEBUG:Divergences:row [517]: error-zigzag-isnan
# DEBUG:Divergences:row [518]: error-zigzag-isnan
# DEBUG:Divergences:row [519]: error-zigzag-isnan
# DEBUG:Divergences:row [520]: error-zigzag-isnan
# DEBUG:Divergences:row [521]: error-zigzag-isnan
# DEBUG:Divergences:row [522]: error-zigzag-isnan
# DEBUG:Divergences:row [523]: error-zigzag-isnan
# DEBUG:Divergences:row [524]: error-zigzag-isnan
# DEBUG:Divergences:row [525]: error-zigzag-isnan
# DEBUG:Divergences:row [526]: error-zigzag-isnan
# DEBUG:Divergences:row [527]: error-zigzag-isnan
# DEBUG:Divergences:row [528]: error-zigzag-isnan
# DEBUG:Divergences:row [529]: error-zigzag-isnan
# DEBUG:Divergences:row [530]: error-zigzag-isnan
# DEBUG:Divergences:row [531]: error-zigzag-isnan
# DEBUG:Divergences:row [532]: error-zigzag-isnan
# DEBUG:Divergences:row [533]: error-zigzag-isnan
# DEBUG:Divergences:row [534]: error-zigzag-isnan
# DEBUG:Divergences:row [535]: error-zigzag-isnan
# DEBUG:Divergences:row [536]: error-zigzag-isnan
# DEBUG:Divergences:row [537]: error-zigzag-isnan
# DEBUG:Divergences:row [538]: error-zigzag-isnan
# DEBUG:Divergences:row [539]: error-zigzag-isnan
# DEBUG:Divergences:row [540]: error-zigzag-isnan
# DEBUG:Divergences:row [541]: error-zigzag-isnan
# DEBUG:Divergences:row [542]: error-zigzag-isnan
# DEBUG:Divergences:row [543]: error-zigzag-isnan
# DEBUG:Divergences:row [544]: error-zigzag-isnan
# DEBUG:Divergences:row [545]: error-zigzag-isnan
# DEBUG:Divergences:row [546]: error-zigzag-isnan
# DEBUG:Divergences:row [547]: error-zigzag-isnan
# DEBUG:Divergences:row [548]: error-zigzag-isnan
# DEBUG:Divergences:row [549]: error-zigzag-isnan
# DEBUG:Divergences:row [550]: error-zigzag-isnan
# DEBUG:Divergences:row [551]: error-zigzag-isnan
# DEBUG:Divergences:row [552]: error-zigzag-isnan
# DEBUG:Divergences:row [553]: error-zigzag-isnan
# DEBUG:Divergences:row [554]: error-zigzag-isnan
# DEBUG:Divergences:row [555]: error-zigzag-isnan
# DEBUG:Divergences:row [556]: error-zigzag-isnan
# DEBUG:Divergences:row [557]: error-zigzag-isnan
# DEBUG:Divergences:row [558]: error-zigzag-isnan
# DEBUG:Divergences:row [559]: error-zigzag-isnan
# DEBUG:Divergences:row [560]: error-zigzag-isnan
# DEBUG:Divergences:row [561]: zzpoints=418    1.13035
# 437    1.14983
# 465    1.12701
# 476    1.13520
# 479    1.12698
# 561    1.14429
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [562]: error-zigzag-isnan
# DEBUG:Divergences:row [563]: error-zigzag-isnan
# DEBUG:Divergences:row [564]: error-zigzag-isnan
# DEBUG:Divergences:row [565]: error-zigzag-isnan
# DEBUG:Divergences:row [566]: error-zigzag-isnan
# DEBUG:Divergences:row [567]: error-zigzag-isnan
# DEBUG:Divergences:row [568]: error-zigzag-isnan
# DEBUG:Divergences:row [569]: error-zigzag-isnan
# DEBUG:Divergences:row [570]: error-zigzag-isnan
# DEBUG:Divergences:row [571]: error-zigzag-isnan
# DEBUG:Divergences:row [572]: error-zigzag-isnan
# DEBUG:Divergences:row [573]: error-zigzag-isnan
# DEBUG:Divergences:row [574]: error-zigzag-isnan
# DEBUG:Divergences:row [575]: error-zigzag-isnan
# DEBUG:Divergences:row [576]: error-zigzag-isnan
# DEBUG:Divergences:row [577]: error-zigzag-isnan
# DEBUG:Divergences:row [578]: error-zigzag-isnan
# DEBUG:Divergences:row [579]: error-zigzag-isnan
# DEBUG:Divergences:row [580]: error-zigzag-isnan
# DEBUG:Divergences:row [581]: error-zigzag-isnan
# DEBUG:Divergences:row [582]: error-zigzag-isnan
# DEBUG:Divergences:row [583]: error-zigzag-isnan
# DEBUG:Divergences:row [584]: error-zigzag-isnan
# DEBUG:Divergences:row [585]: zzpoints=437    1.14983
# 465    1.12701
# 476    1.13520
# 479    1.12698
# 561    1.14429
# 585    1.13196
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [586]: error-zigzag-isnan
# DEBUG:Divergences:row [587]: error-zigzag-isnan
# DEBUG:Divergences:row [588]: error-zigzag-isnan
# DEBUG:Divergences:row [589]: error-zigzag-isnan
# DEBUG:Divergences:row [590]: error-zigzag-isnan
# DEBUG:Divergences:row [591]: error-zigzag-isnan
# DEBUG:Divergences:row [592]: error-zigzag-isnan
# DEBUG:Divergences:row [593]: error-zigzag-isnan
# DEBUG:Divergences:row [594]: zzpoints=465    1.12701
# 476    1.13520
# 479    1.12698
# 561    1.14429
# 585    1.13196
# 594    1.14285
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [595]: error-zigzag-isnan
# DEBUG:Divergences:row [596]: error-zigzag-isnan
# DEBUG:Divergences:row [597]: error-zigzag-isnan
# DEBUG:Divergences:row [598]: error-zigzag-isnan
# DEBUG:Divergences:row [599]: error-zigzag-isnan
# DEBUG:Divergences:row [600]: error-zigzag-isnan
# DEBUG:Divergences:row [601]: error-zigzag-isnan
# DEBUG:Divergences:row [602]: error-zigzag-isnan
# DEBUG:Divergences:row [603]: error-zigzag-isnan
# DEBUG:Divergences:row [604]: error-zigzag-isnan
# DEBUG:Divergences:row [605]: zzpoints=476    1.13520
# 479    1.12698
# 561    1.14429
# 585    1.13196
# 594    1.14285
# 605    1.13191
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [606]: error-zigzag-isnan
# DEBUG:Divergences:row [607]: error-zigzag-isnan
# DEBUG:Divergences:row [608]: error-zigzag-isnan
# DEBUG:Divergences:row [609]: error-zigzag-isnan
# DEBUG:Divergences:row [610]: error-zigzag-isnan
# DEBUG:Divergences:row [611]: error-zigzag-isnan
# DEBUG:Divergences:row [612]: error-zigzag-isnan
# DEBUG:Divergences:row [613]: error-zigzag-isnan
# DEBUG:Divergences:row [614]: error-zigzag-isnan
# DEBUG:Divergences:row [615]: error-zigzag-isnan
# DEBUG:Divergences:row [616]: error-zigzag-isnan
# DEBUG:Divergences:row [617]: error-zigzag-isnan
# DEBUG:Divergences:row [618]: error-zigzag-isnan
# DEBUG:Divergences:row [619]: error-zigzag-isnan
# DEBUG:Divergences:row [620]: error-zigzag-isnan
# DEBUG:Divergences:row [621]: error-zigzag-isnan
# DEBUG:Divergences:row [622]: zzpoints=479    1.12698
# 561    1.14429
# 585    1.13196
# 594    1.14285
# 605    1.13191
# 622    1.14478
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [623]: error-zigzag-isnan
# DEBUG:Divergences:row [624]: error-zigzag-isnan
# DEBUG:Divergences:row [625]: error-zigzag-isnan
# DEBUG:Divergences:row [626]: error-zigzag-isnan
# DEBUG:Divergences:row [627]: error-zigzag-isnan
# DEBUG:Divergences:row [628]: error-zigzag-isnan
# DEBUG:Divergences:row [629]: error-zigzag-isnan
# DEBUG:Divergences:row [630]: error-zigzag-isnan
# DEBUG:Divergences:row [631]: error-zigzag-isnan
# DEBUG:Divergences:row [632]: error-zigzag-isnan
# DEBUG:Divergences:row [633]: error-zigzag-isnan
# DEBUG:Divergences:row [634]: error-zigzag-isnan
# DEBUG:Divergences:row [635]: error-zigzag-isnan
# DEBUG:Divergences:row [636]: error-zigzag-isnan
# DEBUG:Divergences:row [637]: error-zigzag-isnan
# DEBUG:Divergences:row [638]: error-zigzag-isnan
# DEBUG:Divergences:row [639]: error-zigzag-isnan
# DEBUG:Divergences:row [640]: error-zigzag-isnan
# DEBUG:Divergences:row [641]: error-zigzag-isnan
# DEBUG:Divergences:row [642]: error-zigzag-isnan
# DEBUG:Divergences:row [643]: error-zigzag-isnan
# DEBUG:Divergences:row [644]: error-zigzag-isnan
# DEBUG:Divergences:row [645]: error-zigzag-isnan
# DEBUG:Divergences:row [646]: error-zigzag-isnan
# DEBUG:Divergences:row [647]: error-zigzag-isnan
# DEBUG:Divergences:row [648]: error-zigzag-isnan
# DEBUG:Divergences:row [649]: error-zigzag-isnan
# DEBUG:Divergences:row [650]: error-zigzag-isnan
# DEBUG:Divergences:row [651]: error-zigzag-isnan
# DEBUG:Divergences:row [652]: zzpoints=561    1.14429
# 585    1.13196
# 594    1.14285
# 605    1.13191
# 622    1.14478
# 652    1.13335
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [653]: error-zigzag-isnan
# DEBUG:Divergences:row [654]: error-zigzag-isnan
# DEBUG:Divergences:row [655]: error-zigzag-isnan
# DEBUG:Divergences:row [656]: error-zigzag-isnan
# DEBUG:Divergences:row [657]: zzpoints=585    1.13196
# 594    1.14285
# 605    1.13191
# 622    1.14478
# 652    1.13335
# 657    1.14500
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [658]: error-zigzag-isnan
# DEBUG:Divergences:row [659]: error-zigzag-isnan
# DEBUG:Divergences:row [660]: error-zigzag-isnan
# DEBUG:Divergences:row [661]: error-zigzag-isnan
# DEBUG:Divergences:row [662]: error-zigzag-isnan
# DEBUG:Divergences:row [663]: error-zigzag-isnan
# DEBUG:Divergences:row [664]: error-zigzag-isnan
# DEBUG:Divergences:row [665]: error-zigzag-isnan
# DEBUG:Divergences:row [666]: error-zigzag-isnan
# DEBUG:Divergences:row [667]: error-zigzag-isnan
# DEBUG:Divergences:row [668]: error-zigzag-isnan
# DEBUG:Divergences:row [669]: error-zigzag-isnan
# DEBUG:Divergences:row [670]: error-zigzag-isnan
# DEBUG:Divergences:row [671]: error-zigzag-isnan
# DEBUG:Divergences:row [672]: error-zigzag-isnan
# DEBUG:Divergences:row [673]: error-zigzag-isnan
# DEBUG:Divergences:row [674]: error-zigzag-isnan
# DEBUG:Divergences:row [675]: error-zigzag-isnan
# DEBUG:Divergences:row [676]: error-zigzag-isnan
# DEBUG:Divergences:row [677]: error-zigzag-isnan
# DEBUG:Divergences:row [678]: error-zigzag-isnan
# DEBUG:Divergences:row [679]: error-zigzag-isnan
# DEBUG:Divergences:row [680]: error-zigzag-isnan
# DEBUG:Divergences:row [681]: error-zigzag-isnan
# DEBUG:Divergences:row [682]: error-zigzag-isnan
# DEBUG:Divergences:row [683]: error-zigzag-isnan
# DEBUG:Divergences:row [684]: error-zigzag-isnan
# DEBUG:Divergences:row [685]: error-zigzag-isnan
# DEBUG:Divergences:row [686]: error-zigzag-isnan
# DEBUG:Divergences:row [687]: error-zigzag-isnan
# DEBUG:Divergences:row [688]: error-zigzag-isnan
# DEBUG:Divergences:row [689]: error-zigzag-isnan
# DEBUG:Divergences:row [690]: error-zigzag-isnan
# DEBUG:Divergences:row [691]: error-zigzag-isnan
# DEBUG:Divergences:row [692]: error-zigzag-isnan
# DEBUG:Divergences:row [693]: error-zigzag-isnan
# DEBUG:Divergences:row [694]: error-zigzag-isnan
# DEBUG:Divergences:row [695]: error-zigzag-isnan
# DEBUG:Divergences:row [696]: zzpoints=594    1.14285
# 605    1.13191
# 622    1.14478
# 652    1.13335
# 657    1.14500
# 696    1.12788
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [697]: error-zigzag-isnan
# DEBUG:Divergences:row [698]: error-zigzag-isnan
# DEBUG:Divergences:row [699]: error-zigzag-isnan
# DEBUG:Divergences:row [700]: error-zigzag-isnan
# DEBUG:Divergences:row [701]: error-zigzag-isnan
# DEBUG:Divergences:row [702]: error-zigzag-isnan
# DEBUG:Divergences:row [703]: error-zigzag-isnan
# DEBUG:Divergences:row [704]: error-zigzag-isnan
# DEBUG:Divergences:row [705]: error-zigzag-isnan
# DEBUG:Divergences:row [706]: error-zigzag-isnan
# DEBUG:Divergences:row [707]: error-zigzag-isnan
# DEBUG:Divergences:row [708]: error-zigzag-isnan
# DEBUG:Divergences:row [709]: error-zigzag-isnan
# DEBUG:Divergences:row [710]: error-zigzag-isnan
# DEBUG:Divergences:row [711]: error-zigzag-isnan
# DEBUG:Divergences:row [712]: error-zigzag-isnan
# DEBUG:Divergences:row [713]: error-zigzag-isnan
# DEBUG:Divergences:row [714]: error-zigzag-isnan
# DEBUG:Divergences:row [715]: error-zigzag-isnan
# DEBUG:Divergences:row [716]: error-zigzag-isnan
# DEBUG:Divergences:row [717]: error-zigzag-isnan
# DEBUG:Divergences:row [718]: error-zigzag-isnan
# DEBUG:Divergences:row [719]: error-zigzag-isnan
# DEBUG:Divergences:row [720]: error-zigzag-isnan
# DEBUG:Divergences:row [721]: error-zigzag-isnan
# DEBUG:Divergences:row [722]: error-zigzag-isnan
# DEBUG:Divergences:row [723]: error-zigzag-isnan
# DEBUG:Divergences:row [724]: error-zigzag-isnan
# DEBUG:Divergences:row [725]: error-zigzag-isnan
# DEBUG:Divergences:row [726]: error-zigzag-isnan
# DEBUG:Divergences:row [727]: error-zigzag-isnan
# DEBUG:Divergences:row [728]: error-zigzag-isnan
# DEBUG:Divergences:row [729]: error-zigzag-isnan
# DEBUG:Divergences:row [730]: error-zigzag-isnan
# DEBUG:Divergences:row [731]: error-zigzag-isnan
# DEBUG:Divergences:row [732]: error-zigzag-isnan
# DEBUG:Divergences:row [733]: error-zigzag-isnan
# DEBUG:Divergences:row [734]: error-zigzag-isnan
# DEBUG:Divergences:row [735]: error-zigzag-isnan
# DEBUG:Divergences:row [736]: error-zigzag-isnan
# DEBUG:Divergences:row [737]: error-zigzag-isnan
# DEBUG:Divergences:row [738]: error-zigzag-isnan
# DEBUG:Divergences:row [739]: error-zigzag-isnan
# DEBUG:Divergences:row [740]: error-zigzag-isnan
# DEBUG:Divergences:row [741]: error-zigzag-isnan
# DEBUG:Divergences:row [742]: error-zigzag-isnan
# DEBUG:Divergences:row [743]: error-zigzag-isnan
# DEBUG:Divergences:row [744]: error-zigzag-isnan
# DEBUG:Divergences:row [745]: error-zigzag-isnan
# DEBUG:Divergences:row [746]: error-zigzag-isnan
# DEBUG:Divergences:row [747]: error-zigzag-isnan
# DEBUG:Divergences:row [748]: error-zigzag-isnan
# DEBUG:Divergences:row [749]: error-zigzag-isnan
# DEBUG:Divergences:row [750]: error-zigzag-isnan
# DEBUG:Divergences:row [751]: error-zigzag-isnan
# DEBUG:Divergences:row [752]: error-zigzag-isnan
# DEBUG:Divergences:row [753]: zzpoints=605    1.13191
# 622    1.14478
# 652    1.13335
# 657    1.14500
# 696    1.12788
# 753    1.13885
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [754]: error-zigzag-isnan
# DEBUG:Divergences:row [755]: error-zigzag-isnan
# DEBUG:Divergences:row [756]: error-zigzag-isnan
# DEBUG:Divergences:row [757]: error-zigzag-isnan
# DEBUG:Divergences:row [758]: error-zigzag-isnan
# DEBUG:Divergences:row [759]: error-zigzag-isnan
# DEBUG:Divergences:row [760]: error-zigzag-isnan
# DEBUG:Divergences:row [761]: error-zigzag-isnan
# DEBUG:Divergences:row [762]: error-zigzag-isnan
# DEBUG:Divergences:row [763]: error-zigzag-isnan
# DEBUG:Divergences:row [764]: error-zigzag-isnan
# DEBUG:Divergences:row [765]: error-zigzag-isnan
# DEBUG:Divergences:row [766]: error-zigzag-isnan
# DEBUG:Divergences:row [767]: error-zigzag-isnan
# DEBUG:Divergences:row [768]: error-zigzag-isnan
# DEBUG:Divergences:row [769]: error-zigzag-isnan
# DEBUG:Divergences:row [770]: error-zigzag-isnan
# DEBUG:Divergences:row [771]: error-zigzag-isnan
# DEBUG:Divergences:row [772]: error-zigzag-isnan
# DEBUG:Divergences:row [773]: error-zigzag-isnan
# DEBUG:Divergences:row [774]: error-zigzag-isnan
# DEBUG:Divergences:row [775]: error-zigzag-isnan
# DEBUG:Divergences:row [776]: error-zigzag-isnan
# DEBUG:Divergences:row [777]: zzpoints=622    1.14478
# 652    1.13335
# 657    1.14500
# 696    1.12788
# 753    1.13885
# 777    1.11835
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [778]: error-zigzag-isnan
# DEBUG:Divergences:row [779]: error-zigzag-isnan
# DEBUG:Divergences:row [780]: error-zigzag-isnan
# DEBUG:Divergences:row [781]: error-zigzag-isnan
# DEBUG:Divergences:row [782]: error-zigzag-isnan
# DEBUG:Divergences:row [783]: error-zigzag-isnan
# DEBUG:Divergences:row [784]: error-zigzag-isnan
# DEBUG:Divergences:row [785]: error-zigzag-isnan
# DEBUG:Divergences:row [786]: error-zigzag-isnan
# DEBUG:Divergences:row [787]: error-zigzag-isnan
# DEBUG:Divergences:row [788]: error-zigzag-isnan
# DEBUG:Divergences:row [789]: zzpoints=652    1.13335
# 657    1.14500
# 696    1.12788
# 753    1.13885
# 777    1.11835
# 789    1.13791
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [790]: error-zigzag-isnan
# DEBUG:Divergences:row [791]: error-zigzag-isnan
# DEBUG:Divergences:row [792]: error-zigzag-isnan
# DEBUG:Divergences:row [793]: error-zigzag-isnan
# DEBUG:Divergences:row [794]: error-zigzag-isnan
# DEBUG:Divergences:row [795]: error-zigzag-isnan
# DEBUG:Divergences:row [796]: error-zigzag-isnan
# DEBUG:Divergences:row [797]: error-zigzag-isnan
# DEBUG:Divergences:row [798]: error-zigzag-isnan
# DEBUG:Divergences:row [799]: error-zigzag-isnan
# DEBUG:Divergences:row [800]: error-zigzag-isnan
# DEBUG:Divergences:row [801]: zzpoints=657    1.14500
# 696    1.12788
# 753    1.13885
# 777    1.11835
# 789    1.13791
# 801    1.11762
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [802]: error-zigzag-isnan
# DEBUG:Divergences:row [803]: error-zigzag-isnan
# DEBUG:Divergences:row [804]: error-zigzag-isnan
# DEBUG:Divergences:row [805]: error-zigzag-isnan
# DEBUG:Divergences:row [806]: error-zigzag-isnan
# DEBUG:Divergences:row [807]: error-zigzag-isnan
# DEBUG:Divergences:row [808]: error-zigzag-isnan
# DEBUG:Divergences:row [809]: error-zigzag-isnan
# DEBUG:Divergences:row [810]: error-zigzag-isnan
# DEBUG:Divergences:row [811]: error-zigzag-isnan
# DEBUG:Divergences:row [812]: error-zigzag-isnan
# DEBUG:Divergences:row [813]: error-zigzag-isnan
# DEBUG:Divergences:row [814]: error-zigzag-isnan
# DEBUG:Divergences:row [815]: error-zigzag-isnan
# DEBUG:Divergences:row [816]: zzpoints=696    1.12788
# 753    1.13885
# 777    1.11835
# 789    1.13791
# 801    1.11762
# 816    1.12446
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [817]: error-zigzag-isnan
# DEBUG:Divergences:row [818]: error-zigzag-isnan
# DEBUG:Divergences:row [819]: error-zigzag-isnan
# DEBUG:Divergences:row [820]: error-zigzag-isnan
# DEBUG:Divergences:row [821]: error-zigzag-isnan
# DEBUG:Divergences:row [822]: error-zigzag-isnan
# DEBUG:Divergences:row [823]: error-zigzag-isnan
# DEBUG:Divergences:row [824]: error-zigzag-isnan
# DEBUG:Divergences:row [825]: error-zigzag-isnan
# DEBUG:Divergences:row [826]: zzpoints=753    1.13885
# 777    1.11835
# 789    1.13791
# 801    1.11762
# 816    1.12446
# 826    1.11597
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [827]: error-zigzag-isnan
# DEBUG:Divergences:row [828]: error-zigzag-isnan
# DEBUG:Divergences:row [829]: error-zigzag-isnan
# DEBUG:Divergences:row [830]: error-zigzag-isnan
# DEBUG:Divergences:row [831]: error-zigzag-isnan
# DEBUG:Divergences:row [832]: error-zigzag-isnan
# DEBUG:Divergences:row [833]: error-zigzag-isnan
# DEBUG:Divergences:row [834]: error-zigzag-isnan
# DEBUG:Divergences:row [835]: error-zigzag-isnan
# DEBUG:Divergences:row [836]: error-zigzag-isnan
# DEBUG:Divergences:row [837]: error-zigzag-isnan
# DEBUG:Divergences:row [838]: error-zigzag-isnan
# DEBUG:Divergences:row [839]: zzpoints=777    1.11835
# 789    1.13791
# 801    1.11762
# 816    1.12446
# 826    1.11597
# 839    1.12402
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [840]: error-zigzag-isnan
# DEBUG:Divergences:row [841]: error-zigzag-isnan
# DEBUG:Divergences:row [842]: error-zigzag-isnan
# DEBUG:Divergences:row [843]: error-zigzag-isnan
# DEBUG:Divergences:row [844]: error-zigzag-isnan
# DEBUG:Divergences:row [845]: error-zigzag-isnan
# DEBUG:Divergences:row [846]: error-zigzag-isnan
# DEBUG:Divergences:row [847]: error-zigzag-isnan
# DEBUG:Divergences:row [848]: error-zigzag-isnan
# DEBUG:Divergences:row [849]: error-zigzag-isnan
# DEBUG:Divergences:row [850]: error-zigzag-isnan
# DEBUG:Divergences:row [851]: error-zigzag-isnan
# DEBUG:Divergences:row [852]: error-zigzag-isnan
# DEBUG:Divergences:row [853]: error-zigzag-isnan
# DEBUG:Divergences:row [854]: error-zigzag-isnan
# DEBUG:Divergences:row [855]: error-zigzag-isnan
# DEBUG:Divergences:row [856]: error-zigzag-isnan
# DEBUG:Divergences:row [857]: error-zigzag-isnan
# DEBUG:Divergences:row [858]: error-zigzag-isnan
# DEBUG:Divergences:row [859]: error-zigzag-isnan
# DEBUG:Divergences:row [860]: error-zigzag-isnan
# DEBUG:Divergences:row [861]: error-zigzag-isnan
# DEBUG:Divergences:row [862]: error-zigzag-isnan
# DEBUG:Divergences:row [863]: error-zigzag-isnan
# DEBUG:Divergences:row [864]: error-zigzag-isnan
# DEBUG:Divergences:row [865]: error-zigzag-isnan
# DEBUG:Divergences:row [866]: error-zigzag-isnan
# DEBUG:Divergences:row [867]: error-zigzag-isnan
# DEBUG:Divergences:row [868]: error-zigzag-isnan
# DEBUG:Divergences:row [869]: error-zigzag-isnan
# DEBUG:Divergences:row [870]: error-zigzag-isnan
# DEBUG:Divergences:row [871]: error-zigzag-isnan
# DEBUG:Divergences:row [872]: error-zigzag-isnan
# DEBUG:Divergences:row [873]: error-zigzag-isnan
# DEBUG:Divergences:row [874]: error-zigzag-isnan
# DEBUG:Divergences:row [875]: error-zigzag-isnan
# DEBUG:Divergences:row [876]: error-zigzag-isnan
# DEBUG:Divergences:row [877]: error-zigzag-isnan
# DEBUG:Divergences:row [878]: error-zigzag-isnan
# DEBUG:Divergences:row [879]: error-zigzag-isnan
# DEBUG:Divergences:row [880]: error-zigzag-isnan
# DEBUG:Divergences:row [881]: error-zigzag-isnan
# DEBUG:Divergences:row [882]: error-zigzag-isnan
# DEBUG:Divergences:row [883]: error-zigzag-isnan
# DEBUG:Divergences:row [884]: error-zigzag-isnan
# DEBUG:Divergences:row [885]: error-zigzag-isnan
# DEBUG:Divergences:row [886]: error-zigzag-isnan
# DEBUG:Divergences:row [887]: error-zigzag-isnan
# DEBUG:Divergences:row [888]: error-zigzag-isnan
# DEBUG:Divergences:row [889]: error-zigzag-isnan
# DEBUG:Divergences:row [890]: error-zigzag-isnan
# DEBUG:Divergences:row [891]: error-zigzag-isnan
# DEBUG:Divergences:row [892]: error-zigzag-isnan
# DEBUG:Divergences:row [893]: error-zigzag-isnan
# DEBUG:Divergences:row [894]: error-zigzag-isnan
# DEBUG:Divergences:row [895]: error-zigzag-isnan
# DEBUG:Divergences:row [896]: error-zigzag-isnan
# DEBUG:Divergences:row [897]: zzpoints=789    1.13791
# 801    1.11762
# 816    1.12446
# 826    1.11597
# 839    1.12402
# 897    1.09874
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [898]: error-zigzag-isnan
# DEBUG:Divergences:row [899]: error-zigzag-isnan
# DEBUG:Divergences:row [900]: error-zigzag-isnan
# DEBUG:Divergences:row [901]: error-zigzag-isnan
# DEBUG:Divergences:row [902]: error-zigzag-isnan
# DEBUG:Divergences:row [903]: error-zigzag-isnan
# DEBUG:Divergences:row [904]: error-zigzag-isnan
# DEBUG:Divergences:row [905]: error-zigzag-isnan
# DEBUG:Divergences:row [906]: error-zigzag-isnan
# DEBUG:Divergences:row [907]: error-zigzag-isnan
# DEBUG:Divergences:row [908]: error-zigzag-isnan
# DEBUG:Divergences:row [909]: error-zigzag-isnan
# DEBUG:Divergences:row [910]: error-zigzag-isnan
# DEBUG:Divergences:row [911]: error-zigzag-isnan
# DEBUG:Divergences:row [912]: zzpoints=801    1.11762
# 816    1.12446
# 826    1.11597
# 839    1.12402
# 897    1.09874
# 912    1.11118
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [913]: error-zigzag-isnan
# DEBUG:Divergences:row [914]: error-zigzag-isnan
# DEBUG:Divergences:row [915]: error-zigzag-isnan
# DEBUG:Divergences:row [916]: error-zigzag-isnan
# DEBUG:Divergences:row [917]: error-zigzag-isnan
# DEBUG:Divergences:row [918]: error-zigzag-isnan
# DEBUG:Divergences:row [919]: error-zigzag-isnan
# DEBUG:Divergences:row [920]: error-zigzag-isnan
# DEBUG:Divergences:row [921]: error-zigzag-isnan
# DEBUG:Divergences:row [922]: error-zigzag-isnan
# DEBUG:Divergences:row [923]: error-zigzag-isnan
# DEBUG:Divergences:row [924]: error-zigzag-isnan
# DEBUG:Divergences:row [925]: error-zigzag-isnan
# DEBUG:Divergences:row [926]: error-zigzag-isnan
# DEBUG:Divergences:row [927]: error-zigzag-isnan
# ...
# DEBUG:Divergences:row [26387]: error-zigzag-isnan
# DEBUG:Divergences:row [26388]: error-zigzag-isnan
# DEBUG:Divergences:row [26389]: error-zigzag-isnan
# DEBUG:Divergences:row [26390]: error-zigzag-isnan
# DEBUG:Divergences:row [26391]: error-zigzag-isnan
# DEBUG:Divergences:row [26392]: error-zigzag-isnan
# DEBUG:Divergences:row [26393]: error-zigzag-isnan
# DEBUG:Divergences:row [26394]: error-zigzag-isnan
# DEBUG:Divergences:row [26395]: error-zigzag-isnan
# DEBUG:Divergences:row [26396]: error-zigzag-isnan
# DEBUG:Divergences:row [26397]: error-zigzag-isnan
# DEBUG:Divergences:row [26398]: error-zigzag-isnan
# DEBUG:Divergences:row [26399]: error-zigzag-isnan
# DEBUG:Divergences:row [26400]: error-zigzag-isnan
# DEBUG:Divergences:row [26401]: error-zigzag-isnan
# DEBUG:Divergences:row [26402]: error-zigzag-isnan
# DEBUG:Divergences:row [26403]: error-zigzag-isnan
# DEBUG:Divergences:row [26404]: error-zigzag-isnan
# DEBUG:Divergences:row [26405]: error-zigzag-isnan
# DEBUG:Divergences:row [26406]: error-zigzag-isnan
# DEBUG:Divergences:row [26407]: error-zigzag-isnan
# DEBUG:Divergences:row [26408]: error-zigzag-isnan
# DEBUG:Divergences:row [26409]: error-zigzag-isnan
# DEBUG:Divergences:row [26410]: error-zigzag-isnan
# DEBUG:Divergences:row [26411]: error-zigzag-isnan
# DEBUG:Divergences:row [26412]: error-zigzag-isnan
# DEBUG:Divergences:row [26413]: error-zigzag-isnan
# DEBUG:Divergences:row [26414]: error-zigzag-isnan
# DEBUG:Divergences:row [26415]: error-zigzag-isnan
# DEBUG:Divergences:row [26416]: error-zigzag-isnan
# DEBUG:Divergences:row [26417]: error-zigzag-isnan
# DEBUG:Divergences:row [26418]: error-zigzag-isnan
# DEBUG:Divergences:row [26419]: error-zigzag-isnan
# DEBUG:Divergences:row [26420]: error-zigzag-isnan
# DEBUG:Divergences:row [26421]: error-zigzag-isnan
# DEBUG:Divergences:row [26422]: error-zigzag-isnan
# DEBUG:Divergences:row [26423]: error-zigzag-isnan
# DEBUG:Divergences:row [26424]: error-zigzag-isnan
# DEBUG:Divergences:row [26425]: error-zigzag-isnan
# DEBUG:Divergences:row [26426]: error-zigzag-isnan
# DEBUG:Divergences:row [26427]: error-zigzag-isnan
# DEBUG:Divergences:row [26428]: error-zigzag-isnan
# DEBUG:Divergences:row [26429]: error-zigzag-isnan
# DEBUG:Divergences:row [26430]: error-zigzag-isnan
# DEBUG:Divergences:row [26431]: error-zigzag-isnan
# DEBUG:Divergences:row [26432]: zzpoints=26288    1.12060
# 26311    1.12484
# 26314    1.12100
# 26383    1.12882
# 26384    1.12295
# 26432    1.13239
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [26433]: error-zigzag-isnan
# DEBUG:Divergences:row [26434]: error-zigzag-isnan
# DEBUG:Divergences:row [26435]: error-zigzag-isnan
# DEBUG:Divergences:row [26436]: error-zigzag-isnan
# DEBUG:Divergences:row [26437]: error-zigzag-isnan
# DEBUG:Divergences:row [26438]: error-zigzag-isnan
# DEBUG:Divergences:row [26439]: error-zigzag-isnan
# DEBUG:Divergences:row [26440]: error-zigzag-isnan
# DEBUG:Divergences:row [26441]: error-zigzag-isnan
# DEBUG:Divergences:row [26442]: error-zigzag-isnan
# DEBUG:Divergences:row [26443]: error-zigzag-isnan
# DEBUG:Divergences:row [26444]: error-zigzag-isnan
# DEBUG:Divergences:row [26445]: error-zigzag-isnan
# DEBUG:Divergences:row [26446]: error-zigzag-isnan
# DEBUG:Divergences:row [26447]: error-zigzag-isnan
# DEBUG:Divergences:row [26448]: error-zigzag-isnan
# DEBUG:Divergences:row [26449]: error-zigzag-isnan
# DEBUG:Divergences:row [26450]: error-zigzag-isnan
# DEBUG:Divergences:row [26451]: error-zigzag-isnan
# DEBUG:Divergences:row [26452]: error-zigzag-isnan
# DEBUG:Divergences:row [26453]: error-zigzag-isnan
# DEBUG:Divergences:row [26454]: error-zigzag-isnan
# DEBUG:Divergences:row [26455]: error-zigzag-isnan
# DEBUG:Divergences:row [26456]: error-zigzag-isnan
# DEBUG:Divergences:row [26457]: error-zigzag-isnan
# DEBUG:Divergences:row [26458]: error-zigzag-isnan
# DEBUG:Divergences:row [26459]: error-zigzag-isnan
# DEBUG:Divergences:row [26460]: error-zigzag-isnan
# DEBUG:Divergences:row [26461]: error-zigzag-isnan
# DEBUG:Divergences:row [26462]: error-zigzag-isnan
# DEBUG:Divergences:row [26463]: error-zigzag-isnan
# DEBUG:Divergences:row [26464]: error-zigzag-isnan
# DEBUG:Divergences:row [26465]: error-zigzag-isnan
# DEBUG:Divergences:row [26466]: error-zigzag-isnan
# DEBUG:Divergences:row [26467]: error-zigzag-isnan
# DEBUG:Divergences:row [26468]: error-zigzag-isnan
# DEBUG:Divergences:row [26469]: error-zigzag-isnan
# DEBUG:Divergences:row [26470]: error-zigzag-isnan
# DEBUG:Divergences:row [26471]: error-zigzag-isnan
# DEBUG:Divergences:row [26472]: error-zigzag-isnan
# DEBUG:Divergences:row [26473]: error-zigzag-isnan
# DEBUG:Divergences:row [26474]: error-zigzag-isnan
# DEBUG:Divergences:row [26475]: error-zigzag-isnan
# DEBUG:Divergences:row [26476]: error-zigzag-isnan
# DEBUG:Divergences:row [26477]: error-zigzag-isnan
# DEBUG:Divergences:row [26478]: error-zigzag-isnan
# DEBUG:Divergences:row [26479]: error-zigzag-isnan
# DEBUG:Divergences:row [26480]: error-zigzag-isnan
# DEBUG:Divergences:row [26481]: error-zigzag-isnan
# DEBUG:Divergences:row [26482]: error-zigzag-isnan
# DEBUG:Divergences:row [26483]: error-zigzag-isnan
# DEBUG:Divergences:row [26484]: error-zigzag-isnan
# DEBUG:Divergences:row [26485]: error-zigzag-isnan
# DEBUG:Divergences:row [26486]: error-zigzag-isnan
# DEBUG:Divergences:row [26487]: error-zigzag-isnan
# DEBUG:Divergences:row [26488]: error-zigzag-isnan
# DEBUG:Divergences:row [26489]: zzpoints=26311    1.12484
# 26314    1.12100
# 26383    1.12882
# 26384    1.12295
# 26432    1.13239
# 26489    1.12786
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [26490]: error-zigzag-isnan
# DEBUG:Divergences:row [26491]: error-zigzag-isnan
# DEBUG:Divergences:row [26492]: error-zigzag-isnan
# DEBUG:Divergences:row [26493]: error-zigzag-isnan
# DEBUG:Divergences:row [26494]: error-zigzag-isnan
# DEBUG:Divergences:row [26495]: error-zigzag-isnan
# DEBUG:Divergences:row [26496]: error-zigzag-isnan
# DEBUG:Divergences:row [26497]: error-zigzag-isnan
# DEBUG:Divergences:row [26498]: zzpoints=26314    1.12100
# 26383    1.12882
# 26384    1.12295
# 26432    1.13239
# 26489    1.12786
# 26498    1.13237
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [26499]: error-zigzag-isnan
# DEBUG:Divergences:row [26500]: error-zigzag-isnan
# DEBUG:Divergences:row [26501]: error-zigzag-isnan
# DEBUG:Divergences:row [26502]: error-zigzag-isnan
# DEBUG:Divergences:row [26503]: error-zigzag-isnan
# DEBUG:Divergences:row [26504]: error-zigzag-isnan
# DEBUG:Divergences:row [26505]: error-zigzag-isnan
# DEBUG:Divergences:row [26506]: error-zigzag-isnan
# DEBUG:Divergences:row [26507]: error-zigzag-isnan
# DEBUG:Divergences:row [26508]: error-zigzag-isnan
# DEBUG:Divergences:row [26509]: error-zigzag-isnan
# DEBUG:Divergences:row [26510]: error-zigzag-isnan
# DEBUG:Divergences:row [26511]: error-zigzag-isnan
# DEBUG:Divergences:row [26512]: error-zigzag-isnan
# DEBUG:Divergences:row [26513]: error-zigzag-isnan
# DEBUG:Divergences:row [26514]: error-zigzag-isnan
# DEBUG:Divergences:row [26515]: error-zigzag-isnan
# DEBUG:Divergences:row [26516]: error-zigzag-isnan
# DEBUG:Divergences:row [26517]: error-zigzag-isnan
# DEBUG:Divergences:row [26518]: error-zigzag-isnan
# DEBUG:Divergences:row [26519]: error-zigzag-isnan
# DEBUG:Divergences:row [26520]: error-zigzag-isnan
# DEBUG:Divergences:row [26521]: error-zigzag-isnan
# DEBUG:Divergences:row [26522]: error-zigzag-isnan
# DEBUG:Divergences:row [26523]: error-zigzag-isnan
# DEBUG:Divergences:row [26524]: error-zigzag-isnan
# DEBUG:Divergences:row [26525]: error-zigzag-isnan
# DEBUG:Divergences:row [26526]: error-zigzag-isnan
# DEBUG:Divergences:row [26527]: error-zigzag-isnan
# DEBUG:Divergences:row [26528]: error-zigzag-isnan
# DEBUG:Divergences:row [26529]: error-zigzag-isnan
# DEBUG:Divergences:row [26530]: error-zigzag-isnan
# DEBUG:Divergences:row [26531]: error-zigzag-isnan
# DEBUG:Divergences:row [26532]: zzpoints=26383    1.12882
# 26384    1.12295
# 26432    1.13239
# 26489    1.12786
# 26498    1.13237
# 26532    1.12261
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [26533]: error-zigzag-isnan
# DEBUG:Divergences:row [26534]: error-zigzag-isnan
# DEBUG:Divergences:row [26535]: error-zigzag-isnan
# DEBUG:Divergences:row [26536]: error-zigzag-isnan
# DEBUG:Divergences:row [26537]: error-zigzag-isnan
# DEBUG:Divergences:row [26538]: error-zigzag-isnan
# DEBUG:Divergences:row [26539]: error-zigzag-isnan
# DEBUG:Divergences:row [26540]: error-zigzag-isnan
# DEBUG:Divergences:row [26541]: error-zigzag-isnan
# DEBUG:Divergences:row [26542]: error-zigzag-isnan
# DEBUG:Divergences:row [26543]: error-zigzag-isnan
# DEBUG:Divergences:row [26544]: error-zigzag-isnan
# DEBUG:Divergences:row [26545]: error-zigzag-isnan
# DEBUG:Divergences:row [26546]: error-zigzag-isnan
# DEBUG:Divergences:row [26547]: error-zigzag-isnan
# DEBUG:Divergences:row [26548]: error-zigzag-isnan
# DEBUG:Divergences:row [26549]: error-zigzag-isnan
# DEBUG:Divergences:row [26550]: error-zigzag-isnan
# DEBUG:Divergences:row [26551]: error-zigzag-isnan
# DEBUG:Divergences:row [26552]: error-zigzag-isnan
# DEBUG:Divergences:row [26553]: error-zigzag-isnan
# DEBUG:Divergences:row [26554]: error-zigzag-isnan
# DEBUG:Divergences:row [26555]: error-zigzag-isnan
# DEBUG:Divergences:row [26556]: error-zigzag-isnan
# DEBUG:Divergences:row [26557]: error-zigzag-isnan
# DEBUG:Divergences:row [26558]: error-zigzag-isnan
# DEBUG:Divergences:row [26559]: error-zigzag-isnan
# DEBUG:Divergences:row [26560]: error-zigzag-isnan
# DEBUG:Divergences:row [26561]: error-zigzag-isnan
# DEBUG:Divergences:row [26562]: error-zigzag-isnan
# DEBUG:Divergences:row [26563]: error-zigzag-isnan
# DEBUG:Divergences:row [26564]: error-zigzag-isnan
# DEBUG:Divergences:row [26565]: error-zigzag-isnan
# DEBUG:Divergences:row [26566]: error-zigzag-isnan
# DEBUG:Divergences:row [26567]: error-zigzag-isnan
# DEBUG:Divergences:row [26568]: error-zigzag-isnan
# DEBUG:Divergences:row [26569]: error-zigzag-isnan
# DEBUG:Divergences:row [26570]: error-zigzag-isnan
# DEBUG:Divergences:row [26571]: error-zigzag-isnan
# DEBUG:Divergences:row [26572]: error-zigzag-isnan
# DEBUG:Divergences:row [26573]: error-zigzag-isnan
# DEBUG:Divergences:row [26574]: error-zigzag-isnan
# DEBUG:Divergences:row [26575]: error-zigzag-isnan
# DEBUG:Divergences:row [26576]: error-zigzag-isnan
# DEBUG:Divergences:row [26577]: error-zigzag-isnan
# DEBUG:Divergences:row [26578]: zzpoints=26384    1.12295
# 26432    1.13239
# 26489    1.12786
# 26498    1.13237
# 26532    1.12261
# 26578    1.12619
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [26579]: error-zigzag-isnan
# DEBUG:Divergences:row [26580]: error-zigzag-isnan
# DEBUG:Divergences:row [26581]: error-zigzag-isnan
# DEBUG:Divergences:row [26582]: error-zigzag-isnan
# DEBUG:Divergences:row [26583]: error-zigzag-isnan
# DEBUG:Divergences:row [26584]: error-zigzag-isnan
# DEBUG:Divergences:row [26585]: error-zigzag-isnan
# DEBUG:Divergences:row [26586]: error-zigzag-isnan
# DEBUG:Divergences:row [26587]: error-zigzag-isnan
# DEBUG:Divergences:row [26588]: error-zigzag-isnan
# DEBUG:Divergences:row [26589]: error-zigzag-isnan
# DEBUG:Divergences:row [26590]: error-zigzag-isnan
# DEBUG:Divergences:row [26591]: error-zigzag-isnan
# DEBUG:Divergences:row [26592]: error-zigzag-isnan
# DEBUG:Divergences:row [26593]: error-zigzag-isnan
# DEBUG:Divergences:row [26594]: error-zigzag-isnan
# DEBUG:Divergences:row [26595]: error-zigzag-isnan
# DEBUG:Divergences:row [26596]: error-zigzag-isnan
# DEBUG:Divergences:row [26597]: error-zigzag-isnan
# DEBUG:Divergences:row [26598]: error-zigzag-isnan
# DEBUG:Divergences:row [26599]: error-zigzag-isnan
# DEBUG:Divergences:row [26600]: error-zigzag-isnan
# DEBUG:Divergences:row [26601]: error-zigzag-isnan
# DEBUG:Divergences:row [26602]: error-zigzag-isnan
# DEBUG:Divergences:row [26603]: error-zigzag-isnan
# DEBUG:Divergences:row [26604]: error-zigzag-isnan
# DEBUG:Divergences:row [26605]: error-zigzag-isnan
# DEBUG:Divergences:row [26606]: error-zigzag-isnan
# DEBUG:Divergences:row [26607]: error-zigzag-isnan
# DEBUG:Divergences:row [26608]: error-zigzag-isnan
# DEBUG:Divergences:row [26609]: error-zigzag-isnan
# DEBUG:Divergences:row [26610]: error-zigzag-isnan
# DEBUG:Divergences:row [26611]: error-zigzag-isnan
# DEBUG:Divergences:row [26612]: error-zigzag-isnan
# DEBUG:Divergences:row [26613]: error-zigzag-isnan
# DEBUG:Divergences:row [26614]: error-zigzag-isnan
# DEBUG:Divergences:row [26615]: error-zigzag-isnan
# DEBUG:Divergences:row [26616]: error-zigzag-isnan
# DEBUG:Divergences:row [26617]: error-zigzag-isnan
# DEBUG:Divergences:row [26618]: error-zigzag-isnan
# DEBUG:Divergences:row [26619]: error-zigzag-isnan
# DEBUG:Divergences:row [26620]: error-zigzag-isnan
# DEBUG:Divergences:row [26621]: error-zigzag-isnan
# DEBUG:Divergences:row [26622]: error-zigzag-isnan
# DEBUG:Divergences:row [26623]: error-zigzag-isnan
# DEBUG:Divergences:row [26624]: error-zigzag-isnan
# DEBUG:Divergences:row [26625]: error-zigzag-isnan
# DEBUG:Divergences:row [26626]: error-zigzag-isnan
# DEBUG:Divergences:row [26627]: error-zigzag-isnan
# DEBUG:Divergences:row [26628]: error-zigzag-isnan
# DEBUG:Divergences:row [26629]: error-zigzag-isnan
# DEBUG:Divergences:row [26630]: error-zigzag-isnan
# DEBUG:Divergences:row [26631]: error-zigzag-isnan
# DEBUG:Divergences:row [26632]: error-zigzag-isnan
# DEBUG:Divergences:row [26633]: error-zigzag-isnan
# DEBUG:Divergences:row [26634]: error-zigzag-isnan
# DEBUG:Divergences:row [26635]: error-zigzag-isnan
# DEBUG:Divergences:row [26636]: error-zigzag-isnan
# DEBUG:Divergences:row [26637]: error-zigzag-isnan
# DEBUG:Divergences:row [26638]: error-zigzag-isnan
# DEBUG:Divergences:row [26639]: error-zigzag-isnan
# DEBUG:Divergences:row [26640]: error-zigzag-isnan
# DEBUG:Divergences:row [26641]: error-zigzag-isnan
# DEBUG:Divergences:row [26642]: error-zigzag-isnan
# DEBUG:Divergences:row [26643]: error-zigzag-isnan
# DEBUG:Divergences:row [26644]: error-zigzag-isnan
# DEBUG:Divergences:row [26645]: error-zigzag-isnan
# DEBUG:Divergences:row [26646]: error-zigzag-isnan
# DEBUG:Divergences:row [26647]: zzpoints=26432    1.13239
# 26489    1.12786
# 26498    1.13237
# 26532    1.12261
# 26578    1.12619
# 26647    1.11177
# Name: ZIGZAG, dtype: float64
# DEBUG:Divergences:row [26648]: error-zigzag-isnan
# DEBUG:Divergences:row [26649]: error-zigzag-isnan
# DEBUG:Divergences:row [26650]: error-zigzag-isnan
# DEBUG:Divergences:row [26651]: error-zigzag-isnan
# DEBUG:Divergences:row [26652]: error-zigzag-isnan
# DEBUG:Divergences:row [26653]: error-zigzag-isnan
# DEBUG:Divergences:row [26654]: error-zigzag-isnan
# DEBUG:Divergences:row [26655]: error-zigzag-isnan
# DEBUG:Divergences:row [26656]: error-zigzag-isnan
# DEBUG:Divergences:row [26657]: error-zigzag-isnan
# DEBUG:Divergences:row [26658]: error-zigzag-isnan
# DEBUG:Divergences:row [26659]: error-zigzag-isnan
# DEBUG:Divergences:row [26660]: error-zigzag-isnan
# DEBUG:Divergences:row [26661]: error-zigzag-isnan
# DEBUG:Divergences:row [26662]: error-zigzag-isnan
# DEBUG:Divergences:row [26663]: error-zigzag-isnan
# DEBUG:Divergences:row [26664]: error-zigzag-isnan
# DEBUG:Divergences:row [26665]: error-zigzag-isnan
# DEBUG:Divergences:row [26666]: error-zigzag-isnan
# DEBUG:Divergences:row [26667]: error-zigzag-isnan
# DEBUG:Divergences:row [26668]: error-zigzag-isnan
# DEBUG:Divergences:row [26669]: error-zigzag-isnan
# DEBUG:Divergences:row [26670]: error-zigzag-isnan
# DEBUG:Divergences:row [26671]: error-zigzag-isnan
# DEBUG:Divergences:row [26672]: error-zigzag-isnan
# DEBUG:Divergences:row [26673]: error-zigzag-isnan
# DEBUG:Divergences:row [26674]: error-zigzag-isnan
# DEBUG:Divergences:row [26675]: error-zigzag-isnan
# DEBUG:Divergences:row [26676]: error-zigzag-isnan
# DEBUG:Divergences:row [26677]: error-zigzag-isnan
# DEBUG:Divergences:row [26678]: error-zigzag-isnan
# DEBUG:Divergences:row [26679]: error-zigzag-isnan
# DEBUG:Divergences:row [26680]: error-zigzag-isnan
# DEBUG:Divergences:row [26681]: error-zigzag-isnan
# DEBUG:Divergences:row [26682]: error-zigzag-isnan
# DEBUG:Divergences:row [26683]: error-zigzag-isnan
# DEBUG:Divergences:row [26684]: error-zigzag-isnan
# DEBUG:Divergences:row [26685]: error-zigzag-isnan
# DEBUG:Divergences:row [26686]: error-zigzag-isnan
# DEBUG:Divergences:row [26687]: error-zigzag-isnan
# DEBUG:Divergences:row [27112]: zzpoints=26982    1.11779
# 26985    1.12246
# 27049    1.11505
# 27058    1.11747
# 27075    1.11419
# 27112    1.11879
# Name: ZIGZAG, dtype: float64

# %%
_df
# Out:
#                      TIME     OPEN     HIGH      LOW    CLOSE  BOLLINGER_HI  \
# 0     2015-01-12 15:00:00  1.17897  1.18254  1.17886  1.18230      1.188724
# 1     2015-01-12 16:00:00  1.18231  1.18442  1.18096  1.18393      1.188733
# 2     2015-01-12 17:00:00  1.18391  1.18425  1.18158  1.18162      1.188707
# 3     2015-01-12 18:00:00  1.18161  1.18316  1.18084  1.18306      1.188651
# 4     2015-01-12 19:00:00  1.18306  1.18306  1.18166  1.18253      1.188600
# 5     2015-01-12 20:00:00  1.18254  1.18442  1.18247  1.18411      1.188291
# 6     2015-01-12 21:00:00  1.18410  1.18452  1.18369  1.18388      1.187886
# 7     2015-01-12 22:00:00  1.18389  1.18397  1.18325  1.18366      1.187488
# 8     2015-01-12 23:00:00  1.18365  1.18367  1.18319  1.18325      1.187221
# 9     2015-01-13 00:00:00  1.18319  1.18594  1.17534  1.18286      1.187063
# 10    2015-01-13 01:00:00  1.18286  1.18311  1.18259  1.18311      1.186790
# 11    2015-01-13 02:00:00  1.18313  1.18425  1.18225  1.18412      1.186629
# 12    2015-01-13 03:00:00  1.18414  1.18475  1.18348  1.18443      1.186326
# 13    2015-01-13 04:00:00  1.18440  1.18455  1.18376  1.18447      1.186124
# 14    2015-01-13 05:00:00  1.18447  1.18589  1.18443  1.18453      1.185971
# 15    2015-01-13 06:00:00  1.18453  1.18473  1.18319  1.18360      1.186056
# 16    2015-01-13 07:00:00  1.18357  1.18376  1.18230  1.18271      1.186057
# 17    2015-01-13 08:00:00  1.18270  1.18345  1.18190  1.18296      1.185839
# 18    2015-01-13 09:00:00  1.18296  1.18515  1.18284  1.18496      1.185822
# 19    2015-01-13 10:00:00  1.18495  1.18498  1.18167  1.18206      1.185178
# 20    2015-01-13 11:00:00  1.18206  1.18256  1.17936  1.18077      1.185394
# 21    2015-01-13 12:00:00  1.18076  1.18103  1.17892  1.18015      1.185605
# 22    2015-01-13 13:00:00  1.18015  1.18093  1.17859  1.17923      1.185956
# 23    2015-01-13 14:00:00  1.17924  1.17978  1.17752  1.17800      1.186429
# 24    2015-01-13 15:00:00  1.17801  1.17933  1.17665  1.17692      1.186951
# 25    2015-01-13 16:00:00  1.17691  1.17791  1.17556  1.17611      1.187274
# 26    2015-01-13 17:00:00  1.17610  1.17942  1.17529  1.17806      1.187197
# 27    2015-01-13 18:00:00  1.17807  1.17992  1.17717  1.17778      1.187102
# 28    2015-01-13 19:00:00  1.17778  1.17955  1.17729  1.17838      1.186957
# 29    2015-01-13 20:00:00  1.17840  1.17874  1.17650  1.17663      1.186935
# ...                   ...      ...      ...      ...      ...           ...
# 27083 2019-05-21 19:00:00  1.11583  1.11626  1.11577  1.11600      1.117644
# 27084 2019-05-21 20:00:00  1.11600  1.11627  1.11584  1.11601      1.117573
# 27085 2019-05-21 21:00:00  1.11601  1.11602  1.11540  1.11577      1.117462
# 27086 2019-05-21 22:00:00  1.11577  1.11619  1.11572  1.11613      1.117384
# 27087 2019-05-21 23:00:00  1.11613  1.11654  1.11598  1.11599      1.117330
# 27088 2019-05-22 00:00:00  1.11599  1.11640  1.11581  1.11621      1.117268
# 27089 2019-05-22 01:00:00  1.11621  1.11648  1.11621  1.11635      1.117254
# 27090 2019-05-22 02:00:00  1.11634  1.11656  1.11632  1.11642      1.117268
# 27091 2019-05-22 03:00:00  1.11642  1.11660  1.11607  1.11608      1.117274
# 27092 2019-05-22 04:00:00  1.11608  1.11653  1.11608  1.11645      1.117351
# 27093 2019-05-22 05:00:00  1.11645  1.11656  1.11594  1.11603      1.117360
# 27094 2019-05-22 06:00:00  1.11603  1.11631  1.11600  1.11618      1.117393
# 27095 2019-05-22 07:00:00  1.11618  1.11618  1.11533  1.11553      1.117350
# 27096 2019-05-22 08:00:00  1.11553  1.11568  1.11523  1.11523      1.117341
# 27097 2019-05-22 09:00:00  1.11523  1.11583  1.11504  1.11530      1.117271
# 27098 2019-05-22 10:00:00  1.11530  1.11557  1.11486  1.11522      1.117202
# 27099 2019-05-22 11:00:00  1.11522  1.11638  1.11500  1.11594      1.117207
# 27100 2019-05-22 12:00:00  1.11594  1.11726  1.11579  1.11676      1.117254
# 27101 2019-05-22 13:00:00  1.11676  1.11737  1.11670  1.11689      1.116906
# 27102 2019-05-22 14:00:00  1.11689  1.11704  1.11644  1.11664      1.116982
# 27103 2019-05-22 15:00:00  1.11664  1.11804  1.11648  1.11669      1.117056
# 27104 2019-05-22 16:00:00  1.11669  1.11689  1.11574  1.11627      1.117072
# 27105 2019-05-22 17:00:00  1.11627  1.11680  1.11525  1.11537      1.117094
# 27106 2019-05-22 18:00:00  1.11537  1.11604  1.11509  1.11565      1.117087
# 27107 2019-05-22 19:00:00  1.11565  1.11597  1.11534  1.11569      1.117085
# 27108 2019-05-22 20:00:00  1.11569  1.11631  1.11545  1.11610      1.117077
# 27109 2019-05-22 21:00:00  1.11610  1.11636  1.11567  1.11596      1.117048
# 27110 2019-05-22 22:00:00  1.11596  1.11597  1.11529  1.11533      1.117018
# 27111 2019-05-22 23:00:00  1.11533  1.11547  1.11495  1.11495      1.117049
# 27112 2019-05-23 00:00:00  1.11495  1.11536  1.11495  1.11523      1.116996
#
#        BOLLINGER_MA  BOLLINGER_LO  BOLLINGER_WIDTH  BOLLINGER_WIDTH_SMA100  \
# 0          1.183879      1.179033         0.009691                0.007777
# 1          1.183888      1.179042         0.009690                0.007816
# 2          1.183764      1.178820         0.009886                0.007844
# 3          1.183704      1.178757         0.009894                0.007870
# 4          1.183630      1.178659         0.009941                0.007893
# 5          1.183505      1.178718         0.009573                0.007909
# 6          1.183354      1.178821         0.009065                0.007919
# 7          1.183206      1.178923         0.008565                0.007925
# 8          1.183086      1.178951         0.008270                0.007927
# 9          1.182994      1.178925         0.008137                0.007928
# 10         1.182878      1.178965         0.007824                0.007924
# 11         1.182822      1.179015         0.007614                0.007916
# 12         1.182740      1.179153         0.007173                0.007899
# 13         1.182684      1.179244         0.006880                0.007871
# 14         1.182643      1.179314         0.006656                0.007835
# 15         1.182750      1.179443         0.006614                0.007796
# 16         1.182823      1.179588         0.006470                0.007759
# 17         1.182998      1.180157         0.005682                0.007721
# 18         1.183254      1.180685         0.005137                0.007682
# 19         1.183408      1.181637         0.003541                0.007634
# 20         1.183331      1.181268         0.004126                0.007590
# 21         1.183142      1.180679         0.004926                0.007551
# 22         1.183023      1.180089         0.005867                0.007522
# 23         1.182770      1.179110         0.007320                0.007505
# 24         1.182489      1.178027         0.008925                0.007499
# 25         1.182089      1.176904         0.010370                0.007503
# 26         1.181798      1.176399         0.010798                0.007501
# 27         1.181504      1.175906         0.011197                0.007509
# 28         1.181261      1.175564         0.011392                0.007519
# 29         1.180949      1.174963         0.011972                0.007543
# ...             ...           ...              ...                     ...
# 27083      1.115867      1.114089         0.003556                0.003050
# 27084      1.115833      1.114093         0.003480                0.003048
# 27085      1.115781      1.114100         0.003363                0.003044
# 27086      1.115751      1.114118         0.003267                0.003039
# 27087      1.115727      1.114123         0.003207                0.003034
# 27088      1.115705      1.114141         0.003127                0.003028
# 27089      1.115700      1.114145         0.003109                0.003022
# 27090      1.115705      1.114141         0.003127                0.003016
# 27091      1.115708      1.114142         0.003133                0.003010
# 27092      1.115769      1.114186         0.003165                0.003004
# 27093      1.115825      1.114290         0.003069                0.002998
# 27094      1.115856      1.114319         0.003074                0.002992
# 27095      1.115898      1.114445         0.002905                0.002984
# 27096      1.115906      1.114471         0.002869                0.002977
# 27097      1.115943      1.114615         0.002656                0.002967
# 27098      1.115974      1.114745         0.002457                0.002957
# 27099      1.115983      1.114759         0.002449                0.002947
# 27100      1.116071      1.114887         0.002366                0.002936
# 27101      1.116016      1.115126         0.001781                0.002919
# 27102      1.116057      1.115131         0.001852                0.002910
# 27103      1.116091      1.115126         0.001931                0.002905
# 27104      1.116104      1.115136         0.001936                0.002908
# 27105      1.116084      1.115074         0.002020                0.002913
# 27106      1.116060      1.115033         0.002055                0.002918
# 27107      1.116045      1.115005         0.002079                0.002915
# 27108      1.116040      1.115002         0.002075                0.002906
# 27109      1.116020      1.114992         0.002056                0.002889
# 27110      1.115966      1.114913         0.002105                0.002866
# 27111      1.115909      1.114769         0.002279                0.002840
# 27112      1.115848      1.114700         0.002296                0.002809
#
#        BOLLINGER_b   ZIGZAG            ACTION  MACD_main   MACD_signal  \
# 0         0.337117  0.00000               low   0.000054  1.199572e-03
# 1         0.504386  0.00000               low   0.000180  9.956292e-04
# 2         0.283180  0.00000               low   0.000092  8.148851e-04
# 3         0.434908  0.00000               low   0.000137  6.792733e-04
# 4         0.389395  0.00000               low   0.000128  5.690546e-04
# 5         0.563249  0.00000               low   0.000246  5.044406e-04
# 6         0.558082  0.00000               low   0.000317  4.669786e-04
# 7         0.553065  0.00000               low   0.000352  4.439246e-04
# 8         0.519831  0.00000               low   0.000342  4.235566e-04
# 9         0.483532  0.00000               low   0.000300  3.987523e-04
# 10        0.529715  0.00000               low   0.000283  3.755474e-04
# 11        0.670468  0.00000               low   0.000347  3.698194e-04
# 12        0.735689  0.00000               low   0.000418  3.794490e-04
# 13        0.759584  0.00000               low   0.000472  3.979728e-04
# 14        0.783562  0.00000               low   0.000514  4.211506e-04
# 15        0.628599  0.00000               low   0.000467  4.302328e-04
# 16        0.482611  0.00000               low   0.000353  4.148241e-04
# 17        0.493312  0.00000               low   0.000280  3.879159e-04
# 18        0.832209  0.00000               low   0.000380  3.862352e-04
# 19        0.119429  0.00000               low   0.000222  3.533067e-04
# 20       -0.120641  0.00000               low  -0.000008  2.811323e-04
# 21       -0.107415  0.00000               low  -0.000236  1.776104e-04
# 22       -0.146383  0.00000               low  -0.000487  4.478445e-05
# 23       -0.151586  0.00000               low  -0.000775 -1.191718e-04
# 24       -0.124006  0.00000               low  -0.001078 -3.110043e-04
# 25       -0.076560  0.00000               low  -0.001368 -5.224670e-04
# 26        0.153837  0.00000               low  -0.001424 -7.028465e-04
# 27        0.167399  0.00000               low  -0.001474 -8.571531e-04
# 28        0.247153  0.00000               low  -0.001449 -9.755025e-04
# 29        0.139253  0.00000               low  -0.001552 -1.090807e-03
# ...            ...      ...               ...        ...           ...
# 27083     0.537544  0.00000              high  -0.000107 -2.224997e-04
# 27084     0.550856  0.00000              high  -0.000083 -1.946238e-04
# 27085     0.496729  0.00000              high  -0.000082 -1.721646e-04
# 27086     0.616015  0.00000              high  -0.000052 -1.481418e-04
# 27087     0.582171  0.00000              high  -0.000039 -1.262943e-04
# 27088     0.661640  0.00000              high  -0.000011 -1.031576e-04
# 27089     0.709204  0.00000              high   0.000023 -7.795710e-05
# 27090     0.728847  0.00000              high   0.000054 -5.148955e-05
# 27091     0.618751  0.00000              high   0.000051 -3.092247e-05
# 27092     0.715295  0.00000              high   0.000078 -9.158232e-06
# 27093     0.566792  0.00000              high   0.000064  5.535455e-06
# 27094     0.605401  0.00000              high   0.000065  1.740774e-05
# 27095     0.373484  0.00000              high   0.000013  1.647921e-05
# 27096     0.264388  0.00000              high  -0.000052  2.752175e-06
# 27097     0.257908  0.00000              high  -0.000097 -1.716659e-05
# 27098     0.193309  0.00000              high  -0.000137 -4.115926e-05
# 27099     0.482439  0.00000              high  -0.000110 -5.486666e-05
# 27100     0.791398  0.00000              high  -0.000022 -4.820120e-05
# 27101     0.990765  0.00000              high   0.000058 -2.693191e-05
# 27102     0.815099  0.00000              high   0.000100 -1.551422e-06
# 27103     0.810208  0.00000              high   0.000136  2.587666e-05
# 27104     0.585764  0.00000              high   0.000128  4.639048e-05
# 27105     0.146589  0.00000              high   0.000050  4.703049e-05
# 27106     0.300449  0.00000              high   0.000010  3.954048e-05
# 27107     0.329269  0.00000              high  -0.000019  2.789543e-05
# 27108     0.529164  0.00000              high  -0.000008  2.073426e-05
# 27109     0.470811  0.00000              high  -0.000011  1.447802e-05
# 27110     0.198092  0.00000              high  -0.000063 -9.673369e-07
# 27111     0.079217  0.00000              high  -0.000133 -2.742306e-05
# 27112     0.230779  1.11879  high-in-progress  -0.000165 -5.486328e-05
#
#        MACD_hist        RSI    STOCH_K    STOCH_d
# 0      -0.001145  49.154020  38.499994  18.870443
# 1      -0.000816  54.189572  63.925158  36.833869
# 2      -0.000723  47.074415  79.275502  60.566885
# 3      -0.000542  51.361700  73.549488  72.250049
# 4      -0.000441  49.763876  65.005811  72.610267
# 5      -0.000258  54.325593  78.046595  72.200631
# 6      -0.000150  53.563105  79.985557  74.345988
# 7      -0.000092  52.799726  83.526638  80.519597
# 8      -0.000081  51.331463  71.611179  78.374458
# 9      -0.000099  49.909714  67.722746  74.286854
# 10     -0.000093  50.849496  66.613230  68.649051
# 11     -0.000023  54.558777  75.691824  70.009266
# 12      0.000039  55.664729  80.628931  74.311328
# 13      0.000074  55.814164  84.905660  80.408805
# 14      0.000093  56.053442  78.174718  81.236437
# 15      0.000036  51.406621  61.952450  75.010943
# 16     -0.000062  47.360304  37.048629  59.058599
# 17     -0.000108  48.584551  25.024980  41.342020
# 18     -0.000007  57.166963  38.226253  33.433287
# 19     -0.000132  45.346982  38.155014  33.802082
# 20     -0.000289  41.260218  37.416986  37.932751
# 21     -0.000414  39.421355  18.434135  31.335378
# 22     -0.000531  36.800447  17.950536  24.600552
# 23     -0.000656  33.585498  11.977864  16.120845
# 24     -0.000767  31.022758   6.919647  12.282682
# 25     -0.000846  29.221791   7.019230   8.638914
# 26     -0.000722  38.480905  21.245616  11.728164
# 27     -0.000617  37.717904  37.649339  21.971395
# 28     -0.000473  40.443055  56.543945  38.479633
# 29     -0.000461  35.556351  49.820014  48.004433
# ...          ...        ...        ...        ...
# 27083   0.000115  50.428442  49.139510  55.075522
# 27084   0.000112  50.485389  31.454108  43.531550
# 27085   0.000090  49.029631  27.849984  36.147867
# 27086   0.000096  51.298162  24.876565  28.060219
# 27087   0.000087  50.359480  32.616459  28.447669
# 27088   0.000093  51.850514  49.046784  35.513269
# 27089   0.000101  52.821659  68.713450  50.125564
# 27090   0.000106  53.328531  79.239766  65.666667
# 27091   0.000082  50.491033  66.947961  71.633726
# 27092   0.000087  53.397042  66.174402  70.787376
# 27093   0.000059  49.822112  42.942079  58.688147
# 27094   0.000047  51.081756  43.670886  50.929122
# 27095  -0.000004  45.725066  21.916010  36.176325
# 27096  -0.000055  43.459841  17.370556  27.652484
# 27097  -0.000080  44.155029  10.951098  16.745888
# 27098  -0.000096  43.496796  13.977616  14.099757
# 27099  -0.000055  50.630072  37.661827  20.863514
# 27100   0.000027  57.249536  58.348961  36.662802
# 27101   0.000085  58.206258  77.031931  57.680906
# 27102   0.000102  55.628038  76.986498  70.789130
# 27103   0.000110  56.047362  69.128311  74.382247
# 27104   0.000082  51.633330  49.850639  65.321816
# 27105   0.000003  43.692514  27.645553  48.874835
# 27106  -0.000030  46.451699  15.442535  30.979576
# 27107  -0.000047  46.852368  14.541036  19.209708
# 27108  -0.000029  50.907141  31.811048  20.598207
# 27109  -0.000025  49.517912  42.442429  29.598171
# 27110  -0.000062  43.734120  41.961981  38.738486
# 27111  -0.000106  40.649951  23.258277  35.887562
# 27112  -0.000110  43.795167  12.918598  26.046285
#
# [27113 rows x 19 columns]

# %%
nan_value = 0.0
# choose a row with a minimum
row = _df[_df.index==344]
row
# Out:
#                    TIME     OPEN     HIGH     LOW    CLOSE  BOLLINGER_HI  \
# 344 2015-01-30 23:00:00  1.12989  1.12994  1.1277  1.12844      1.135726
#
#      BOLLINGER_MA  BOLLINGER_LO  BOLLINGER_WIDTH  BOLLINGER_WIDTH_SMA100  \
# 344       1.13134      1.126953         0.008772                0.010252
#
#      BOLLINGER_b  ZIGZAG ACTION  MACD_main  MACD_signal  MACD_hist        RSI  \
# 344     0.169468  1.1277    low  -0.000864    -0.000489  -0.000374  41.969449
#
#        STOCH_K    STOCH_d
# 344  34.869811  28.701358

# %%
if row.ZIGZAG == nan_value:
  print('NAN')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-d0b9670fbdae> in <module>
# ----> 1 if row.ZIGZAG == nan_value:
#       2   print('NAN')
#
# ~\Programas\anaconda3\envs\keras\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1574         raise ValueError("The truth value of a {0} is ambiguous. "
#    1575                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1576                          .format(self.__class__.__name__))
#    1577
#    1578     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# skip rows where no zzpoints
else:
  # get last 6 zigzag points
  zzpoints = df.ZIGZAG[(df.index <= row.index) & (df.ZIGZAG != nan_value)]
  # discard if no 6 points
  if zzpoints.shape[0] < 6: return
  # get indexes of 2 last min and max points:
  if zzpoints[-1] > zzpoints[-2]:
    max1_idx = zzpoints[-3].index
    max0_idx = zzpoints[-1].index
    min1_idx = zzpoints[-4].index
    min0_idx = zzpoints[-2].index
  else:
    # get indexes of last 2 min and max points
    max1_idx = zzpoints[-4].index
    max0_idx = zzpoints[-2].index
    min1_idx = zzpoints[-3].index
    min0_idx = zzpoints[-1].index

  # check if is bullish trend
  if ((zzpoints[-1] >= zzpoints[-3] and zzpoints[-3] >= zzpoints[-5]) or (zzpoints[-2] >= zzpoints[-4] and zzpoints[-4] >= zzpoints[-6])):

  # check if is bearish trend
  elif ((zzpoints[-1] <= zzpoints[-3] and zzpoints[-3] <= zzpoints[-5]) or (zzpoints[-2] <= zzpoints[-4] and zzpoints[-4] <= zzpoints[-6])):

  # is an undefined trend, then discard calculation
  else: return 
  #---end-of-search-function

# %% [markdown]
# ## Configurations
#
# ### 1) One indicator per timeframe

# %%
# loads df dataframe at M15, H1 and H4
df_M15 = pd.read_csv('../csv_data/EURUSD_M15.csv', sep=';')
df_M15['TIME'] = df_M15['DATE'] + '  ' + df_M15['TIME'] 
df_M15['TIME'] = df_M15['TIME'].map(lambda x: datetime.datetime.strptime(x, '%Y.%m.%d %H:%M:%S'))  
df_M15['TIME'] = pd.to_datetime(df_M15['TIME'])
df_M15 = df_M15[['TIME', 'OPEN','HIGH','LOW','CLOSE']]

df_H1 = pd.read_csv('../csv_data/EURUSD_H1.csv', sep=';')
df_H1['TIME'] = df_H1['DATE'] + '  ' + df_H1['TIME'] 
df_H1['TIME'] = df_H1['TIME'].map(lambda x: datetime.datetime.strptime(x, '%Y.%m.%d %H:%M:%S'))  
df_H1['TIME'] = pd.to_datetime(df_H1['TIME'])
df_H1 = df_H1[['TIME', 'OPEN','HIGH','LOW','CLOSE']]

df_H4 = pd.read_csv('../csv_data/EURUSD_H4.csv', sep=';')
df_H4['TIME'] = df_H4['DATE'] + '  ' + df_H4['TIME'] 
df_H4['TIME'] = df_H4['TIME'].map(lambda x: datetime.datetime.strptime(x, '%Y.%m.%d %H:%M:%S'))  
df_H4['TIME'] = pd.to_datetime(df_H4['TIME'])
df_H4 = df_H4[['TIME', 'OPEN','HIGH','LOW','CLOSE']]

print('m15_rows={}, h1_rows={}, h4_rows={}'.format(df_M15.shape[0],df_H1.shape[0],df_H4.shape[0]))
# Out:
# m15 rows=109028, h1_rows=27264, h4_rows=6825

# %%
# builds indicators for each timeframe
_df_H4_result, _x, _y, _events = zz.ZIGZAG(df_H4, 
                                  minbars=12, 
                                  bb_period=20, 
                                  bb_dev = 2.0,
                                  bb_sma = [100],
                                  nan_value = 0.0, 
                                  level=logging.WARN)
_df_H1_result, _x, _y, _events = zz.ZIGZAG(df_H1, 
                                  minbars=12, 
                                  bb_period=20, 
                                  bb_dev = 2.0,
                                  bb_sma = [100],
                                  nan_value = 0.0, 
                                  level=logging.WARN)
_df_M15_result, _x, _y, _events = zz.ZIGZAG(df_M15, 
                                  minbars=12, 
                                  bb_period=20, 
                                  bb_dev = 2.0,
                                  bb_sma = [100],
                                  nan_value = 0.0, 
                                  level=logging.WARN)

print('M15 from={} to={}\r\nH1  from={} to={}\r\nH4  from={} to={}'.format(_df_M15_result.TIME.iloc[0], 
                                                                          _df_M15_result.TIME.iloc[-1], 
                                                                          _df_H1_result.TIME.iloc[0], 
                                                                          _df_H1_result.TIME.iloc[-1], 
                                                                          _df_H4_result.TIME.iloc[0], 
                                                                          _df_H4_result.TIME.iloc[-1]))
# Out:
# M15 from=2015-01-05 14:15:00 to=2019-05-23 00:00:00
# H1  from=2015-01-09 06:00:00 to=2019-05-23 00:00:00
# H4  from=2015-01-29 20:00:00 to=2019-05-23 00:00:00

# %%
# setup same starting date
same_time = max(_df_M15_result.TIME.iloc[0], _df_H1_result.TIME.iloc[0], _df_H4_result.TIME.iloc[0])

# filter samples previous same_time and reset index to start from 0
_df_M15_result = _df_M15_result[_df_M15_result.TIME >= same_time].reset_index(drop=True)
_df_H1_result = _df_H1_result[_df_H1_result.TIME >= same_time].reset_index(drop=True)
_df_H4_result = _df_H4_result[_df_H4_result.TIME >= same_time].reset_index(drop=True)

print('M15 from={} to={}\r\nH1  from={} to={}\r\nH4  from={} to={}'.format(_df_M15_result.TIME.iloc[0], 
                                                                          _df_M15_result.TIME.iloc[-1], 
                                                                          _df_H1_result.TIME.iloc[0], 
                                                                          _df_H1_result.TIME.iloc[-1], 
                                                                          _df_H4_result.TIME.iloc[0], 
                                                                          _df_H4_result.TIME.iloc[-1]))
# Out:
# M15 from=2015-01-29 20:00:00 to=2019-05-23 00:00:00
# H1  from=2015-01-29 20:00:00 to=2019-05-23 00:00:00
# H4  from=2015-01-29 20:00:00 to=2019-05-23 00:00:00

# %%
# Plot H4 zigzag indicator
trace_ohlc = go.Ohlc(x=_df_H4_result.index.values, open=_df_H4_result.OPEN, high=_df_H4_result.HIGH, low=_df_H4_result.LOW, close=_df_H4_result.CLOSE, name='Candlestick')

_dfz_h4 = _df_H4_result[_df_H4_result.ZIGZAG > 0].copy()
trace_zigzag = go.Scatter(x=_dfz_h4.reset_index()['index'], y=_dfz_h4.ZIGZAG, name='h4', line=scatter.Line(color='black', width=1))

py.iplot([trace_ohlc, trace_zigzag], filename='simple_ohlc')
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): plot.ly:443
# DEBUG:urllib3.connectionpool:https://plot.ly:443 "POST /clientresp HTTP/1.1" 200 None
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~raulMrello/130.embed" height="525px" width="100%"></iframe>

# %%
# Plot H1 zigzag indicator
trace_ohlc = go.Ohlc(x=_df_H1_result.index.values, open=_df_H1_result.OPEN, high=_df_H1_result.HIGH, low=_df_H1_result.LOW, close=_df_H1_result.CLOSE, name='Candlestick')

_dfz_h1 = _df_H1_result[_df_H1_result.ZIGZAG > 0].copy()
trace_zigzag = go.Scatter(x=_dfz_h1.reset_index()['index'], y=_dfz_h1.ZIGZAG, name='h1', line=scatter.Line(color='black', width=1))

py.iplot([trace_ohlc, trace_zigzag], filename='simple_ohlc')
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): plot.ly:443
# DEBUG:urllib3.connectionpool:https://plot.ly:443 "POST /clientresp HTTP/1.1" 200 None
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~raulMrello/130.embed" height="525px" width="100%"></iframe>

# %%
# Plot M15 zigzag indicator limited to 20k
_df_M15_limit = _df_M15_result[0:20000].copy()
trace_ohlc = go.Ohlc(x=_df_M15_limit.index.values, open=_df_M15_limit.OPEN, high=_df_M15_limit.HIGH, low=_df_M15_limit.LOW, close=_df_M15_limit.CLOSE, name='Candlestick')

_dfz_M15 = _df_M15_limit[_df_M15_limit.ZIGZAG > 0].copy()
trace_zigzag_M15 = go.Scatter(x=_dfz_M15.reset_index()['index'], y=_dfz_M15.ZIGZAG, name='h1', line=scatter.Line(color='black', width=1))

py.iplot([trace_ohlc, trace_zigzag_M15], filename='simple_ohlc')
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): plot.ly:443
# DEBUG:urllib3.connectionpool:https://plot.ly:443 "POST /clientresp HTTP/1.1" 200 None
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~raulMrello/130.embed" height="525px" width="100%"></iframe>

# %%
# plot zigzag at H4 and H1
trace_zigzag_H4 = go.Scatter(x=_dfz_h4.reset_index()['index']*4, y=_dfz_h4.ZIGZAG, name='h4', line=scatter.Line(color='black', width=1))
trace_zigzag_H1 = go.Scatter(x=_dfz_h1.reset_index()['index'], y=_dfz_h1.ZIGZAG, name='h1', line=scatter.Line(color='red', width=1))

py.iplot([trace_zigzag_H4, trace_zigzag_H1], filename='simple_ohlc')
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): plot.ly:443
# DEBUG:urllib3.connectionpool:https://plot.ly:443 "POST /clientresp HTTP/1.1" 200 None
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~raulMrello/130.embed" height="525px" width="100%"></iframe>

# %%
# plot zigzag at H1 and M15 limited to 20k

_df_M15_limit = _df_M15_result[0:20000].copy()
_dfz_M15 = _df_M15_limit[_df_M15_limit.ZIGZAG > 0].copy()
trace_zigzag_M15 = go.Scatter(x=_dfz_M15.reset_index()['index'], y=_dfz_M15.ZIGZAG, name='m15', line=scatter.Line(color='red', width=1))

_df_H1_limit = _df_H1_result[0:5000].copy()
_dfz_H1 = _df_H1_limit[_df_H1_limit.ZIGZAG > 0].copy()
trace_zigzag_H1 = go.Scatter(x=_dfz_H1.reset_index()['index']*4, y=_dfz_H1.ZIGZAG, name='h1', line=scatter.Line(color='black', width=1))

py.iplot([trace_zigzag_H1, trace_zigzag_M15], filename='simple_ohlc')
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): plot.ly:443
# DEBUG:urllib3.connectionpool:https://plot.ly:443 "POST /clientresp HTTP/1.1" 200 None
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~raulMrello/130.embed" height="525px" width="100%"></iframe>

# %%
# plot zigzag at H4 and M15 limited to 20k

_df_M15_limit = _df_M15_result[0:20000].copy()
_dfz_M15 = _df_M15_limit[_df_M15_limit.ZIGZAG > 0].copy()
trace_zigzag_M15 = go.Scatter(x=_dfz_M15.reset_index()['index'], y=_dfz_M15.ZIGZAG, name='m15', line=scatter.Line(color='red', width=1))

_df_H4_limit = _df_H4_result[0:1250].copy()
_dfz_H4 = _df_H4_limit[_df_H4_limit.ZIGZAG > 0].copy()
trace_zigzag_H4 = go.Scatter(x=_dfz_H4.reset_index()['index']*16, y=_dfz_H4.ZIGZAG, name='h4', line=scatter.Line(color='black', width=1))

py.iplot([trace_zigzag_H4, trace_zigzag_M15], filename='simple_ohlc')
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): plot.ly:443
# DEBUG:urllib3.connectionpool:https://plot.ly:443 "POST /clientresp HTTP/1.1" 200 None
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~raulMrello/130.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ### 2) Sinthetic indicators from smaller timeframes
#
# **Build H4 from H1**

# %%
# Build a sinthetic zigzag indicator at H1 for H4
_df_H4S_result, _x, _y, _events = zz.ZIGZAG(df_H1, 
                                  minbars=48, 
                                  bb_period=80, 
                                  bb_dev = 2.0,
                                  bb_sma = [100],
                                  nan_value = 0.0, 
                                  level=logging.WARN)

print('H4S  from={} to={}\r\nH4  from={} to={}'.format(_df_H4S_result.TIME.iloc[0], 
                                                       _df_H4S_result.TIME.iloc[-1], 
                                                       _df_H4_result.TIME.iloc[0], 
                                                       _df_H4_result.TIME.iloc[-1]))
# Out:
# H4S  from=2015-01-13 18:00:00 to=2019-05-23 00:00:00
# H4  from=2015-01-29 20:00:00 to=2019-05-23 00:00:00

# %%
# setup same starting date
same_time = max(_df_H4S_result.TIME.iloc[0], _df_H4_result.TIME.iloc[0])

# filter samples previous same_time and reset index to start from 0
_df_H4S_result = _df_H4S_result[_df_H4S_result.TIME >= same_time].reset_index(drop=True)
_df_H4_result = _df_H4_result[_df_H4_result.TIME >= same_time].reset_index(drop=True)

print('H4S  from={} to={}\r\nH4  from={} to={}'.format(_df_H4S_result.TIME.iloc[0], 
                                                       _df_H4S_result.TIME.iloc[-1], 
                                                       _df_H4_result.TIME.iloc[0], 
                                                       _df_H4_result.TIME.iloc[-1]))
# Out:
# H4S  from=2015-01-29 20:00:00 to=2019-05-23 00:00:00
# H4  from=2015-01-29 20:00:00 to=2019-05-23 00:00:00

# %%
# Plot H4 and H4Sinthetic zigzag indicators

trace_ohlc = go.Ohlc(x=_df_H1_result.index.values, open=_df_H1_result.OPEN, high=_df_H1_result.HIGH, low=_df_H1_result.LOW, close=_df_H1_result.CLOSE, name='Candlestick')

_dfz_h4 = _df_H4_result[_df_H4_result.ZIGZAG > 0].copy()
trace_zigzag_h4 = go.Scatter(x=_dfz_h4.reset_index()['index']*4, y=_dfz_h4.ZIGZAG, name='h4', line=scatter.Line(color='black', width=1))

_dfz_h4s = _df_H4S_result[_df_H4S_result.ZIGZAG > 0].copy()
trace_zigzag_h4s = go.Scatter(x=_dfz_h4s.reset_index()['index'], y=_dfz_h4s.ZIGZAG, name='h4_sinthetic', line=scatter.Line(color='red', width=1))

py.iplot([trace_ohlc, trace_zigzag_h4, trace_zigzag_h4s], filename='simple_ohlc')
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): plot.ly:443
# DEBUG:urllib3.connectionpool:https://plot.ly:443 "POST /clientresp HTTP/1.1" 200 None
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~raulMrello/130.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# **Build H4 from M15**

# %%
# Build a sinthetic zigzag indicator at M15 for H4
_df_H4S_result, _x, _y, _events = zz.ZIGZAG(df_M15, 
                                  minbars=192, 
                                  bb_period=320, 
                                  bb_dev = 2.0,
                                  bb_sma = [100],
                                  nan_value = 0.0, 
                                  level=logging.WARN)

print('H4S  from={} to={}\r\nH4  from={} to={}'.format(_df_H4S_result.TIME.iloc[0], 
                                                       _df_H4S_result.TIME.iloc[-1], 
                                                       _df_H4_result.TIME.iloc[0], 
                                                       _df_H4_result.TIME.iloc[-1]))
# Out:
# H4S  from=2015-01-08 17:15:00 to=2019-05-23 00:00:00
# H4  from=2015-01-29 20:00:00 to=2019-05-23 00:00:00

# %%
# setup same starting date
same_time = max(_df_H4S_result.TIME.iloc[0], _df_H4_result.TIME.iloc[0])

# filter samples previous same_time and reset index to start from 0
_df_H4S_result = _df_H4S_result[_df_H4S_result.TIME >= same_time].reset_index(drop=True)
_df_H4_result = _df_H4_result[_df_H4_result.TIME >= same_time].reset_index(drop=True)

print('H4S  from={} to={}\r\nH4  from={} to={}'.format(_df_H4S_result.TIME.iloc[0], 
                                                       _df_H4S_result.TIME.iloc[-1], 
                                                       _df_H4_result.TIME.iloc[0], 
                                                       _df_H4_result.TIME.iloc[-1]))
# Out:
# H4S  from=2015-01-29 20:00:00 to=2019-05-23 00:00:00
# H4  from=2015-01-29 20:00:00 to=2019-05-23 00:00:00

# %%
# Plot H4 and H4Sinthetic zigzag indicators, as built from M15, limit to 20k samples
_df_M15_limit = _df_M15_result[0:20000].copy()
trace_ohlc = go.Ohlc(x=_df_M15_limit.index.values, open=_df_M15_limit.OPEN, high=_df_M15_limit.HIGH, low=_df_M15_limit.LOW, close=_df_M15_limit.CLOSE, name='Candlestick')

_df_H4_limit = _df_H4_result[0:1250].copy()
_dfz_h4 = _df_H4_limit[_df_H4_limit.ZIGZAG > 0].copy()
trace_zigzag_h4 = go.Scatter(x=_dfz_h4.reset_index()['index']*16, y=_dfz_h4.ZIGZAG, name='h4', line=scatter.Line(color='black', width=1))

_df_H4S_limit = _df_H4S_result[0:20000].copy()
_dfz_h4s = _df_H4S_limit[_df_H4S_limit.ZIGZAG > 0].copy()
trace_zigzag_h4s = go.Scatter(x=_dfz_h4s.reset_index()['index'], y=_dfz_h4s.ZIGZAG, name='h4_sinthetic', line=scatter.Line(color='red', width=1))

py.iplot([trace_ohlc, trace_zigzag_h4, trace_zigzag_h4s], filename='simple_ohlc')
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): plot.ly:443
# DEBUG:urllib3.connectionpool:https://plot.ly:443 "POST /clientresp HTTP/1.1" 200 None
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~raulMrello/130.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # Conclussions
#
# This zigzag indicator, as shown above, is able to build upwards timeframe indicators from a smaller one, just modifying ```minbars``` and ```bb_period ``` parameters accordingly with the timeframe difference. Some examples:
#
# ```
# - From M15 calculate M30 zigzag: minbars = 12*2=24,   bb_period = 20*2 = 40
# - From M15 calculate H2 zigzag:  minbars = 12*8=96,   bb_period = 20*8 = 160
# - From H1  calculate D1 zigzag:  minbars = 12*24=288, bb_period = 20*24 = 480
# ```
