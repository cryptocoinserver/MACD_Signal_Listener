# %% [markdown]
# # Introduction
#
# In this notebook, I study the generation of a ZIGZAG indicator based on BollingerBands indicator

# %%
import sys

####################################################################################
# Data handling 
import pandas as pd
from pandas import concat
from pandas.plotting import scatter_matrix
import numpy as np

####################################################################################
# Visualization
import matplotlib.pyplot as plt
from matplotlib import dates, ticker
from matplotlib.dates import (MONDAY, DateFormatter, MonthLocator, WeekdayLocator, date2num)
import matplotlib as mpl
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.graph_objs import *
from plotly.tools import FigureFactory as FF
import plotly.tools as tls
plotly.offline.init_notebook_mode(connected=True)

####################################################################################
# TA-Lib: 
import talib

####################################################################################
# Other utilities
import datetime
import time
import os
import sys
import math
from enum import Enum
import logging
logging.basicConfig(level=logging.DEBUG, stream=sys.stdout)

print('Packages loaded!!')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# Packages loaded!!
# DEBUG:matplotlib.pyplot:Loaded backend module://ipykernel.pylab.backend_inline version unknown.

# %%
# Append path for MACD_Signal_Listener class (parent folder)
sys.path.append('..')

# import main class and event class
from ZIGZAG_Signal_Listener import ZIGZAG_Signal_Listener

print('Done!')
# Out:
# Done!

# %%
# loads df dataframe
df = pd.read_csv('../csv_data/EURUSD_M15.csv', sep=';')
df = df[['OPEN','HIGH','LOW','CLOSE']]
df.sample(2)
# Out:
#            OPEN     HIGH      LOW    CLOSE
# 32959   0.98720  0.98930  0.97690  0.98730
# 251104  1.41294  1.41446  1.41294  1.41443

# %%
# creates zigzag signal listener
zz = ZIGZAG_Signal_Listener(level=logging.INFO)
zz
# Out:
# INFO:ZIGZAG_Signal_Listener:Created!

# %%
# range for zigzag build
_from_sample = -2000
_num_samples = 1000

# %%
# builds indicator
#executes ZIGZAG indicator
_to_sample = _from_sample + _num_samples - 1
_df_result, _x, _y, _events = zz.ZIGZAG(df[_from_sample:_to_sample], 
                                  minbars=12, 
                                  bb_period=20, 
                                  bb_dev = 2.0,
                                  bb_sma = [20,50,100],
                                  nan_value = 0.0, 
                                  level=logging.DEBUG)
_from_sample += _num_samples/4
_df_result.sample(3)
# Out:
# DEBUG:ZIGZAG_Signal_Listener:New action at idx=0: last_high=1.13598, last_low=1.13553, min-delta=12
# INFO:ZIGZAG_Signal_Listener:Procesing [0]: ERR_DELTA /\ =0 keep_LOW @[0]=>1.13553 remove HIGH @[0]
# DEBUG:ZIGZAG_Signal_Listener:Procesing [1]: new LOW=1.13475
# DEBUG:ZIGZAG_Signal_Listener:Procesing [2]: new LOW=1.1343
# DEBUG:ZIGZAG_Signal_Listener:Procesing [3]: new LOW=1.13341
# DEBUG:ZIGZAG_Signal_Listener:Procesing [4]: curr LOW @[3]=>1.13341
# DEBUG:ZIGZAG_Signal_Listener:Procesing [5]: curr LOW @[3]=>1.13341
# DEBUG:ZIGZAG_Signal_Listener:Procesing [6]: curr LOW @[3]=>1.13341
# DEBUG:ZIGZAG_Signal_Listener:Procesing [7]: curr LOW @[3]=>1.13341
# DEBUG:ZIGZAG_Signal_Listener:Procesing [8]: curr LOW @[3]=>1.13341
# DEBUG:ZIGZAG_Signal_Listener:Procesing [9]: curr LOW @[3]=>1.13341
# DEBUG:ZIGZAG_Signal_Listener:Procesing [10]: curr LOW @[3]=>1.13341
# DEBUG:ZIGZAG_Signal_Listener:Procesing [11]: curr LOW @[3]=>1.13341
# DEBUG:ZIGZAG_Signal_Listener:Procesing [12]: curr LOW @[3]=>1.13341
# DEBUG:ZIGZAG_Signal_Listener:Procesing [13]: curr LOW @[3]=>1.13341
# DEBUG:ZIGZAG_Signal_Listener:Procesing [14]: curr LOW @[3]=>1.13341
# DEBUG:ZIGZAG_Signal_Listener:Procesing [15]: curr LOW @[3]=>1.13341
# DEBUG:ZIGZAG_Signal_Listener:Procesing [16]: new LOW=1.13275
# DEBUG:ZIGZAG_Signal_Listener:Procesing [17]: curr LOW @[16]=>1.13275
# DEBUG:ZIGZAG_Signal_Listener:Procesing [18]: curr LOW @[16]=>1.13275
# DEBUG:ZIGZAG_Signal_Listener:Procesing [19]: curr LOW @[16]=>1.13275
# DEBUG:ZIGZAG_Signal_Listener:Procesing [20]: curr LOW @[16]=>1.13275
# DEBUG:ZIGZAG_Signal_Listener:Procesing [21]: curr LOW @[16]=>1.13275
# DEBUG:ZIGZAG_Signal_Listener:Procesing [22]: curr LOW @[16]=>1.13275
# DEBUG:ZIGZAG_Signal_Listener:Procesing [23]: curr LOW @[16]=>1.13275
# DEBUG:ZIGZAG_Signal_Listener:Procesing [24]: curr LOW @[16]=>1.13275
# DEBUG:ZIGZAG_Signal_Listener:Procesing [25]: curr LOW @[16]=>1.13275
# DEBUG:ZIGZAG_Signal_Listener:Procesing [26]: curr LOW @[16]=>1.13275
# DEBUG:ZIGZAG_Signal_Listener:Procesing [27]: new LOW=1.1325399999999999
# DEBUG:ZIGZAG_Signal_Listener:Procesing [28]: new LOW=1.1322
# DEBUG:ZIGZAG_Signal_Listener:Procesing [29]: new LOW=1.13189
# DEBUG:ZIGZAG_Signal_Listener:Procesing [30]: new LOW=1.13133
# DEBUG:ZIGZAG_Signal_Listener:Procesing [31]: new LOW=1.1309
# DEBUG:ZIGZAG_Signal_Listener:Procesing [32]: curr LOW @[31]=>1.1309
# DEBUG:ZIGZAG_Signal_Listener:Procesing [33]: curr LOW @[31]=>1.1309
# DEBUG:ZIGZAG_Signal_Listener:Procesing [34]: curr LOW @[31]=>1.1309
# DEBUG:ZIGZAG_Signal_Listener:Procesing [35]: curr LOW @[31]=>1.1309
# DEBUG:ZIGZAG_Signal_Listener:Procesing [36]: curr LOW @[31]=>1.1309
# DEBUG:ZIGZAG_Signal_Listener:Procesing [37]: curr LOW @[31]=>1.1309
# DEBUG:ZIGZAG_Signal_Listener:Procesing [38]: curr LOW @[31]=>1.1309
# DEBUG:ZIGZAG_Signal_Listener:Procesing [39]: curr LOW @[31]=>1.1309
# DEBUG:ZIGZAG_Signal_Listener:Procesing [40]: curr LOW @[31]=>1.1309
# DEBUG:ZIGZAG_Signal_Listener:Procesing [41]: curr LOW @[31]=>1.1309
# DEBUG:ZIGZAG_Signal_Listener:Procesing [42]: curr LOW @[31]=>1.1309
# DEBUG:ZIGZAG_Signal_Listener:Procesing [43]: curr LOW @[31]=>1.1309
# DEBUG:ZIGZAG_Signal_Listener:Procesing [44]: curr LOW @[31]=>1.1309
# DEBUG:ZIGZAG_Signal_Listener:Procesing [45]: curr LOW @[31]=>1.1309
# DEBUG:ZIGZAG_Signal_Listener:Procesing [46]: curr LOW @[31]=>1.1309
# DEBUG:ZIGZAG_Signal_Listener:Procesing [47]: curr LOW @[31]=>1.1309
# DEBUG:ZIGZAG_Signal_Listener:Procesing [48]: curr LOW @[31]=>1.1309
# DEBUG:ZIGZAG_Signal_Listener:Procesing [49]: curr LOW @[31]=>1.1309
# DEBUG:ZIGZAG_Signal_Listener:Procesing [50]: curr LOW @[31]=>1.1309
# DEBUG:ZIGZAG_Signal_Listener:Procesing [51]: save LOW @[31]=1.1309, new HIGH=>1.1340299999999999
# DEBUG:ZIGZAG_Signal_Listener:Procesing [52]: new HIGH=1.1342700000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [53]: new HIGH=1.13429
# DEBUG:ZIGZAG_Signal_Listener:Procesing [54]: curr HIGH @[53]=>1.13429
# DEBUG:ZIGZAG_Signal_Listener:Procesing [55]: curr HIGH @[53]=>1.13429
# DEBUG:ZIGZAG_Signal_Listener:Procesing [56]: curr HIGH @[53]=>1.13429
# DEBUG:ZIGZAG_Signal_Listener:Procesing [57]: curr HIGH @[53]=>1.13429
# DEBUG:ZIGZAG_Signal_Listener:Procesing [58]: curr HIGH @[53]=>1.13429
# DEBUG:ZIGZAG_Signal_Listener:Procesing [59]: curr HIGH @[53]=>1.13429
# DEBUG:ZIGZAG_Signal_Listener:Procesing [60]: curr HIGH @[53]=>1.13429
# DEBUG:ZIGZAG_Signal_Listener:Procesing [61]: curr HIGH @[53]=>1.13429
# DEBUG:ZIGZAG_Signal_Listener:Procesing [62]: curr HIGH @[53]=>1.13429
# DEBUG:ZIGZAG_Signal_Listener:Procesing [63]: curr HIGH @[53]=>1.13429
# DEBUG:ZIGZAG_Signal_Listener:Procesing [64]: curr HIGH @[53]=>1.13429
# DEBUG:ZIGZAG_Signal_Listener:Procesing [65]: curr HIGH @[53]=>1.13429
# DEBUG:ZIGZAG_Signal_Listener:Procesing [66]: curr HIGH @[53]=>1.13429
# DEBUG:ZIGZAG_Signal_Listener:Procesing [67]: curr HIGH @[53]=>1.13429
# DEBUG:ZIGZAG_Signal_Listener:Procesing [68]: curr HIGH @[53]=>1.13429
# DEBUG:ZIGZAG_Signal_Listener:Procesing [69]: curr HIGH @[53]=>1.13429
# DEBUG:ZIGZAG_Signal_Listener:Procesing [70]: curr HIGH @[53]=>1.13429
# DEBUG:ZIGZAG_Signal_Listener:Procesing [71]: curr HIGH @[53]=>1.13429
# DEBUG:ZIGZAG_Signal_Listener:Procesing [72]: curr HIGH @[53]=>1.13429
# DEBUG:ZIGZAG_Signal_Listener:Procesing [73]: curr HIGH @[53]=>1.13429
# DEBUG:ZIGZAG_Signal_Listener:Procesing [74]: curr HIGH @[53]=>1.13429
# DEBUG:ZIGZAG_Signal_Listener:Procesing [75]: curr HIGH @[53]=>1.13429
# DEBUG:ZIGZAG_Signal_Listener:Procesing [76]: curr HIGH @[53]=>1.13429
# DEBUG:ZIGZAG_Signal_Listener:Procesing [77]: curr HIGH @[53]=>1.13429
# DEBUG:ZIGZAG_Signal_Listener:Procesing [78]: curr HIGH @[53]=>1.13429
# DEBUG:ZIGZAG_Signal_Listener:Procesing [79]: curr HIGH @[53]=>1.13429
# DEBUG:ZIGZAG_Signal_Listener:Procesing [80]: save HIGH @[53]=1.13429, new LOW=>1.13271
# DEBUG:ZIGZAG_Signal_Listener:Procesing [81]: new LOW=1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [82]: curr LOW @[81]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [83]: curr LOW @[81]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [84]: curr LOW @[81]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [85]: curr LOW @[81]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [86]: curr LOW @[81]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [87]: curr LOW @[81]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [88]: curr LOW @[81]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [89]: curr LOW @[81]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [90]: curr LOW @[81]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [91]: curr LOW @[81]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [92]: new LOW=1.13202
# DEBUG:ZIGZAG_Signal_Listener:Procesing [93]: curr LOW @[92]=>1.13202
# DEBUG:ZIGZAG_Signal_Listener:Procesing [94]: new LOW=1.13181
# DEBUG:ZIGZAG_Signal_Listener:Procesing [95]: curr LOW @[94]=>1.13181
# DEBUG:ZIGZAG_Signal_Listener:Procesing [96]: curr LOW @[94]=>1.13181
# DEBUG:ZIGZAG_Signal_Listener:Procesing [97]: new LOW=1.1316
# DEBUG:ZIGZAG_Signal_Listener:Procesing [98]: curr LOW @[97]=>1.1316
# DEBUG:ZIGZAG_Signal_Listener:Procesing [99]: curr LOW @[97]=>1.1316
# DEBUG:ZIGZAG_Signal_Listener:Procesing [100]: save LOW @[97]=1.1316, new HIGH=>1.13381
# DEBUG:ZIGZAG_Signal_Listener:Procesing [101]: curr HIGH @[100]=>1.13381
# DEBUG:ZIGZAG_Signal_Listener:Procesing [102]: curr HIGH @[100]=>1.13381
# DEBUG:ZIGZAG_Signal_Listener:Procesing [103]: curr HIGH @[100]=>1.13381
# DEBUG:ZIGZAG_Signal_Listener:Procesing [104]: curr HIGH @[100]=>1.13381
# DEBUG:ZIGZAG_Signal_Listener:Procesing [105]: curr HIGH @[100]=>1.13381
# DEBUG:ZIGZAG_Signal_Listener:Procesing [106]: curr HIGH @[100]=>1.13381
# DEBUG:ZIGZAG_Signal_Listener:Procesing [107]: curr HIGH @[100]=>1.13381
# DEBUG:ZIGZAG_Signal_Listener:Procesing [108]: curr HIGH @[100]=>1.13381
# DEBUG:ZIGZAG_Signal_Listener:Procesing [109]: curr HIGH @[100]=>1.13381
# DEBUG:ZIGZAG_Signal_Listener:Procesing [110]: curr HIGH @[100]=>1.13381
# DEBUG:ZIGZAG_Signal_Listener:Procesing [111]: curr HIGH @[100]=>1.13381
# DEBUG:ZIGZAG_Signal_Listener:Procesing [112]: curr HIGH @[100]=>1.13381
# DEBUG:ZIGZAG_Signal_Listener:Procesing [113]: curr HIGH @[100]=>1.13381
# DEBUG:ZIGZAG_Signal_Listener:Procesing [114]: new HIGH=1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [115]: curr HIGH @[114]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [116]: curr HIGH @[114]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [117]: curr HIGH @[114]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [118]: curr HIGH @[114]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [119]: curr HIGH @[114]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [120]: curr HIGH @[114]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [121]: curr HIGH @[114]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [122]: save HIGH @[114]=1.13386, new LOW=>1.13191
# DEBUG:ZIGZAG_Signal_Listener:Procesing [123]: curr LOW @[122]=>1.13191
# DEBUG:ZIGZAG_Signal_Listener:Procesing [124]: curr LOW @[122]=>1.13191
# DEBUG:ZIGZAG_Signal_Listener:Procesing [125]: new LOW=1.1306
# DEBUG:ZIGZAG_Signal_Listener:Procesing [126]: new LOW=1.12932
# DEBUG:ZIGZAG_Signal_Listener:Procesing [127]: new LOW=1.1292
# DEBUG:ZIGZAG_Signal_Listener:Procesing [128]: curr LOW @[127]=>1.1292
# DEBUG:ZIGZAG_Signal_Listener:Procesing [129]: curr LOW @[127]=>1.1292
# DEBUG:ZIGZAG_Signal_Listener:Procesing [130]: curr LOW @[127]=>1.1292
# DEBUG:ZIGZAG_Signal_Listener:Procesing [131]: curr LOW @[127]=>1.1292
# DEBUG:ZIGZAG_Signal_Listener:Procesing [132]: curr LOW @[127]=>1.1292
# DEBUG:ZIGZAG_Signal_Listener:Procesing [133]: curr LOW @[127]=>1.1292
# DEBUG:ZIGZAG_Signal_Listener:Procesing [134]: new LOW=1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [135]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [136]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [137]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [138]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [139]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [140]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [141]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [142]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [143]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [144]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [145]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [146]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [147]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [148]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [149]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [150]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [151]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [152]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [153]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [154]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [155]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [156]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [157]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [158]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [159]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [160]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [161]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [162]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [163]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [164]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [165]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [166]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [167]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [168]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [169]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [170]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [171]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [172]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [173]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [174]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [175]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [176]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [177]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [178]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [179]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [180]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [181]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [182]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [183]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [184]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [185]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [186]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [187]: curr LOW @[134]=>1.12895
# DEBUG:ZIGZAG_Signal_Listener:Procesing [188]: save LOW @[134]=1.12895, new HIGH=>1.13037
# DEBUG:ZIGZAG_Signal_Listener:Procesing [189]: curr HIGH @[188]=>1.13037
# DEBUG:ZIGZAG_Signal_Listener:Procesing [190]: curr HIGH @[188]=>1.13037
# DEBUG:ZIGZAG_Signal_Listener:Procesing [191]: curr HIGH @[188]=>1.13037
# DEBUG:ZIGZAG_Signal_Listener:Procesing [192]: new HIGH=1.1304
# DEBUG:ZIGZAG_Signal_Listener:Procesing [193]: new HIGH=1.1306
# DEBUG:ZIGZAG_Signal_Listener:Procesing [194]: new HIGH=1.13073
# DEBUG:ZIGZAG_Signal_Listener:Procesing [195]: new HIGH=1.13103
# DEBUG:ZIGZAG_Signal_Listener:Procesing [196]: curr HIGH @[195]=>1.13103
# DEBUG:ZIGZAG_Signal_Listener:Procesing [197]: curr HIGH @[195]=>1.13103
# DEBUG:ZIGZAG_Signal_Listener:Procesing [198]: curr HIGH @[195]=>1.13103
# DEBUG:ZIGZAG_Signal_Listener:Procesing [199]: curr HIGH @[195]=>1.13103
# DEBUG:ZIGZAG_Signal_Listener:Procesing [200]: curr HIGH @[195]=>1.13103
# DEBUG:ZIGZAG_Signal_Listener:Procesing [201]: curr HIGH @[195]=>1.13103
# DEBUG:ZIGZAG_Signal_Listener:Procesing [202]: curr HIGH @[195]=>1.13103
# DEBUG:ZIGZAG_Signal_Listener:Procesing [203]: curr HIGH @[195]=>1.13103
# DEBUG:ZIGZAG_Signal_Listener:Procesing [204]: curr HIGH @[195]=>1.13103
# DEBUG:ZIGZAG_Signal_Listener:Procesing [205]: curr HIGH @[195]=>1.13103
# DEBUG:ZIGZAG_Signal_Listener:Procesing [206]: curr HIGH @[195]=>1.13103
# DEBUG:ZIGZAG_Signal_Listener:Procesing [207]: curr HIGH @[195]=>1.13103
# DEBUG:ZIGZAG_Signal_Listener:Procesing [208]: curr HIGH @[195]=>1.13103
# DEBUG:ZIGZAG_Signal_Listener:Procesing [209]: curr HIGH @[195]=>1.13103
# DEBUG:ZIGZAG_Signal_Listener:Procesing [210]: curr HIGH @[195]=>1.13103
# DEBUG:ZIGZAG_Signal_Listener:Procesing [211]: curr HIGH @[195]=>1.13103
# DEBUG:ZIGZAG_Signal_Listener:Procesing [212]: curr HIGH @[195]=>1.13103
# DEBUG:ZIGZAG_Signal_Listener:Procesing [213]: curr HIGH @[195]=>1.13103
# DEBUG:ZIGZAG_Signal_Listener:Procesing [214]: new HIGH=1.13151
# DEBUG:ZIGZAG_Signal_Listener:Procesing [215]: save HIGH @[214]=1.13151, new LOW=>1.1285399999999999
# INFO:ZIGZAG_Signal_Listener:Procesing [216]: ERR_DELTA \/ =2 keep_HIGH @[214]=>1.13151 remove LOW @[215]
# DEBUG:ZIGZAG_Signal_Listener:Procesing [217]: curr HIGH @[214]=>1.13151
# DEBUG:ZIGZAG_Signal_Listener:Procesing [218]: new HIGH=1.13171
# DEBUG:ZIGZAG_Signal_Listener:Procesing [219]: curr HIGH @[218]=>1.13171
# DEBUG:ZIGZAG_Signal_Listener:Procesing [220]: curr HIGH @[218]=>1.13171
# DEBUG:ZIGZAG_Signal_Listener:Procesing [221]: curr HIGH @[218]=>1.13171
# DEBUG:ZIGZAG_Signal_Listener:Procesing [222]: curr HIGH @[218]=>1.13171
# DEBUG:ZIGZAG_Signal_Listener:Procesing [223]: new HIGH=1.13196
# DEBUG:ZIGZAG_Signal_Listener:Procesing [224]: new HIGH=1.13235
# DEBUG:ZIGZAG_Signal_Listener:Procesing [225]: new HIGH=1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [226]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [227]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [228]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [229]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [230]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [231]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [232]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [233]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [234]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [235]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [236]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [237]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [238]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [239]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [240]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [241]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [242]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [243]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [244]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [245]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [246]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [247]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [248]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [249]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [250]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [251]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [252]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [253]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [254]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [255]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [256]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [257]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [258]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [259]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [260]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [261]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [262]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [263]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [264]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [265]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [266]: curr HIGH @[225]=>1.13247
# DEBUG:ZIGZAG_Signal_Listener:Procesing [267]: save HIGH @[225]=1.13247, new LOW=>1.13047
# DEBUG:ZIGZAG_Signal_Listener:Procesing [268]: curr LOW @[267]=>1.13047
# DEBUG:ZIGZAG_Signal_Listener:Procesing [269]: curr LOW @[267]=>1.13047
# DEBUG:ZIGZAG_Signal_Listener:Procesing [270]: new LOW=1.1304100000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [271]: new LOW=1.13028
# DEBUG:ZIGZAG_Signal_Listener:Procesing [272]: curr LOW @[271]=>1.13028
# DEBUG:ZIGZAG_Signal_Listener:Procesing [273]: curr LOW @[271]=>1.13028
# DEBUG:ZIGZAG_Signal_Listener:Procesing [274]: curr LOW @[271]=>1.13028
# DEBUG:ZIGZAG_Signal_Listener:Procesing [275]: curr LOW @[271]=>1.13028
# DEBUG:ZIGZAG_Signal_Listener:Procesing [276]: curr LOW @[271]=>1.13028
# DEBUG:ZIGZAG_Signal_Listener:Procesing [277]: curr LOW @[271]=>1.13028
# DEBUG:ZIGZAG_Signal_Listener:Procesing [278]: curr LOW @[271]=>1.13028
# DEBUG:ZIGZAG_Signal_Listener:Procesing [279]: curr LOW @[271]=>1.13028
# DEBUG:ZIGZAG_Signal_Listener:Procesing [280]: curr LOW @[271]=>1.13028
# DEBUG:ZIGZAG_Signal_Listener:Procesing [281]: curr LOW @[271]=>1.13028
# DEBUG:ZIGZAG_Signal_Listener:Procesing [282]: curr LOW @[271]=>1.13028
# DEBUG:ZIGZAG_Signal_Listener:Procesing [283]: curr LOW @[271]=>1.13028
# DEBUG:ZIGZAG_Signal_Listener:Procesing [284]: new LOW=1.13022
# DEBUG:ZIGZAG_Signal_Listener:Procesing [285]: new LOW=1.13011
# DEBUG:ZIGZAG_Signal_Listener:Procesing [286]: curr LOW @[285]=>1.13011
# DEBUG:ZIGZAG_Signal_Listener:Procesing [287]: save LOW @[285]=1.13011, new HIGH=>1.13075
# DEBUG:ZIGZAG_Signal_Listener:Procesing [288]: new HIGH=1.1309799999999999
# DEBUG:ZIGZAG_Signal_Listener:Procesing [289]: new HIGH=1.1310200000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [290]: new HIGH=1.13132
# DEBUG:ZIGZAG_Signal_Listener:Procesing [291]: new HIGH=1.13133
# DEBUG:ZIGZAG_Signal_Listener:Procesing [292]: curr HIGH @[291]=>1.13133
# DEBUG:ZIGZAG_Signal_Listener:Procesing [293]: new HIGH=1.1313799999999998
# DEBUG:ZIGZAG_Signal_Listener:Procesing [294]: curr HIGH @[293]=>1.1313799999999998
# DEBUG:ZIGZAG_Signal_Listener:Procesing [295]: curr HIGH @[293]=>1.1313799999999998
# DEBUG:ZIGZAG_Signal_Listener:Procesing [296]: curr HIGH @[293]=>1.1313799999999998
# DEBUG:ZIGZAG_Signal_Listener:Procesing [297]: new HIGH=1.1314600000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [298]: curr HIGH @[297]=>1.1314600000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [299]: new HIGH=1.13158
# DEBUG:ZIGZAG_Signal_Listener:Procesing [300]: new HIGH=1.13184
# DEBUG:ZIGZAG_Signal_Listener:Procesing [301]: new HIGH=1.13198
# DEBUG:ZIGZAG_Signal_Listener:Procesing [302]: new HIGH=1.13202
# DEBUG:ZIGZAG_Signal_Listener:Procesing [303]: curr HIGH @[302]=>1.13202
# DEBUG:ZIGZAG_Signal_Listener:Procesing [304]: curr HIGH @[302]=>1.13202
# DEBUG:ZIGZAG_Signal_Listener:Procesing [305]: curr HIGH @[302]=>1.13202
# DEBUG:ZIGZAG_Signal_Listener:Procesing [306]: curr HIGH @[302]=>1.13202
# DEBUG:ZIGZAG_Signal_Listener:Procesing [307]: curr HIGH @[302]=>1.13202
# DEBUG:ZIGZAG_Signal_Listener:Procesing [308]: save HIGH @[302]=1.13202, new LOW=>1.1274600000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [309]: new LOW=1.12693
# DEBUG:ZIGZAG_Signal_Listener:Procesing [310]: new LOW=1.12629
# DEBUG:ZIGZAG_Signal_Listener:Procesing [311]: new LOW=1.12545
# DEBUG:ZIGZAG_Signal_Listener:Procesing [312]: new LOW=1.12539
# DEBUG:ZIGZAG_Signal_Listener:Procesing [313]: new LOW=1.12456
# DEBUG:ZIGZAG_Signal_Listener:Procesing [314]: new LOW=1.12426
# DEBUG:ZIGZAG_Signal_Listener:Procesing [315]: new LOW=1.1233
# DEBUG:ZIGZAG_Signal_Listener:Procesing [316]: new LOW=1.12296
# DEBUG:ZIGZAG_Signal_Listener:Procesing [317]: curr LOW @[316]=>1.12296
# DEBUG:ZIGZAG_Signal_Listener:Procesing [318]: curr LOW @[316]=>1.12296
# DEBUG:ZIGZAG_Signal_Listener:Procesing [319]: curr LOW @[316]=>1.12296
# DEBUG:ZIGZAG_Signal_Listener:Procesing [320]: curr LOW @[316]=>1.12296
# DEBUG:ZIGZAG_Signal_Listener:Procesing [321]: new LOW=1.1223100000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [322]: new LOW=1.1221
# DEBUG:ZIGZAG_Signal_Listener:Procesing [323]: new LOW=1.12182
# DEBUG:ZIGZAG_Signal_Listener:Procesing [324]: new LOW=1.12061
# DEBUG:ZIGZAG_Signal_Listener:Procesing [325]: curr LOW @[324]=>1.12061
# DEBUG:ZIGZAG_Signal_Listener:Procesing [326]: curr LOW @[324]=>1.12061
# DEBUG:ZIGZAG_Signal_Listener:Procesing [327]: curr LOW @[324]=>1.12061
# DEBUG:ZIGZAG_Signal_Listener:Procesing [328]: curr LOW @[324]=>1.12061
# DEBUG:ZIGZAG_Signal_Listener:Procesing [329]: curr LOW @[324]=>1.12061
# DEBUG:ZIGZAG_Signal_Listener:Procesing [330]: curr LOW @[324]=>1.12061
# DEBUG:ZIGZAG_Signal_Listener:Procesing [331]: curr LOW @[324]=>1.12061
# DEBUG:ZIGZAG_Signal_Listener:Procesing [332]: curr LOW @[324]=>1.12061
# DEBUG:ZIGZAG_Signal_Listener:Procesing [333]: curr LOW @[324]=>1.12061
# DEBUG:ZIGZAG_Signal_Listener:Procesing [334]: curr LOW @[324]=>1.12061
# DEBUG:ZIGZAG_Signal_Listener:Procesing [335]: new LOW=1.11855
# DEBUG:ZIGZAG_Signal_Listener:Procesing [336]: new LOW=1.11763
# DEBUG:ZIGZAG_Signal_Listener:Procesing [337]: curr LOW @[336]=>1.11763
# DEBUG:ZIGZAG_Signal_Listener:Procesing [338]: curr LOW @[336]=>1.11763
# DEBUG:ZIGZAG_Signal_Listener:Procesing [339]: curr LOW @[336]=>1.11763
# DEBUG:ZIGZAG_Signal_Listener:Procesing [340]: curr LOW @[336]=>1.11763
# DEBUG:ZIGZAG_Signal_Listener:Procesing [341]: curr LOW @[336]=>1.11763
# DEBUG:ZIGZAG_Signal_Listener:Procesing [342]: curr LOW @[336]=>1.11763
# DEBUG:ZIGZAG_Signal_Listener:Procesing [343]: curr LOW @[336]=>1.11763
# DEBUG:ZIGZAG_Signal_Listener:Procesing [344]: curr LOW @[336]=>1.11763
# DEBUG:ZIGZAG_Signal_Listener:Procesing [345]: curr LOW @[336]=>1.11763
# DEBUG:ZIGZAG_Signal_Listener:Procesing [346]: curr LOW @[336]=>1.11763
# DEBUG:ZIGZAG_Signal_Listener:Procesing [347]: curr LOW @[336]=>1.11763
# DEBUG:ZIGZAG_Signal_Listener:Procesing [348]: curr LOW @[336]=>1.11763
# DEBUG:ZIGZAG_Signal_Listener:Procesing [349]: curr LOW @[336]=>1.11763
# DEBUG:ZIGZAG_Signal_Listener:Procesing [350]: curr LOW @[336]=>1.11763
# DEBUG:ZIGZAG_Signal_Listener:Procesing [351]: curr LOW @[336]=>1.11763
# DEBUG:ZIGZAG_Signal_Listener:Procesing [352]: curr LOW @[336]=>1.11763
# DEBUG:ZIGZAG_Signal_Listener:Procesing [353]: curr LOW @[336]=>1.11763
# DEBUG:ZIGZAG_Signal_Listener:Procesing [354]: curr LOW @[336]=>1.11763
# DEBUG:ZIGZAG_Signal_Listener:Procesing [355]: curr LOW @[336]=>1.11763
# DEBUG:ZIGZAG_Signal_Listener:Procesing [356]: curr LOW @[336]=>1.11763
# DEBUG:ZIGZAG_Signal_Listener:Procesing [357]: curr LOW @[336]=>1.11763
# DEBUG:ZIGZAG_Signal_Listener:Procesing [358]: curr LOW @[336]=>1.11763
# DEBUG:ZIGZAG_Signal_Listener:Procesing [359]: curr LOW @[336]=>1.11763
# DEBUG:ZIGZAG_Signal_Listener:Procesing [360]: curr LOW @[336]=>1.11763
# DEBUG:ZIGZAG_Signal_Listener:Procesing [361]: curr LOW @[336]=>1.11763
# DEBUG:ZIGZAG_Signal_Listener:Procesing [362]: curr LOW @[336]=>1.11763
# DEBUG:ZIGZAG_Signal_Listener:Procesing [363]: save LOW @[336]=1.11763, new HIGH=>1.12004
# DEBUG:ZIGZAG_Signal_Listener:Procesing [364]: new HIGH=1.1200700000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [365]: curr HIGH @[364]=>1.1200700000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [366]: curr HIGH @[364]=>1.1200700000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [367]: curr HIGH @[364]=>1.1200700000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [368]: curr HIGH @[364]=>1.1200700000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [369]: curr HIGH @[364]=>1.1200700000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [370]: curr HIGH @[364]=>1.1200700000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [371]: curr HIGH @[364]=>1.1200700000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [372]: curr HIGH @[364]=>1.1200700000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [373]: curr HIGH @[364]=>1.1200700000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [374]: curr HIGH @[364]=>1.1200700000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [375]: curr HIGH @[364]=>1.1200700000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [376]: new HIGH=1.1202
# DEBUG:ZIGZAG_Signal_Listener:Procesing [377]: new HIGH=1.1204100000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [378]: new HIGH=1.1204399999999999
# DEBUG:ZIGZAG_Signal_Listener:Procesing [379]: new HIGH=1.1206
# DEBUG:ZIGZAG_Signal_Listener:Procesing [380]: new HIGH=1.12093
# DEBUG:ZIGZAG_Signal_Listener:Procesing [381]: curr HIGH @[380]=>1.12093
# DEBUG:ZIGZAG_Signal_Listener:Procesing [382]: curr HIGH @[380]=>1.12093
# DEBUG:ZIGZAG_Signal_Listener:Procesing [383]: curr HIGH @[380]=>1.12093
# DEBUG:ZIGZAG_Signal_Listener:Procesing [384]: new HIGH=1.12117
# DEBUG:ZIGZAG_Signal_Listener:Procesing [385]: new HIGH=1.12124
# DEBUG:ZIGZAG_Signal_Listener:Procesing [386]: curr HIGH @[385]=>1.12124
# DEBUG:ZIGZAG_Signal_Listener:Procesing [387]: curr HIGH @[385]=>1.12124
# DEBUG:ZIGZAG_Signal_Listener:Procesing [388]: curr HIGH @[385]=>1.12124
# DEBUG:ZIGZAG_Signal_Listener:Procesing [389]: curr HIGH @[385]=>1.12124
# DEBUG:ZIGZAG_Signal_Listener:Procesing [390]: new HIGH=1.12147
# DEBUG:ZIGZAG_Signal_Listener:Procesing [391]: curr HIGH @[390]=>1.12147
# DEBUG:ZIGZAG_Signal_Listener:Procesing [392]: new HIGH=1.12154
# DEBUG:ZIGZAG_Signal_Listener:Procesing [393]: new HIGH=1.12173
# DEBUG:ZIGZAG_Signal_Listener:Procesing [394]: curr HIGH @[393]=>1.12173
# DEBUG:ZIGZAG_Signal_Listener:Procesing [395]: new HIGH=1.1218700000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [396]: new HIGH=1.12199
# DEBUG:ZIGZAG_Signal_Listener:Procesing [397]: curr HIGH @[396]=>1.12199
# DEBUG:ZIGZAG_Signal_Listener:Procesing [398]: new HIGH=1.1220700000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [399]: curr HIGH @[398]=>1.1220700000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [400]: curr HIGH @[398]=>1.1220700000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [401]: curr HIGH @[398]=>1.1220700000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [402]: curr HIGH @[398]=>1.1220700000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [403]: curr HIGH @[398]=>1.1220700000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [404]: new HIGH=1.1223
# DEBUG:ZIGZAG_Signal_Listener:Procesing [405]: new HIGH=1.12237
# DEBUG:ZIGZAG_Signal_Listener:Procesing [406]: new HIGH=1.1228
# DEBUG:ZIGZAG_Signal_Listener:Procesing [407]: new HIGH=1.1241
# DEBUG:ZIGZAG_Signal_Listener:Procesing [408]: curr HIGH @[407]=>1.1241
# DEBUG:ZIGZAG_Signal_Listener:Procesing [409]: curr HIGH @[407]=>1.1241
# DEBUG:ZIGZAG_Signal_Listener:Procesing [410]: curr HIGH @[407]=>1.1241
# DEBUG:ZIGZAG_Signal_Listener:Procesing [411]: curr HIGH @[407]=>1.1241
# DEBUG:ZIGZAG_Signal_Listener:Procesing [412]: curr HIGH @[407]=>1.1241
# DEBUG:ZIGZAG_Signal_Listener:Procesing [413]: curr HIGH @[407]=>1.1241
# DEBUG:ZIGZAG_Signal_Listener:Procesing [414]: curr HIGH @[407]=>1.1241
# DEBUG:ZIGZAG_Signal_Listener:Procesing [415]: curr HIGH @[407]=>1.1241
# DEBUG:ZIGZAG_Signal_Listener:Procesing [416]: curr HIGH @[407]=>1.1241
# DEBUG:ZIGZAG_Signal_Listener:Procesing [417]: curr HIGH @[407]=>1.1241
# DEBUG:ZIGZAG_Signal_Listener:Procesing [418]: new HIGH=1.12446
# DEBUG:ZIGZAG_Signal_Listener:Procesing [419]: curr HIGH @[418]=>1.12446
# DEBUG:ZIGZAG_Signal_Listener:Procesing [420]: curr HIGH @[418]=>1.12446
# DEBUG:ZIGZAG_Signal_Listener:Procesing [421]: new HIGH=1.12461
# DEBUG:ZIGZAG_Signal_Listener:Procesing [422]: curr HIGH @[421]=>1.12461
# DEBUG:ZIGZAG_Signal_Listener:Procesing [423]: curr HIGH @[421]=>1.12461
# DEBUG:ZIGZAG_Signal_Listener:Procesing [424]: curr HIGH @[421]=>1.12461
# DEBUG:ZIGZAG_Signal_Listener:Procesing [425]: curr HIGH @[421]=>1.12461
# DEBUG:ZIGZAG_Signal_Listener:Procesing [426]: curr HIGH @[421]=>1.12461
# DEBUG:ZIGZAG_Signal_Listener:Procesing [427]: curr HIGH @[421]=>1.12461
# DEBUG:ZIGZAG_Signal_Listener:Procesing [428]: curr HIGH @[421]=>1.12461
# DEBUG:ZIGZAG_Signal_Listener:Procesing [429]: curr HIGH @[421]=>1.12461
# DEBUG:ZIGZAG_Signal_Listener:Procesing [430]: curr HIGH @[421]=>1.12461
# DEBUG:ZIGZAG_Signal_Listener:Procesing [431]: curr HIGH @[421]=>1.12461
# DEBUG:ZIGZAG_Signal_Listener:Procesing [432]: curr HIGH @[421]=>1.12461
# DEBUG:ZIGZAG_Signal_Listener:Procesing [433]: curr HIGH @[421]=>1.12461
# DEBUG:ZIGZAG_Signal_Listener:Procesing [434]: curr HIGH @[421]=>1.12461
# DEBUG:ZIGZAG_Signal_Listener:Procesing [435]: save HIGH @[421]=1.12461, new LOW=>1.12322
# DEBUG:ZIGZAG_Signal_Listener:Procesing [436]: new LOW=1.12313
# DEBUG:ZIGZAG_Signal_Listener:Procesing [437]: new LOW=1.12304
# DEBUG:ZIGZAG_Signal_Listener:Procesing [438]: curr LOW @[437]=>1.12304
# DEBUG:ZIGZAG_Signal_Listener:Procesing [439]: curr LOW @[437]=>1.12304
# DEBUG:ZIGZAG_Signal_Listener:Procesing [440]: curr LOW @[437]=>1.12304
# DEBUG:ZIGZAG_Signal_Listener:Procesing [441]: curr LOW @[437]=>1.12304
# DEBUG:ZIGZAG_Signal_Listener:Procesing [442]: curr LOW @[437]=>1.12304
# DEBUG:ZIGZAG_Signal_Listener:Procesing [443]: curr LOW @[437]=>1.12304
# DEBUG:ZIGZAG_Signal_Listener:Procesing [444]: curr LOW @[437]=>1.12304
# DEBUG:ZIGZAG_Signal_Listener:Procesing [445]: curr LOW @[437]=>1.12304
# DEBUG:ZIGZAG_Signal_Listener:Procesing [446]: curr LOW @[437]=>1.12304
# DEBUG:ZIGZAG_Signal_Listener:Procesing [447]: curr LOW @[437]=>1.12304
# DEBUG:ZIGZAG_Signal_Listener:Procesing [448]: curr LOW @[437]=>1.12304
# DEBUG:ZIGZAG_Signal_Listener:Procesing [449]: curr LOW @[437]=>1.12304
# DEBUG:ZIGZAG_Signal_Listener:Procesing [450]: curr LOW @[437]=>1.12304
# DEBUG:ZIGZAG_Signal_Listener:Procesing [451]: curr LOW @[437]=>1.12304
# DEBUG:ZIGZAG_Signal_Listener:Procesing [452]: curr LOW @[437]=>1.12304
# DEBUG:ZIGZAG_Signal_Listener:Procesing [453]: new LOW=1.12287
# DEBUG:ZIGZAG_Signal_Listener:Procesing [454]: new LOW=1.12256
# DEBUG:ZIGZAG_Signal_Listener:Procesing [455]: new LOW=1.1223100000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [456]: curr LOW @[455]=>1.1223100000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [457]: curr LOW @[455]=>1.1223100000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [458]: curr LOW @[455]=>1.1223100000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [459]: curr LOW @[455]=>1.1223100000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [460]: curr LOW @[455]=>1.1223100000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [461]: curr LOW @[455]=>1.1223100000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [462]: curr LOW @[455]=>1.1223100000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [463]: curr LOW @[455]=>1.1223100000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [464]: curr LOW @[455]=>1.1223100000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [465]: curr LOW @[455]=>1.1223100000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [466]: curr LOW @[455]=>1.1223100000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [467]: curr LOW @[455]=>1.1223100000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [468]: curr LOW @[455]=>1.1223100000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [469]: curr LOW @[455]=>1.1223100000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [470]: curr LOW @[455]=>1.1223100000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [471]: curr LOW @[455]=>1.1223100000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [472]: curr LOW @[455]=>1.1223100000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [473]: curr LOW @[455]=>1.1223100000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [474]: curr LOW @[455]=>1.1223100000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [475]: curr LOW @[455]=>1.1223100000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [476]: curr LOW @[455]=>1.1223100000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [477]: curr LOW @[455]=>1.1223100000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [478]: save LOW @[455]=1.1223100000000001, new HIGH=>1.12401
# DEBUG:ZIGZAG_Signal_Listener:Procesing [479]: new HIGH=1.1241
# DEBUG:ZIGZAG_Signal_Listener:Procesing [480]: curr HIGH @[479]=>1.1241
# DEBUG:ZIGZAG_Signal_Listener:Procesing [481]: new HIGH=1.1241299999999999
# DEBUG:ZIGZAG_Signal_Listener:Procesing [482]: new HIGH=1.1243299999999998
# DEBUG:ZIGZAG_Signal_Listener:Procesing [483]: new HIGH=1.12456
# DEBUG:ZIGZAG_Signal_Listener:Procesing [484]: new HIGH=1.12506
# DEBUG:ZIGZAG_Signal_Listener:Procesing [485]: curr HIGH @[484]=>1.12506
# DEBUG:ZIGZAG_Signal_Listener:Procesing [486]: curr HIGH @[484]=>1.12506
# DEBUG:ZIGZAG_Signal_Listener:Procesing [487]: curr HIGH @[484]=>1.12506
# DEBUG:ZIGZAG_Signal_Listener:Procesing [488]: curr HIGH @[484]=>1.12506
# DEBUG:ZIGZAG_Signal_Listener:Procesing [489]: curr HIGH @[484]=>1.12506
# DEBUG:ZIGZAG_Signal_Listener:Procesing [490]: curr HIGH @[484]=>1.12506
# DEBUG:ZIGZAG_Signal_Listener:Procesing [491]: new HIGH=1.12585
# DEBUG:ZIGZAG_Signal_Listener:Procesing [492]: curr HIGH @[491]=>1.12585
# DEBUG:ZIGZAG_Signal_Listener:Procesing [493]: curr HIGH @[491]=>1.12585
# DEBUG:ZIGZAG_Signal_Listener:Procesing [494]: curr HIGH @[491]=>1.12585
# DEBUG:ZIGZAG_Signal_Listener:Procesing [495]: curr HIGH @[491]=>1.12585
# DEBUG:ZIGZAG_Signal_Listener:Procesing [496]: curr HIGH @[491]=>1.12585
# DEBUG:ZIGZAG_Signal_Listener:Procesing [497]: curr HIGH @[491]=>1.12585
# DEBUG:ZIGZAG_Signal_Listener:Procesing [498]: curr HIGH @[491]=>1.12585
# DEBUG:ZIGZAG_Signal_Listener:Procesing [499]: curr HIGH @[491]=>1.12585
# DEBUG:ZIGZAG_Signal_Listener:Procesing [500]: curr HIGH @[491]=>1.12585
# DEBUG:ZIGZAG_Signal_Listener:Procesing [501]: curr HIGH @[491]=>1.12585
# DEBUG:ZIGZAG_Signal_Listener:Procesing [502]: curr HIGH @[491]=>1.12585
# DEBUG:ZIGZAG_Signal_Listener:Procesing [503]: save HIGH @[491]=1.12585, new LOW=>1.12331
# DEBUG:ZIGZAG_Signal_Listener:Procesing [504]: new LOW=1.12325
# DEBUG:ZIGZAG_Signal_Listener:Procesing [505]: curr LOW @[504]=>1.12325
# DEBUG:ZIGZAG_Signal_Listener:Procesing [506]: curr LOW @[504]=>1.12325
# DEBUG:ZIGZAG_Signal_Listener:Procesing [507]: save LOW @[504]=1.12325, new HIGH=>1.12548
# DEBUG:ZIGZAG_Signal_Listener:Procesing [508]: curr HIGH @[507]=>1.12548
# DEBUG:ZIGZAG_Signal_Listener:Procesing [509]: curr HIGH @[507]=>1.12548
# DEBUG:ZIGZAG_Signal_Listener:Procesing [510]: curr HIGH @[507]=>1.12548
# DEBUG:ZIGZAG_Signal_Listener:Procesing [511]: curr HIGH @[507]=>1.12548
# INFO:ZIGZAG_Signal_Listener:Procesing [512]: ERR_DELTA /\ =8 keep_LOW @[504]=>1.12325 remove HIGH @[507]
# DEBUG:ZIGZAG_Signal_Listener:Procesing [513]: curr LOW @[504]=>1.12325
# DEBUG:ZIGZAG_Signal_Listener:Procesing [514]: curr LOW @[504]=>1.12325
# DEBUG:ZIGZAG_Signal_Listener:Procesing [515]: curr LOW @[504]=>1.12325
# DEBUG:ZIGZAG_Signal_Listener:Procesing [516]: new LOW=1.12218
# DEBUG:ZIGZAG_Signal_Listener:Procesing [517]: curr LOW @[516]=>1.12218
# DEBUG:ZIGZAG_Signal_Listener:Procesing [518]: curr LOW @[516]=>1.12218
# DEBUG:ZIGZAG_Signal_Listener:Procesing [519]: curr LOW @[516]=>1.12218
# DEBUG:ZIGZAG_Signal_Listener:Procesing [520]: curr LOW @[516]=>1.12218
# DEBUG:ZIGZAG_Signal_Listener:Procesing [521]: curr LOW @[516]=>1.12218
# DEBUG:ZIGZAG_Signal_Listener:Procesing [522]: curr LOW @[516]=>1.12218
# DEBUG:ZIGZAG_Signal_Listener:Procesing [523]: curr LOW @[516]=>1.12218
# DEBUG:ZIGZAG_Signal_Listener:Procesing [524]: curr LOW @[516]=>1.12218
# DEBUG:ZIGZAG_Signal_Listener:Procesing [525]: curr LOW @[516]=>1.12218
# DEBUG:ZIGZAG_Signal_Listener:Procesing [526]: curr LOW @[516]=>1.12218
# DEBUG:ZIGZAG_Signal_Listener:Procesing [527]: curr LOW @[516]=>1.12218
# DEBUG:ZIGZAG_Signal_Listener:Procesing [528]: curr LOW @[516]=>1.12218
# DEBUG:ZIGZAG_Signal_Listener:Procesing [529]: curr LOW @[516]=>1.12218
# DEBUG:ZIGZAG_Signal_Listener:Procesing [530]: curr LOW @[516]=>1.12218
# DEBUG:ZIGZAG_Signal_Listener:Procesing [531]: curr LOW @[516]=>1.12218
# DEBUG:ZIGZAG_Signal_Listener:Procesing [532]: save LOW @[516]=1.12218, new HIGH=>1.12504
# DEBUG:ZIGZAG_Signal_Listener:Procesing [533]: curr HIGH @[532]=>1.12504
# DEBUG:ZIGZAG_Signal_Listener:Procesing [534]: curr HIGH @[532]=>1.12504
# DEBUG:ZIGZAG_Signal_Listener:Procesing [535]: curr HIGH @[532]=>1.12504
# DEBUG:ZIGZAG_Signal_Listener:Procesing [536]: curr HIGH @[532]=>1.12504
# DEBUG:ZIGZAG_Signal_Listener:Procesing [537]: curr HIGH @[532]=>1.12504
# DEBUG:ZIGZAG_Signal_Listener:Procesing [538]: curr HIGH @[532]=>1.12504
# DEBUG:ZIGZAG_Signal_Listener:Procesing [539]: curr HIGH @[532]=>1.12504
# DEBUG:ZIGZAG_Signal_Listener:Procesing [540]: curr HIGH @[532]=>1.12504
# DEBUG:ZIGZAG_Signal_Listener:Procesing [541]: new HIGH=1.12737
# DEBUG:ZIGZAG_Signal_Listener:Procesing [542]: curr HIGH @[541]=>1.12737
# DEBUG:ZIGZAG_Signal_Listener:Procesing [543]: curr HIGH @[541]=>1.12737
# DEBUG:ZIGZAG_Signal_Listener:Procesing [544]: curr HIGH @[541]=>1.12737
# DEBUG:ZIGZAG_Signal_Listener:Procesing [545]: curr HIGH @[541]=>1.12737
# DEBUG:ZIGZAG_Signal_Listener:Procesing [546]: curr HIGH @[541]=>1.12737
# DEBUG:ZIGZAG_Signal_Listener:Procesing [547]: curr HIGH @[541]=>1.12737
# DEBUG:ZIGZAG_Signal_Listener:Procesing [548]: curr HIGH @[541]=>1.12737
# DEBUG:ZIGZAG_Signal_Listener:Procesing [549]: curr HIGH @[541]=>1.12737
# DEBUG:ZIGZAG_Signal_Listener:Procesing [550]: curr HIGH @[541]=>1.12737
# DEBUG:ZIGZAG_Signal_Listener:Procesing [551]: curr HIGH @[541]=>1.12737
# DEBUG:ZIGZAG_Signal_Listener:Procesing [552]: curr HIGH @[541]=>1.12737
# DEBUG:ZIGZAG_Signal_Listener:Procesing [553]: curr HIGH @[541]=>1.12737
# DEBUG:ZIGZAG_Signal_Listener:Procesing [554]: curr HIGH @[541]=>1.12737
# DEBUG:ZIGZAG_Signal_Listener:Procesing [555]: curr HIGH @[541]=>1.12737
# DEBUG:ZIGZAG_Signal_Listener:Procesing [556]: curr HIGH @[541]=>1.12737
# DEBUG:ZIGZAG_Signal_Listener:Procesing [557]: curr HIGH @[541]=>1.12737
# DEBUG:ZIGZAG_Signal_Listener:Procesing [558]: curr HIGH @[541]=>1.12737
# DEBUG:ZIGZAG_Signal_Listener:Procesing [559]: curr HIGH @[541]=>1.12737
# DEBUG:ZIGZAG_Signal_Listener:Procesing [560]: curr HIGH @[541]=>1.12737
# DEBUG:ZIGZAG_Signal_Listener:Procesing [561]: curr HIGH @[541]=>1.12737
# DEBUG:ZIGZAG_Signal_Listener:Procesing [562]: curr HIGH @[541]=>1.12737
# DEBUG:ZIGZAG_Signal_Listener:Procesing [563]: curr HIGH @[541]=>1.12737
# DEBUG:ZIGZAG_Signal_Listener:Procesing [564]: curr HIGH @[541]=>1.12737
# DEBUG:ZIGZAG_Signal_Listener:Procesing [565]: curr HIGH @[541]=>1.12737
# DEBUG:ZIGZAG_Signal_Listener:Procesing [566]: curr HIGH @[541]=>1.12737
# DEBUG:ZIGZAG_Signal_Listener:Procesing [567]: curr HIGH @[541]=>1.12737
# DEBUG:ZIGZAG_Signal_Listener:Procesing [568]: save HIGH @[541]=1.12737, new LOW=>1.12511
# DEBUG:ZIGZAG_Signal_Listener:Procesing [569]: curr LOW @[568]=>1.12511
# DEBUG:ZIGZAG_Signal_Listener:Procesing [570]: curr LOW @[568]=>1.12511
# DEBUG:ZIGZAG_Signal_Listener:Procesing [571]: curr LOW @[568]=>1.12511
# DEBUG:ZIGZAG_Signal_Listener:Procesing [572]: curr LOW @[568]=>1.12511
# DEBUG:ZIGZAG_Signal_Listener:Procesing [573]: curr LOW @[568]=>1.12511
# DEBUG:ZIGZAG_Signal_Listener:Procesing [574]: curr LOW @[568]=>1.12511
# DEBUG:ZIGZAG_Signal_Listener:Procesing [575]: curr LOW @[568]=>1.12511
# DEBUG:ZIGZAG_Signal_Listener:Procesing [576]: curr LOW @[568]=>1.12511
# DEBUG:ZIGZAG_Signal_Listener:Procesing [577]: curr LOW @[568]=>1.12511
# DEBUG:ZIGZAG_Signal_Listener:Procesing [578]: curr LOW @[568]=>1.12511
# DEBUG:ZIGZAG_Signal_Listener:Procesing [579]: curr LOW @[568]=>1.12511
# DEBUG:ZIGZAG_Signal_Listener:Procesing [580]: save LOW @[568]=1.12511, new HIGH=>1.12675
# DEBUG:ZIGZAG_Signal_Listener:Procesing [581]: new HIGH=1.12693
# DEBUG:ZIGZAG_Signal_Listener:Procesing [582]: new HIGH=1.12755
# DEBUG:ZIGZAG_Signal_Listener:Procesing [583]: curr HIGH @[582]=>1.12755
# DEBUG:ZIGZAG_Signal_Listener:Procesing [584]: new HIGH=1.12832
# DEBUG:ZIGZAG_Signal_Listener:Procesing [585]: new HIGH=1.12842
# DEBUG:ZIGZAG_Signal_Listener:Procesing [586]: curr HIGH @[585]=>1.12842
# DEBUG:ZIGZAG_Signal_Listener:Procesing [587]: new HIGH=1.1284299999999998
# DEBUG:ZIGZAG_Signal_Listener:Procesing [588]: curr HIGH @[587]=>1.1284299999999998
# DEBUG:ZIGZAG_Signal_Listener:Procesing [589]: curr HIGH @[587]=>1.1284299999999998
# DEBUG:ZIGZAG_Signal_Listener:Procesing [590]: curr HIGH @[587]=>1.1284299999999998
# DEBUG:ZIGZAG_Signal_Listener:Procesing [591]: curr HIGH @[587]=>1.1284299999999998
# DEBUG:ZIGZAG_Signal_Listener:Procesing [592]: curr HIGH @[587]=>1.1284299999999998
# DEBUG:ZIGZAG_Signal_Listener:Procesing [593]: curr HIGH @[587]=>1.1284299999999998
# DEBUG:ZIGZAG_Signal_Listener:Procesing [594]: save HIGH @[587]=1.1284299999999998, new LOW=>1.12503
# DEBUG:ZIGZAG_Signal_Listener:Procesing [595]: curr LOW @[594]=>1.12503
# DEBUG:ZIGZAG_Signal_Listener:Procesing [596]: curr LOW @[594]=>1.12503
# DEBUG:ZIGZAG_Signal_Listener:Procesing [597]: new LOW=1.12495
# DEBUG:ZIGZAG_Signal_Listener:Procesing [598]: curr LOW @[597]=>1.12495
# DEBUG:ZIGZAG_Signal_Listener:Procesing [599]: curr LOW @[597]=>1.12495
# DEBUG:ZIGZAG_Signal_Listener:Procesing [600]: curr LOW @[597]=>1.12495
# DEBUG:ZIGZAG_Signal_Listener:Procesing [601]: curr LOW @[597]=>1.12495
# DEBUG:ZIGZAG_Signal_Listener:Procesing [602]: curr LOW @[597]=>1.12495
# DEBUG:ZIGZAG_Signal_Listener:Procesing [603]: curr LOW @[597]=>1.12495
# DEBUG:ZIGZAG_Signal_Listener:Procesing [604]: curr LOW @[597]=>1.12495
# DEBUG:ZIGZAG_Signal_Listener:Procesing [605]: curr LOW @[597]=>1.12495
# DEBUG:ZIGZAG_Signal_Listener:Procesing [606]: curr LOW @[597]=>1.12495
# DEBUG:ZIGZAG_Signal_Listener:Procesing [607]: curr LOW @[597]=>1.12495
# DEBUG:ZIGZAG_Signal_Listener:Procesing [608]: curr LOW @[597]=>1.12495
# DEBUG:ZIGZAG_Signal_Listener:Procesing [609]: curr LOW @[597]=>1.12495
# DEBUG:ZIGZAG_Signal_Listener:Procesing [610]: save LOW @[597]=1.12495, new HIGH=>1.1294
# DEBUG:ZIGZAG_Signal_Listener:Procesing [611]: new HIGH=1.12945
# DEBUG:ZIGZAG_Signal_Listener:Procesing [612]: curr HIGH @[611]=>1.12945
# DEBUG:ZIGZAG_Signal_Listener:Procesing [613]: curr HIGH @[611]=>1.12945
# DEBUG:ZIGZAG_Signal_Listener:Procesing [614]: curr HIGH @[611]=>1.12945
# DEBUG:ZIGZAG_Signal_Listener:Procesing [615]: curr HIGH @[611]=>1.12945
# DEBUG:ZIGZAG_Signal_Listener:Procesing [616]: new HIGH=1.12951
# DEBUG:ZIGZAG_Signal_Listener:Procesing [617]: curr HIGH @[616]=>1.12951
# DEBUG:ZIGZAG_Signal_Listener:Procesing [618]: curr HIGH @[616]=>1.12951
# DEBUG:ZIGZAG_Signal_Listener:Procesing [619]: curr HIGH @[616]=>1.12951
# DEBUG:ZIGZAG_Signal_Listener:Procesing [620]: curr HIGH @[616]=>1.12951
# DEBUG:ZIGZAG_Signal_Listener:Procesing [621]: curr HIGH @[616]=>1.12951
# DEBUG:ZIGZAG_Signal_Listener:Procesing [622]: new HIGH=1.13006
# DEBUG:ZIGZAG_Signal_Listener:Procesing [623]: new HIGH=1.13008
# DEBUG:ZIGZAG_Signal_Listener:Procesing [624]: curr HIGH @[623]=>1.13008
# DEBUG:ZIGZAG_Signal_Listener:Procesing [625]: curr HIGH @[623]=>1.13008
# DEBUG:ZIGZAG_Signal_Listener:Procesing [626]: new HIGH=1.1303
# DEBUG:ZIGZAG_Signal_Listener:Procesing [627]: new HIGH=1.1305
# DEBUG:ZIGZAG_Signal_Listener:Procesing [628]: curr HIGH @[627]=>1.1305
# DEBUG:ZIGZAG_Signal_Listener:Procesing [629]: curr HIGH @[627]=>1.1305
# DEBUG:ZIGZAG_Signal_Listener:Procesing [630]: curr HIGH @[627]=>1.1305
# DEBUG:ZIGZAG_Signal_Listener:Procesing [631]: curr HIGH @[627]=>1.1305
# DEBUG:ZIGZAG_Signal_Listener:Procesing [632]: save HIGH @[627]=1.1305, new LOW=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [633]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [634]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [635]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [636]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [637]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [638]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [639]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [640]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [641]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [642]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [643]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [644]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [645]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [646]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [647]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [648]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [649]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [650]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [651]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [652]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [653]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [654]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [655]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [656]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [657]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [658]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [659]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [660]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [661]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [662]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [663]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [664]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [665]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [666]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [667]: curr LOW @[632]=>1.12821
# DEBUG:ZIGZAG_Signal_Listener:Procesing [668]: curr LOW @[632]=>1.12821
# ...
# DEBUG:ZIGZAG_Signal_Listener:Procesing [674]: curr HIGH @[673]=>1.1289200000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [675]: save HIGH @[673]=1.1289200000000001, new LOW=>1.12826
# DEBUG:ZIGZAG_Signal_Listener:Procesing [676]: new LOW=1.12785
# DEBUG:ZIGZAG_Signal_Listener:Procesing [677]: new LOW=1.12773
# INFO:ZIGZAG_Signal_Listener:Procesing [678]: ERR_DELTA \/ =5 replace_HIGH @[673]=>1.12941 remove LOW @[677]
# DEBUG:ZIGZAG_Signal_Listener:Procesing [679]: new HIGH=1.1297
# DEBUG:ZIGZAG_Signal_Listener:Procesing [680]: curr HIGH @[679]=>1.1297
# DEBUG:ZIGZAG_Signal_Listener:Procesing [681]: curr HIGH @[679]=>1.1297
# DEBUG:ZIGZAG_Signal_Listener:Procesing [682]: new HIGH=1.12979
# DEBUG:ZIGZAG_Signal_Listener:Procesing [683]: curr HIGH @[682]=>1.12979
# DEBUG:ZIGZAG_Signal_Listener:Procesing [684]: curr HIGH @[682]=>1.12979
# DEBUG:ZIGZAG_Signal_Listener:Procesing [685]: new HIGH=1.13028
# DEBUG:ZIGZAG_Signal_Listener:Procesing [686]: curr HIGH @[685]=>1.13028
# DEBUG:ZIGZAG_Signal_Listener:Procesing [687]: curr HIGH @[685]=>1.13028
# DEBUG:ZIGZAG_Signal_Listener:Procesing [688]: curr HIGH @[685]=>1.13028
# DEBUG:ZIGZAG_Signal_Listener:Procesing [689]: curr HIGH @[685]=>1.13028
# DEBUG:ZIGZAG_Signal_Listener:Procesing [690]: curr HIGH @[685]=>1.13028
# DEBUG:ZIGZAG_Signal_Listener:Procesing [691]: curr HIGH @[685]=>1.13028
# DEBUG:ZIGZAG_Signal_Listener:Procesing [692]: new HIGH=1.13047
# DEBUG:ZIGZAG_Signal_Listener:Procesing [693]: new HIGH=1.13049
# DEBUG:ZIGZAG_Signal_Listener:Procesing [694]: curr HIGH @[693]=>1.13049
# DEBUG:ZIGZAG_Signal_Listener:Procesing [695]: curr HIGH @[693]=>1.13049
# DEBUG:ZIGZAG_Signal_Listener:Procesing [696]: curr HIGH @[693]=>1.13049
# DEBUG:ZIGZAG_Signal_Listener:Procesing [697]: curr HIGH @[693]=>1.13049
# DEBUG:ZIGZAG_Signal_Listener:Procesing [698]: curr HIGH @[693]=>1.13049
# DEBUG:ZIGZAG_Signal_Listener:Procesing [699]: curr HIGH @[693]=>1.13049
# DEBUG:ZIGZAG_Signal_Listener:Procesing [700]: new HIGH=1.13127
# DEBUG:ZIGZAG_Signal_Listener:Procesing [701]: curr HIGH @[700]=>1.13127
# DEBUG:ZIGZAG_Signal_Listener:Procesing [702]: new HIGH=1.1313600000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [703]: curr HIGH @[702]=>1.1313600000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [704]: curr HIGH @[702]=>1.1313600000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [705]: curr HIGH @[702]=>1.1313600000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [706]: curr HIGH @[702]=>1.1313600000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [707]: curr HIGH @[702]=>1.1313600000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [708]: new HIGH=1.1313799999999998
# DEBUG:ZIGZAG_Signal_Listener:Procesing [709]: new HIGH=1.13153
# DEBUG:ZIGZAG_Signal_Listener:Procesing [710]: curr HIGH @[709]=>1.13153
# DEBUG:ZIGZAG_Signal_Listener:Procesing [711]: curr HIGH @[709]=>1.13153
# DEBUG:ZIGZAG_Signal_Listener:Procesing [712]: curr HIGH @[709]=>1.13153
# DEBUG:ZIGZAG_Signal_Listener:Procesing [713]: curr HIGH @[709]=>1.13153
# DEBUG:ZIGZAG_Signal_Listener:Procesing [714]: curr HIGH @[709]=>1.13153
# DEBUG:ZIGZAG_Signal_Listener:Procesing [715]: curr HIGH @[709]=>1.13153
# DEBUG:ZIGZAG_Signal_Listener:Procesing [716]: curr HIGH @[709]=>1.13153
# DEBUG:ZIGZAG_Signal_Listener:Procesing [717]: curr HIGH @[709]=>1.13153
# DEBUG:ZIGZAG_Signal_Listener:Procesing [718]: curr HIGH @[709]=>1.13153
# DEBUG:ZIGZAG_Signal_Listener:Procesing [719]: curr HIGH @[709]=>1.13153
# DEBUG:ZIGZAG_Signal_Listener:Procesing [720]: new HIGH=1.13343
# DEBUG:ZIGZAG_Signal_Listener:Procesing [721]: curr HIGH @[720]=>1.13343
# DEBUG:ZIGZAG_Signal_Listener:Procesing [722]: curr HIGH @[720]=>1.13343
# DEBUG:ZIGZAG_Signal_Listener:Procesing [723]: new HIGH=1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [724]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [725]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [726]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [727]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [728]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [729]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [730]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [731]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [732]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [733]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [734]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [735]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [736]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [737]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [738]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [739]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [740]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [741]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [742]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [743]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [744]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [745]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [746]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [747]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [748]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [749]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [750]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [751]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [752]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [753]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [754]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [755]: curr HIGH @[723]=>1.13386
# DEBUG:ZIGZAG_Signal_Listener:Procesing [756]: save HIGH @[723]=1.13386, new LOW=>1.13201
# DEBUG:ZIGZAG_Signal_Listener:Procesing [757]: new LOW=1.13199
# DEBUG:ZIGZAG_Signal_Listener:Procesing [758]: curr LOW @[757]=>1.13199
# DEBUG:ZIGZAG_Signal_Listener:Procesing [759]: new LOW=1.13185
# DEBUG:ZIGZAG_Signal_Listener:Procesing [760]: new LOW=1.1317700000000002
# DEBUG:ZIGZAG_Signal_Listener:Procesing [761]: curr LOW @[760]=>1.1317700000000002
# DEBUG:ZIGZAG_Signal_Listener:Procesing [762]: curr LOW @[760]=>1.1317700000000002
# DEBUG:ZIGZAG_Signal_Listener:Procesing [763]: new LOW=1.13175
# DEBUG:ZIGZAG_Signal_Listener:Procesing [764]: curr LOW @[763]=>1.13175
# DEBUG:ZIGZAG_Signal_Listener:Procesing [765]: new LOW=1.1313600000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [766]: curr LOW @[765]=>1.1313600000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [767]: curr LOW @[765]=>1.1313600000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [768]: curr LOW @[765]=>1.1313600000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [769]: new LOW=1.1312200000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [770]: curr LOW @[769]=>1.1312200000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [771]: save LOW @[769]=1.1312200000000001, new HIGH=>1.13281
# DEBUG:ZIGZAG_Signal_Listener:Procesing [772]: curr HIGH @[771]=>1.13281
# DEBUG:ZIGZAG_Signal_Listener:Procesing [773]: new HIGH=1.13362
# DEBUG:ZIGZAG_Signal_Listener:Procesing [774]: curr HIGH @[773]=>1.13362
# DEBUG:ZIGZAG_Signal_Listener:Procesing [775]: curr HIGH @[773]=>1.13362
# DEBUG:ZIGZAG_Signal_Listener:Procesing [776]: curr HIGH @[773]=>1.13362
# DEBUG:ZIGZAG_Signal_Listener:Procesing [777]: curr HIGH @[773]=>1.13362
# DEBUG:ZIGZAG_Signal_Listener:Procesing [778]: curr HIGH @[773]=>1.13362
# DEBUG:ZIGZAG_Signal_Listener:Procesing [779]: curr HIGH @[773]=>1.13362
# DEBUG:ZIGZAG_Signal_Listener:Procesing [780]: curr HIGH @[773]=>1.13362
# DEBUG:ZIGZAG_Signal_Listener:Procesing [781]: save HIGH @[773]=1.13362, new LOW=>1.1305
# DEBUG:ZIGZAG_Signal_Listener:Procesing [782]: curr LOW @[781]=>1.1305
# DEBUG:ZIGZAG_Signal_Listener:Procesing [783]: new LOW=1.13025
# DEBUG:ZIGZAG_Signal_Listener:Procesing [784]: new LOW=1.1301299999999999
# DEBUG:ZIGZAG_Signal_Listener:Procesing [785]: curr LOW @[784]=>1.1301299999999999
# DEBUG:ZIGZAG_Signal_Listener:Procesing [786]: curr LOW @[784]=>1.1301299999999999
# DEBUG:ZIGZAG_Signal_Listener:Procesing [787]: new LOW=1.12976
# DEBUG:ZIGZAG_Signal_Listener:Procesing [788]: new LOW=1.1295899999999999
# DEBUG:ZIGZAG_Signal_Listener:Procesing [789]: curr LOW @[788]=>1.1295899999999999
# DEBUG:ZIGZAG_Signal_Listener:Procesing [790]: curr LOW @[788]=>1.1295899999999999
# DEBUG:ZIGZAG_Signal_Listener:Procesing [791]: curr LOW @[788]=>1.1295899999999999
# DEBUG:ZIGZAG_Signal_Listener:Procesing [792]: curr LOW @[788]=>1.1295899999999999
# DEBUG:ZIGZAG_Signal_Listener:Procesing [793]: new LOW=1.1294600000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [794]: new LOW=1.12941
# DEBUG:ZIGZAG_Signal_Listener:Procesing [795]: curr LOW @[794]=>1.12941
# DEBUG:ZIGZAG_Signal_Listener:Procesing [796]: curr LOW @[794]=>1.12941
# DEBUG:ZIGZAG_Signal_Listener:Procesing [797]: curr LOW @[794]=>1.12941
# DEBUG:ZIGZAG_Signal_Listener:Procesing [798]: curr LOW @[794]=>1.12941
# DEBUG:ZIGZAG_Signal_Listener:Procesing [799]: curr LOW @[794]=>1.12941
# DEBUG:ZIGZAG_Signal_Listener:Procesing [800]: curr LOW @[794]=>1.12941
# DEBUG:ZIGZAG_Signal_Listener:Procesing [801]: curr LOW @[794]=>1.12941
# DEBUG:ZIGZAG_Signal_Listener:Procesing [802]: curr LOW @[794]=>1.12941
# DEBUG:ZIGZAG_Signal_Listener:Procesing [803]: curr LOW @[794]=>1.12941
# DEBUG:ZIGZAG_Signal_Listener:Procesing [804]: save LOW @[794]=1.12941, new HIGH=>1.13096
# DEBUG:ZIGZAG_Signal_Listener:Procesing [805]: curr HIGH @[804]=>1.13096
# DEBUG:ZIGZAG_Signal_Listener:Procesing [806]: curr HIGH @[804]=>1.13096
# DEBUG:ZIGZAG_Signal_Listener:Procesing [807]: curr HIGH @[804]=>1.13096
# DEBUG:ZIGZAG_Signal_Listener:Procesing [808]: curr HIGH @[804]=>1.13096
# DEBUG:ZIGZAG_Signal_Listener:Procesing [809]: curr HIGH @[804]=>1.13096
# DEBUG:ZIGZAG_Signal_Listener:Procesing [810]: curr HIGH @[804]=>1.13096
# DEBUG:ZIGZAG_Signal_Listener:Procesing [811]: curr HIGH @[804]=>1.13096
# DEBUG:ZIGZAG_Signal_Listener:Procesing [812]: curr HIGH @[804]=>1.13096
# DEBUG:ZIGZAG_Signal_Listener:Procesing [813]: curr HIGH @[804]=>1.13096
# DEBUG:ZIGZAG_Signal_Listener:Procesing [814]: curr HIGH @[804]=>1.13096
# DEBUG:ZIGZAG_Signal_Listener:Procesing [815]: curr HIGH @[804]=>1.13096
# DEBUG:ZIGZAG_Signal_Listener:Procesing [816]: curr HIGH @[804]=>1.13096
# DEBUG:ZIGZAG_Signal_Listener:Procesing [817]: curr HIGH @[804]=>1.13096
# DEBUG:ZIGZAG_Signal_Listener:Procesing [818]: curr HIGH @[804]=>1.13096
# DEBUG:ZIGZAG_Signal_Listener:Procesing [819]: curr HIGH @[804]=>1.13096
# DEBUG:ZIGZAG_Signal_Listener:Procesing [820]: curr HIGH @[804]=>1.13096
# DEBUG:ZIGZAG_Signal_Listener:Procesing [821]: curr HIGH @[804]=>1.13096
# DEBUG:ZIGZAG_Signal_Listener:Procesing [822]: curr HIGH @[804]=>1.13096
# DEBUG:ZIGZAG_Signal_Listener:Procesing [823]: curr HIGH @[804]=>1.13096
# DEBUG:ZIGZAG_Signal_Listener:Procesing [824]: curr HIGH @[804]=>1.13096
# DEBUG:ZIGZAG_Signal_Listener:Procesing [825]: curr HIGH @[804]=>1.13096
# DEBUG:ZIGZAG_Signal_Listener:Procesing [826]: save HIGH @[804]=1.13096, new LOW=>1.12976
# DEBUG:ZIGZAG_Signal_Listener:Procesing [827]: curr LOW @[826]=>1.12976
# DEBUG:ZIGZAG_Signal_Listener:Procesing [828]: save LOW @[826]=1.12976, new HIGH=>1.13065
# DEBUG:ZIGZAG_Signal_Listener:Procesing [829]: new HIGH=1.13101
# DEBUG:ZIGZAG_Signal_Listener:Procesing [830]: curr HIGH @[829]=>1.13101
# DEBUG:ZIGZAG_Signal_Listener:Procesing [831]: curr HIGH @[829]=>1.13101
# DEBUG:ZIGZAG_Signal_Listener:Procesing [832]: curr HIGH @[829]=>1.13101
# DEBUG:ZIGZAG_Signal_Listener:Procesing [833]: curr HIGH @[829]=>1.13101
# DEBUG:ZIGZAG_Signal_Listener:Procesing [834]: curr HIGH @[829]=>1.13101
# DEBUG:ZIGZAG_Signal_Listener:Procesing [835]: curr HIGH @[829]=>1.13101
# DEBUG:ZIGZAG_Signal_Listener:Procesing [836]: curr HIGH @[829]=>1.13101
# DEBUG:ZIGZAG_Signal_Listener:Procesing [837]: curr HIGH @[829]=>1.13101
# DEBUG:ZIGZAG_Signal_Listener:Procesing [838]: curr HIGH @[829]=>1.13101
# DEBUG:ZIGZAG_Signal_Listener:Procesing [839]: curr HIGH @[829]=>1.13101
# DEBUG:ZIGZAG_Signal_Listener:Procesing [840]: curr HIGH @[829]=>1.13101
# DEBUG:ZIGZAG_Signal_Listener:Procesing [841]: curr HIGH @[829]=>1.13101
# DEBUG:ZIGZAG_Signal_Listener:Procesing [842]: curr HIGH @[829]=>1.13101
# DEBUG:ZIGZAG_Signal_Listener:Procesing [843]: new HIGH=1.13125
# DEBUG:ZIGZAG_Signal_Listener:Procesing [844]: curr HIGH @[843]=>1.13125
# DEBUG:ZIGZAG_Signal_Listener:Procesing [845]: curr HIGH @[843]=>1.13125
# DEBUG:ZIGZAG_Signal_Listener:Procesing [846]: new HIGH=1.1315899999999999
# DEBUG:ZIGZAG_Signal_Listener:Procesing [847]: new HIGH=1.1318
# DEBUG:ZIGZAG_Signal_Listener:Procesing [848]: new HIGH=1.13227
# DEBUG:ZIGZAG_Signal_Listener:Procesing [849]: new HIGH=1.13273
# DEBUG:ZIGZAG_Signal_Listener:Procesing [850]: curr HIGH @[849]=>1.13273
# DEBUG:ZIGZAG_Signal_Listener:Procesing [851]: curr HIGH @[849]=>1.13273
# DEBUG:ZIGZAG_Signal_Listener:Procesing [852]: curr HIGH @[849]=>1.13273
# DEBUG:ZIGZAG_Signal_Listener:Procesing [853]: curr HIGH @[849]=>1.13273
# DEBUG:ZIGZAG_Signal_Listener:Procesing [854]: curr HIGH @[849]=>1.13273
# DEBUG:ZIGZAG_Signal_Listener:Procesing [855]: curr HIGH @[849]=>1.13273
# DEBUG:ZIGZAG_Signal_Listener:Procesing [856]: curr HIGH @[849]=>1.13273
# DEBUG:ZIGZAG_Signal_Listener:Procesing [857]: curr HIGH @[849]=>1.13273
# DEBUG:ZIGZAG_Signal_Listener:Procesing [858]: curr HIGH @[849]=>1.13273
# DEBUG:ZIGZAG_Signal_Listener:Procesing [859]: curr HIGH @[849]=>1.13273
# DEBUG:ZIGZAG_Signal_Listener:Procesing [860]: curr HIGH @[849]=>1.13273
# DEBUG:ZIGZAG_Signal_Listener:Procesing [861]: curr HIGH @[849]=>1.13273
# DEBUG:ZIGZAG_Signal_Listener:Procesing [862]: curr HIGH @[849]=>1.13273
# DEBUG:ZIGZAG_Signal_Listener:Procesing [863]: curr HIGH @[849]=>1.13273
# DEBUG:ZIGZAG_Signal_Listener:Procesing [864]: curr HIGH @[849]=>1.13273
# DEBUG:ZIGZAG_Signal_Listener:Procesing [865]: curr HIGH @[849]=>1.13273
# DEBUG:ZIGZAG_Signal_Listener:Procesing [866]: curr HIGH @[849]=>1.13273
# DEBUG:ZIGZAG_Signal_Listener:Procesing [867]: curr HIGH @[849]=>1.13273
# DEBUG:ZIGZAG_Signal_Listener:Procesing [868]: curr HIGH @[849]=>1.13273
# DEBUG:ZIGZAG_Signal_Listener:Procesing [869]: new HIGH=1.13294
# DEBUG:ZIGZAG_Signal_Listener:Procesing [870]: curr HIGH @[869]=>1.13294
# DEBUG:ZIGZAG_Signal_Listener:Procesing [871]: curr HIGH @[869]=>1.13294
# DEBUG:ZIGZAG_Signal_Listener:Procesing [872]: curr HIGH @[869]=>1.13294
# DEBUG:ZIGZAG_Signal_Listener:Procesing [873]: curr HIGH @[869]=>1.13294
# DEBUG:ZIGZAG_Signal_Listener:Procesing [874]: save HIGH @[869]=1.13294, new LOW=>1.1312200000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [875]: curr LOW @[874]=>1.1312200000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [876]: curr LOW @[874]=>1.1312200000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [877]: curr LOW @[874]=>1.1312200000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [878]: curr LOW @[874]=>1.1312200000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [879]: curr LOW @[874]=>1.1312200000000001
# DEBUG:ZIGZAG_Signal_Listener:Procesing [880]: curr LOW @[874]=>1.1312200000000001
#         OPEN     HIGH      LOW    CLOSE  BOLLINGER_HI  BOLLINGER_MA  \
# 798  1.12968  1.13016  1.12944  1.12994      1.131453      1.130418
# 613  1.12763  1.12808  1.12737  1.12790      1.129364      1.127333
# 545  1.12632  1.12678  1.12626  1.12652      1.126866      1.124972
#
#      BOLLINGER_LO  BOLLINGER_WIDTH  BOLLINGER_WIDTH_SMA20  \
# 798      1.129383         0.002071               0.003122
# 613      1.125302         0.004062               0.003503
# 545      1.123079         0.003786               0.002478
#
#      BOLLINGER_WIDTH_SMA50  BOLLINGER_WIDTH_SMA100  BOLLINGER_b  ZIGZAG ACTION
# 798               0.002124                0.002399     0.269177     0.0    low
# 613               0.002677                0.002602     0.639594     0.0   high
# 545               0.002219                0.001833     0.908705     0.0   high

# %%
# plot BollingerBands and Zigzag
_df_draw = _df_result.copy()

# build candlestick trace
trace_ohlc = go.Ohlc(x=_df_draw.index.values, open=_df_draw.OPEN, high=_df_draw.HIGH, low=_df_draw.LOW, close=_df_draw.CLOSE, name='Candlestick')

_dfz = _df_draw[_df_draw.ZIGZAG > 0].copy()
trace_zigzag = go.Scatter(x=_dfz.reset_index()['index'], y=_dfz.ZIGZAG, name='zigzag', line=scatter.Line(color='black', width=1))

trace_bbup = go.Scatter(x=_df_draw.index.values, y=_df_draw.BOLLINGER_HI, name='BBup', line=scatter.Line(color='blue', width=1))
trace_bbdn = go.Scatter(x=_df_draw.index.values, y=_df_draw.BOLLINGER_LO, name='BBdn', line=scatter.Line(color='blue', width=1))
  
py.iplot([trace_ohlc, trace_zigzag, trace_bbup, trace_bbdn], filename='simple_ohlc')
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): plot.ly:443
# DEBUG:urllib3.connectionpool:https://plot.ly:443 "POST /clientresp HTTP/1.1" 200 None
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~raulMrello/130.embed" height="525px" width="100%"></iframe>

# %%
# plot BollingerBands Width and its SMA
_df_draw = _df_result.copy()

trace_bbw = go.Scatter(x=_df_draw.index.values, y=_df_draw.BOLLINGER_WIDTH, name='BBWidth', line=scatter.Line(color='blue', width=1))

#sma_list = [x for x in _df_draw.columns if 'SMA' in x]
trace_bbw_sma20=go.Scatter(x=_df_draw.index.values, y=_df_draw.BOLLINGER_WIDTH_SMA20, name='sma20', line=scatter.Line(color='red', width=1))
trace_bbw_sma50=go.Scatter(x=_df_draw.index.values, y=_df_draw.BOLLINGER_WIDTH_SMA50, name='sma50', line=scatter.Line(color='green', width=1))
trace_bbw_sma100=go.Scatter(x=_df_draw.index.values, y=_df_draw.BOLLINGER_WIDTH_SMA100, name='sma100', line=scatter.Line(color='brown', width=1))
  
py.iplot([trace_bbw, trace_bbw_sma20, trace_bbw_sma50, trace_bbw_sma100], filename='simple_ohlc')
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): plot.ly:443
# DEBUG:urllib3.connectionpool:https://plot.ly:443 "POST /clientresp HTTP/1.1" 200 None
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~raulMrello/130.embed" height="525px" width="100%"></iframe>

# %%
# plot both charts in the same figure
fig = plotly.tools.make_subplots(rows=2, cols=1, subplot_titles=('Zigzag', 'BBWidth'), shared_xaxes=True, vertical_spacing=0.1)
fig['layout'].update(height=600, title='Zigzag Indicator', xaxis=dict(rangeslider=dict(visible = False)))
fig.append_trace(trace_ohlc, 1, 1)
fig.append_trace(trace_zigzag, 1, 1)
fig.append_trace(trace_bbup, 1, 1)
fig.append_trace(trace_bbdn, 1, 1)
fig.append_trace(trace_bbw, 2, 1)
fig.append_trace(trace_bbw_sma50, 2, 1)
py.iplot(fig, filename='zigzag_indicator')
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]
# [ (2,1) x1,y2 ]
#
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): plot.ly:443
# DEBUG:urllib3.connectionpool:https://plot.ly:443 "POST /clientresp HTTP/1.1" 200 None
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~raulMrello/132.embed" height="600px" width="100%"></iframe>
